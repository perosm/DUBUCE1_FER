# %%
colab = True

# %%
if colab:
  from google.colab import drive
  drive.mount('/content/drive/')

  import sys
  sys.path.append('/content/drive/My\ Drive/dubuce/lab2/')
  # %cd /content/drive/My\ Drive/dubuce/lab2/
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive/dubuce/lab2

# %%
# !python3 setup_cython.py build_ext --inplace

# %%
import os
import torch
import torchvision
from torchvision import transforms
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torchvision.datasets import MNIST
from torchvision.datasets import CIFAR10
import matplotlib.pyplot as plt
import skimage as ski
import skimage.io
import task_3
import numpy as np

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-f88898d0bef6> in <cell line: 3>()
#       1 import os
#       2 import torch
# ----> 3 import torchvision
#       4 from torchvision import transforms
#       5 from torch import nn
#
# /usr/local/lib/python3.10/dist-packages/torchvision/__init__.py in <module>
#       4
#       5 import torch
# ----> 6 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils
#       7
#       8 from .extension import _HAS_OPS
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/__init__.py in <module>
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#       5 from .googlenet import *
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/convnext.py in <module>
#       7
#       8 from ..ops.misc import Conv2dNormActivation, Permute
# ----> 9 from ..ops.stochastic_depth import StochasticDepth
#      10 from ..transforms._presets import ImageClassification
#      11 from ..utils import _log_api_usage_once
#
# /usr/local/lib/python3.10/dist-packages/torchvision/ops/__init__.py in <module>
#      21 from .giou_loss import generalized_box_iou_loss
#      22 from .misc import Conv2dNormActivation, Conv3dNormActivation, FrozenBatchNorm2d, MLP, Permute, SqueezeExcitation
# ---> 23 from .poolers import MultiScaleRoIAlign
#      24 from .ps_roi_align import ps_roi_align, PSRoIAlign
#      25 from .ps_roi_pool import ps_roi_pool, PSRoIPool
#
# /usr/local/lib/python3.10/dist-packages/torchvision/ops/poolers.py in <module>
#       8
#       9 from ..utils import _log_api_usage_once
# ---> 10 from .roi_align import roi_align
#      11
#      12
#
# /usr/local/lib/python3.10/dist-packages/torchvision/ops/roi_align.py in <module>
#       2
#       3 import torch
# ----> 4 import torch._dynamo
#       5 import torch.fx
#       6 from torch import nn, Tensor
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/__init__.py in <module>
#       1 import torch
# ----> 2 from . import allowed_functions, convert_frame, eval_frame, resume_execution
#       3 from .backends.registry import list_backends, lookup_backend, register_backend
#       4 from .code_context import code_context
#       5 from .convert_frame import replay
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py in <module>
#      60 )
#      61 from .hooks import Hooks
# ---> 62 from .output_graph import OutputGraph
#      63 from .replay_record import ExecutionRecord
#      64 from .symbolic_convert import InstructionTranslator, SpeculationLog
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py in <module>
#      37 from torch.utils.weak import WeakTensorKeyDictionary
#      38
# ---> 39 from . import config, logging as torchdynamo_logging, variables
#      40 from .backends.registry import CompiledFn, CompilerFn
#      41 from .bytecode_transformation import (
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/__init__.py in <module>
#      66     UnspecializedPythonVariable,
#      67 )
# ---> 68 from .torch import (
#      69     TorchCtxManagerClassVariable,
#      70     TorchInGraphFunctionVariable,
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/torch.py in <module>
#      93     torch.fx._symbolic_trace.is_fx_tracing: False,
#      94     torch.onnx.is_in_onnx_export: False,
# ---> 95     torch._dynamo.external_utils.is_compiling: True,
#      96     torch._utils.is_compiling: True,
#      97 }
#
# AttributeError: partially initialized module 'torch._dynamo' has no attribute 'external_utils' (most likely due to a circular import)

# %%
import layers

# %% [markdown]
# ***1. zadatak (25%)***

# %% [markdown]
# Provjera za FC, ReLU, SoftmaxCrossEntropyWithLogits i L2Regularizer sloj:

# %%
import check_grads
# Out:
# Convolution
# Check grad wrt input
# Relative error =  4.1265702853534004e-10
# Error norm =  2.893025707175853e-10
# Check grad wrt params
# Check weights:
# Relative error =  7.786814481984147e-11
# Error norm =  3.062608726240349e-10
# Check biases:
# Relative error =  5.34905110282533e-12
# Error norm =  9.701961287465584e-11
#
# MaxPooling
# Check grad wrt input
# Relative error =  3.2756317937458486e-12
# Error norm =  9.172497436507492e-11
#
# ReLU
# Check grad wrt input
# Relative error =  3.275632591563771e-12
# Error norm =  6.012417409480184e-11
#
# FC
# Check grad wrt input
# Relative error =  2.087069069748672e-09
# Error norm =  8.178676322866813e-10
# Check grad wrt params
# Check weights:
# Relative error =  2.767133343835897e-09
# Error norm =  7.721063363401009e-10
# Check biases:
# Relative error =  1.4604470151145592e-10
# Error norm =  1.7707692424208752e-10
#
# SoftmaxCrossEntropyWithLogits
# Relative error =  4.904107027226483e-07
# Error norm =  5.77064906016417e-10
#
# L2Regularizer
# Check grad wrt params
# Relative error =  3.0454620975170145e-06
# Error norm =  1.1908363448723337e-09

# %% [markdown]
# Proučite i skicirajte model zadan objektom net u skripti train.py. Odredite veličine tenzora te broj parametara u svakom sloju. Odredite veličinu receptivnog polja značajki iz posljednjeg (drugog) konvolucijskog sloja. Procijenite ukupnu količinu memorije za pohranjivanje aktivacija koje su potrebne za provođenje backpropa ako učimo s mini-grupama od 50 slika.

# %%
# %run train.py
# Out:
# epoch 1, step 0/55000, batch loss = 2.52
# epoch 1, step 250/55000, batch loss = 2.04
# epoch 1, step 500/55000, batch loss = 1.50
# epoch 1, step 750/55000, batch loss = 1.41
# epoch 1, step 1000/55000, batch loss = 0.90
# epoch 1, step 1250/55000, batch loss = 0.63
# epoch 1, step 1500/55000, batch loss = 0.82
# epoch 1, step 1750/55000, batch loss = 0.63
# epoch 1, step 2000/55000, batch loss = 0.76
# epoch 1, step 2250/55000, batch loss = 0.41
# epoch 1, step 2500/55000, batch loss = 0.53
# Train accuracy = 66.63
# epoch 1, step 2750/55000, batch loss = 0.42
# epoch 1, step 3000/55000, batch loss = 0.28
# epoch 1, step 3250/55000, batch loss = 0.41
# epoch 1, step 3500/55000, batch loss = 0.22
# epoch 1, step 3750/55000, batch loss = 0.51
# epoch 1, step 4000/55000, batch loss = 0.19
# epoch 1, step 4250/55000, batch loss = 0.24
# epoch 1, step 4500/55000, batch loss = 0.12
# epoch 1, step 4750/55000, batch loss = 0.26
# epoch 1, step 5000/55000, batch loss = 0.29
# Train accuracy = 78.40
# epoch 1, step 5250/55000, batch loss = 0.13
# epoch 1, step 5500/55000, batch loss = 0.18
# epoch 1, step 5750/55000, batch loss = 0.13
# epoch 1, step 6000/55000, batch loss = 0.16
# epoch 1, step 6250/55000, batch loss = 0.33
# epoch 1, step 6500/55000, batch loss = 0.57
# epoch 1, step 6750/55000, batch loss = 0.42
# epoch 1, step 7000/55000, batch loss = 0.16
# epoch 1, step 7250/55000, batch loss = 0.11
# epoch 1, step 7500/55000, batch loss = 0.09
# Train accuracy = 83.46
# epoch 1, step 7750/55000, batch loss = 0.16
# epoch 1, step 8000/55000, batch loss = 0.47
# epoch 1, step 8250/55000, batch loss = 0.27
# epoch 1, step 8500/55000, batch loss = 0.06
# epoch 1, step 8750/55000, batch loss = 0.20
# epoch 1, step 9000/55000, batch loss = 0.22
# epoch 1, step 9250/55000, batch loss = 0.24
# epoch 1, step 9500/55000, batch loss = 0.29
# epoch 1, step 9750/55000, batch loss = 0.14
# epoch 1, step 10000/55000, batch loss = 0.40
# Train accuracy = 85.87
# epoch 1, step 10250/55000, batch loss = 0.08
# epoch 1, step 10500/55000, batch loss = 0.06
# epoch 1, step 10750/55000, batch loss = 0.33
# epoch 1, step 11000/55000, batch loss = 0.29
# epoch 1, step 11250/55000, batch loss = 0.07
# epoch 1, step 11500/55000, batch loss = 0.08
# epoch 1, step 11750/55000, batch loss = 0.27
# epoch 1, step 12000/55000, batch loss = 0.03
# epoch 1, step 12250/55000, batch loss = 0.03
# epoch 1, step 12500/55000, batch loss = 0.19
# Train accuracy = 87.71
# epoch 1, step 12750/55000, batch loss = 0.13
# epoch 1, step 13000/55000, batch loss = 0.11
# epoch 1, step 13250/55000, batch loss = 0.24
# epoch 1, step 13500/55000, batch loss = 0.10
# epoch 1, step 13750/55000, batch loss = 0.15
# epoch 1, step 14000/55000, batch loss = 0.10
# epoch 1, step 14250/55000, batch loss = 0.22
# epoch 1, step 14500/55000, batch loss = 0.19
# epoch 1, step 14750/55000, batch loss = 0.21
# epoch 1, step 15000/55000, batch loss = 0.13
# Train accuracy = 89.10
# epoch 1, step 15250/55000, batch loss = 0.13
# epoch 1, step 15500/55000, batch loss = 0.11
# epoch 1, step 15750/55000, batch loss = 0.11
# epoch 1, step 16000/55000, batch loss = 0.14
# epoch 1, step 16250/55000, batch loss = 0.06
# epoch 1, step 16500/55000, batch loss = 0.11
# epoch 1, step 16750/55000, batch loss = 0.10
# epoch 1, step 17000/55000, batch loss = 0.12
# epoch 1, step 17250/55000, batch loss = 0.13
# epoch 1, step 17500/55000, batch loss = 0.12
# Train accuracy = 90.20
# epoch 1, step 17750/55000, batch loss = 0.26
# epoch 1, step 18000/55000, batch loss = 0.15
# epoch 1, step 18250/55000, batch loss = 0.14
# epoch 1, step 18500/55000, batch loss = 0.07
# epoch 1, step 18750/55000, batch loss = 0.13
# epoch 1, step 19000/55000, batch loss = 0.09
# epoch 1, step 19250/55000, batch loss = 0.14
# epoch 1, step 19500/55000, batch loss = 0.04
# epoch 1, step 19750/55000, batch loss = 0.11
# epoch 1, step 20000/55000, batch loss = 0.24
# Train accuracy = 90.97
# epoch 1, step 20250/55000, batch loss = 0.17
# epoch 1, step 20500/55000, batch loss = 0.04
# epoch 1, step 20750/55000, batch loss = 0.04
# epoch 1, step 21000/55000, batch loss = 0.09
# epoch 1, step 21250/55000, batch loss = 0.13
# epoch 1, step 21500/55000, batch loss = 0.18
# epoch 1, step 21750/55000, batch loss = 0.07
# epoch 1, step 22000/55000, batch loss = 0.13
# epoch 1, step 22250/55000, batch loss = 0.08
# epoch 1, step 22500/55000, batch loss = 0.09
# Train accuracy = 91.58
# epoch 1, step 22750/55000, batch loss = 0.05
# epoch 1, step 23000/55000, batch loss = 0.03
# epoch 1, step 23250/55000, batch loss = 0.11
# epoch 1, step 23500/55000, batch loss = 0.02
# epoch 1, step 23750/55000, batch loss = 0.11
# epoch 1, step 24000/55000, batch loss = 0.05
# epoch 1, step 24250/55000, batch loss = 0.06
# epoch 1, step 24500/55000, batch loss = 0.12
# epoch 1, step 24750/55000, batch loss = 0.05
# epoch 1, step 25000/55000, batch loss = 0.07
# Train accuracy = 92.17
# epoch 1, step 25250/55000, batch loss = 0.12
# epoch 1, step 25500/55000, batch loss = 0.16
# epoch 1, step 25750/55000, batch loss = 0.11
# epoch 1, step 26000/55000, batch loss = 0.13
# epoch 1, step 26250/55000, batch loss = 0.06
# epoch 1, step 26500/55000, batch loss = 0.17
# epoch 1, step 26750/55000, batch loss = 0.18
# epoch 1, step 27000/55000, batch loss = 0.02
# epoch 1, step 27250/55000, batch loss = 0.02
# epoch 1, step 27500/55000, batch loss = 0.12
# Train accuracy = 92.58
# epoch 1, step 27750/55000, batch loss = 0.20
# epoch 1, step 28000/55000, batch loss = 0.12
# epoch 1, step 28250/55000, batch loss = 0.03
# epoch 1, step 28500/55000, batch loss = 0.21
# epoch 1, step 28750/55000, batch loss = 0.12
# epoch 1, step 29000/55000, batch loss = 0.20
# epoch 1, step 29250/55000, batch loss = 0.03
# epoch 1, step 29500/55000, batch loss = 0.20
# epoch 1, step 29750/55000, batch loss = 0.07
# epoch 1, step 30000/55000, batch loss = 0.04
# Train accuracy = 92.97
# epoch 1, step 30250/55000, batch loss = 0.12
# epoch 1, step 30500/55000, batch loss = 0.04
# epoch 1, step 30750/55000, batch loss = 0.07
# epoch 1, step 31000/55000, batch loss = 0.05
# epoch 1, step 31250/55000, batch loss = 0.02
# epoch 1, step 31500/55000, batch loss = 0.10
# epoch 1, step 31750/55000, batch loss = 0.04
# epoch 1, step 32000/55000, batch loss = 0.05
# epoch 1, step 32250/55000, batch loss = 0.15
# epoch 1, step 32500/55000, batch loss = 0.19
# Train accuracy = 93.29
# epoch 1, step 32750/55000, batch loss = 0.01
# epoch 1, step 33000/55000, batch loss = 0.05
# epoch 1, step 33250/55000, batch loss = 0.05
# epoch 1, step 33500/55000, batch loss = 0.14
# epoch 1, step 33750/55000, batch loss = 0.36
# epoch 1, step 34000/55000, batch loss = 0.05
# epoch 1, step 34250/55000, batch loss = 0.01
# epoch 1, step 34500/55000, batch loss = 0.05
# epoch 1, step 34750/55000, batch loss = 0.10
# epoch 1, step 35000/55000, batch loss = 0.02
# Train accuracy = 93.59
# epoch 1, step 35250/55000, batch loss = 0.09
# epoch 1, step 35500/55000, batch loss = 0.04
# epoch 1, step 35750/55000, batch loss = 0.01
# epoch 1, step 36000/55000, batch loss = 0.13
# epoch 1, step 36250/55000, batch loss = 0.03
# epoch 1, step 36500/55000, batch loss = 0.15
# epoch 1, step 36750/55000, batch loss = 0.04
# epoch 1, step 37000/55000, batch loss = 0.07
# epoch 1, step 37250/55000, batch loss = 0.03
# epoch 1, step 37500/55000, batch loss = 0.10
# Train accuracy = 93.87
# epoch 1, step 37750/55000, batch loss = 0.04
# epoch 1, step 38000/55000, batch loss = 0.08
# epoch 1, step 38250/55000, batch loss = 0.04
# epoch 1, step 38500/55000, batch loss = 0.12
# epoch 1, step 38750/55000, batch loss = 0.11
# epoch 1, step 39000/55000, batch loss = 0.01
# epoch 1, step 39250/55000, batch loss = 0.04
# epoch 1, step 39500/55000, batch loss = 0.18
# epoch 1, step 39750/55000, batch loss = 0.10
# epoch 1, step 40000/55000, batch loss = 0.09
# Train accuracy = 94.12
# epoch 1, step 40250/55000, batch loss = 0.02
# epoch 1, step 40500/55000, batch loss = 0.03
# epoch 1, step 40750/55000, batch loss = 0.02
# epoch 1, step 41000/55000, batch loss = 0.01
# epoch 1, step 41250/55000, batch loss = 0.19
# epoch 1, step 41500/55000, batch loss = 0.26
# epoch 1, step 41750/55000, batch loss = 0.10
# epoch 1, step 42000/55000, batch loss = 0.07
# epoch 1, step 42250/55000, batch loss = 0.16
# epoch 1, step 42500/55000, batch loss = 0.04
# Train accuracy = 94.32
# epoch 1, step 42750/55000, batch loss = 0.03
# epoch 1, step 43000/55000, batch loss = 0.03
# epoch 1, step 43250/55000, batch loss = 0.07
# epoch 1, step 43500/55000, batch loss = 0.04
# epoch 1, step 43750/55000, batch loss = 0.06
# epoch 1, step 44000/55000, batch loss = 0.15
# epoch 1, step 44250/55000, batch loss = 0.08
# epoch 1, step 44500/55000, batch loss = 0.16
# epoch 1, step 44750/55000, batch loss = 0.21
# epoch 1, step 45000/55000, batch loss = 0.04
# Train accuracy = 94.47
# epoch 1, step 45250/55000, batch loss = 0.19
# epoch 1, step 45500/55000, batch loss = 0.06
# epoch 1, step 45750/55000, batch loss = 0.08
# epoch 1, step 46000/55000, batch loss = 0.01
# epoch 1, step 46250/55000, batch loss = 0.01
# epoch 1, step 46500/55000, batch loss = 0.20
# epoch 1, step 46750/55000, batch loss = 0.12
# epoch 1, step 47000/55000, batch loss = 0.23
# epoch 1, step 47250/55000, batch loss = 0.05
# epoch 1, step 47500/55000, batch loss = 0.18
# Train accuracy = 94.64
# epoch 1, step 47750/55000, batch loss = 0.16
# epoch 1, step 48000/55000, batch loss = 0.07
# epoch 1, step 48250/55000, batch loss = 0.07
# epoch 1, step 48500/55000, batch loss = 0.02
# epoch 1, step 48750/55000, batch loss = 0.10
# epoch 1, step 49000/55000, batch loss = 0.06
# epoch 1, step 49250/55000, batch loss = 0.05
# epoch 1, step 49500/55000, batch loss = 0.02
# epoch 1, step 49750/55000, batch loss = 0.06
# epoch 1, step 50000/55000, batch loss = 0.35
# Train accuracy = 94.79
# epoch 1, step 50250/55000, batch loss = 0.05
# epoch 1, step 50500/55000, batch loss = 0.09
# epoch 1, step 50750/55000, batch loss = 0.08
# epoch 1, step 51000/55000, batch loss = 0.19
# epoch 1, step 51250/55000, batch loss = 0.03
# epoch 1, step 51500/55000, batch loss = 0.11
# epoch 1, step 51750/55000, batch loss = 0.04
# epoch 1, step 52000/55000, batch loss = 0.07
# epoch 1, step 52250/55000, batch loss = 0.08
# epoch 1, step 52500/55000, batch loss = 0.13
# Train accuracy = 94.95
# epoch 1, step 52750/55000, batch loss = 0.05
# epoch 1, step 53000/55000, batch loss = 0.10
# epoch 1, step 53250/55000, batch loss = 0.06
# epoch 1, step 53500/55000, batch loss = 0.07
# epoch 1, step 53750/55000, batch loss = 0.01
# epoch 1, step 54000/55000, batch loss = 0.08
# epoch 1, step 54250/55000, batch loss = 0.24
# epoch 1, step 54500/55000, batch loss = 0.02
# epoch 1, step 54750/55000, batch loss = 0.11
# Train accuracy = 95.09
#
# Running evaluation:  Validation
# Validation accuracy = 98.12
# Validation avg loss = 0.06
#
# epoch 2, step 0/55000, batch loss = 0.03
# epoch 2, step 250/55000, batch loss = 0.03
# epoch 2, step 500/55000, batch loss = 0.02
# epoch 2, step 750/55000, batch loss = 0.03
# epoch 2, step 1000/55000, batch loss = 0.03
# epoch 2, step 1250/55000, batch loss = 0.02
# epoch 2, step 1500/55000, batch loss = 0.01
# epoch 2, step 1750/55000, batch loss = 0.06
# epoch 2, step 2000/55000, batch loss = 0.09
# epoch 2, step 2250/55000, batch loss = 0.06
# epoch 2, step 2500/55000, batch loss = 0.02
# Train accuracy = 98.75
# epoch 2, step 2750/55000, batch loss = 0.06
# epoch 2, step 3000/55000, batch loss = 0.10
# epoch 2, step 3250/55000, batch loss = 0.06
# epoch 2, step 3500/55000, batch loss = 0.01
# epoch 2, step 3750/55000, batch loss = 0.03
# epoch 2, step 4000/55000, batch loss = 0.01
# epoch 2, step 4250/55000, batch loss = 0.05
# epoch 2, step 4500/55000, batch loss = 0.00
# epoch 2, step 4750/55000, batch loss = 0.01
# epoch 2, step 5000/55000, batch loss = 0.02
# Train accuracy = 98.75
# epoch 2, step 5250/55000, batch loss = 0.09
# epoch 2, step 5500/55000, batch loss = 0.02
# epoch 2, step 5750/55000, batch loss = 0.01
# epoch 2, step 6000/55000, batch loss = 0.08
# epoch 2, step 6250/55000, batch loss = 0.16
# epoch 2, step 6500/55000, batch loss = 0.09
# epoch 2, step 6750/55000, batch loss = 0.11
# epoch 2, step 7000/55000, batch loss = 0.02
# epoch 2, step 7250/55000, batch loss = 0.10
# epoch 2, step 7500/55000, batch loss = 0.00
# Train accuracy = 98.70
# epoch 2, step 7750/55000, batch loss = 0.02
# epoch 2, step 8000/55000, batch loss = 0.05
# epoch 2, step 8250/55000, batch loss = 0.21
# epoch 2, step 8500/55000, batch loss = 0.04
# epoch 2, step 8750/55000, batch loss = 0.01
# epoch 2, step 9000/55000, batch loss = 0.08
# epoch 2, step 9250/55000, batch loss = 0.01
# epoch 2, step 9500/55000, batch loss = 0.04
# epoch 2, step 9750/55000, batch loss = 0.01
# epoch 2, step 10000/55000, batch loss = 0.15
# Train accuracy = 98.61
# epoch 2, step 10250/55000, batch loss = 0.03
# epoch 2, step 10500/55000, batch loss = 0.02
# epoch 2, step 10750/55000, batch loss = 0.04
# epoch 2, step 11000/55000, batch loss = 0.08
# epoch 2, step 11250/55000, batch loss = 0.11
# epoch 2, step 11500/55000, batch loss = 0.12
# epoch 2, step 11750/55000, batch loss = 0.01
# epoch 2, step 12000/55000, batch loss = 0.10
# epoch 2, step 12250/55000, batch loss = 0.07
# epoch 2, step 12500/55000, batch loss = 0.00
# Train accuracy = 98.61
# epoch 2, step 12750/55000, batch loss = 0.05
# epoch 2, step 13000/55000, batch loss = 0.03
# epoch 2, step 13250/55000, batch loss = 0.04
# epoch 2, step 13500/55000, batch loss = 0.05
# epoch 2, step 13750/55000, batch loss = 0.02
# epoch 2, step 14000/55000, batch loss = 0.01
# epoch 2, step 14250/55000, batch loss = 0.03
# epoch 2, step 14500/55000, batch loss = 0.01
# epoch 2, step 14750/55000, batch loss = 0.05
# epoch 2, step 15000/55000, batch loss = 0.02
# Train accuracy = 98.56
# epoch 2, step 15250/55000, batch loss = 0.01
# epoch 2, step 15500/55000, batch loss = 0.03
# epoch 2, step 15750/55000, batch loss = 0.10
# epoch 2, step 16000/55000, batch loss = 0.05
# epoch 2, step 16250/55000, batch loss = 0.03
# epoch 2, step 16500/55000, batch loss = 0.09
# epoch 2, step 16750/55000, batch loss = 0.13
# epoch 2, step 17000/55000, batch loss = 0.01
# epoch 2, step 17250/55000, batch loss = 0.02
# epoch 2, step 17500/55000, batch loss = 0.21
# Train accuracy = 98.50
# epoch 2, step 17750/55000, batch loss = 0.01
# epoch 2, step 18000/55000, batch loss = 0.03
# epoch 2, step 18250/55000, batch loss = 0.09
# epoch 2, step 18500/55000, batch loss = 0.01
# epoch 2, step 18750/55000, batch loss = 0.02
# epoch 2, step 19000/55000, batch loss = 0.13
# epoch 2, step 19250/55000, batch loss = 0.10
# epoch 2, step 19500/55000, batch loss = 0.03
# epoch 2, step 19750/55000, batch loss = 0.05
# epoch 2, step 20000/55000, batch loss = 0.00
# Train accuracy = 98.53
# epoch 2, step 20250/55000, batch loss = 0.06
# epoch 2, step 20500/55000, batch loss = 0.01
# epoch 2, step 20750/55000, batch loss = 0.00
# epoch 2, step 21000/55000, batch loss = 0.11
# epoch 2, step 21250/55000, batch loss = 0.01
# epoch 2, step 21500/55000, batch loss = 0.03
# epoch 2, step 21750/55000, batch loss = 0.09
# epoch 2, step 22000/55000, batch loss = 0.09
# epoch 2, step 22250/55000, batch loss = 0.06
# epoch 2, step 22500/55000, batch loss = 0.04
# Train accuracy = 98.50
# epoch 2, step 22750/55000, batch loss = 0.03
# epoch 2, step 23000/55000, batch loss = 0.02
# epoch 2, step 23250/55000, batch loss = 0.08
# epoch 2, step 23500/55000, batch loss = 0.01
# epoch 2, step 23750/55000, batch loss = 0.01
# epoch 2, step 24000/55000, batch loss = 0.01
# epoch 2, step 24250/55000, batch loss = 0.04
# epoch 2, step 24500/55000, batch loss = 0.05
# epoch 2, step 24750/55000, batch loss = 0.00
# epoch 2, step 25000/55000, batch loss = 0.08
# Train accuracy = 98.53
# epoch 2, step 25250/55000, batch loss = 0.09
# epoch 2, step 25500/55000, batch loss = 0.01
# epoch 2, step 25750/55000, batch loss = 0.02
# epoch 2, step 26000/55000, batch loss = 0.02
# epoch 2, step 26250/55000, batch loss = 0.15
# epoch 2, step 26500/55000, batch loss = 0.02
# epoch 2, step 26750/55000, batch loss = 0.06
# epoch 2, step 27000/55000, batch loss = 0.02
# epoch 2, step 27250/55000, batch loss = 0.04
# epoch 2, step 27500/55000, batch loss = 0.14
# Train accuracy = 98.48
# epoch 2, step 27750/55000, batch loss = 0.01
# epoch 2, step 28000/55000, batch loss = 0.03
# epoch 2, step 28250/55000, batch loss = 0.21
# epoch 2, step 28500/55000, batch loss = 0.03
# epoch 2, step 28750/55000, batch loss = 0.14
# epoch 2, step 29000/55000, batch loss = 0.09
# epoch 2, step 29250/55000, batch loss = 0.05
# epoch 2, step 29500/55000, batch loss = 0.13
# epoch 2, step 29750/55000, batch loss = 0.07
# epoch 2, step 30000/55000, batch loss = 0.07
# Train accuracy = 98.45
# epoch 2, step 30250/55000, batch loss = 0.01
# epoch 2, step 30500/55000, batch loss = 0.02
# epoch 2, step 30750/55000, batch loss = 0.04
# epoch 2, step 31000/55000, batch loss = 0.02
# epoch 2, step 31250/55000, batch loss = 0.02
# epoch 2, step 31500/55000, batch loss = 0.00
# epoch 2, step 31750/55000, batch loss = 0.04
# epoch 2, step 32000/55000, batch loss = 0.03
# epoch 2, step 32250/55000, batch loss = 0.03
# epoch 2, step 32500/55000, batch loss = 0.01
# Train accuracy = 98.46
# epoch 2, step 32750/55000, batch loss = 0.04
# epoch 2, step 33000/55000, batch loss = 0.08
# epoch 2, step 33250/55000, batch loss = 0.00
# epoch 2, step 33500/55000, batch loss = 0.03
# epoch 2, step 33750/55000, batch loss = 0.05
# epoch 2, step 34000/55000, batch loss = 0.02
# epoch 2, step 34250/55000, batch loss = 0.03
# epoch 2, step 34500/55000, batch loss = 0.04
# epoch 2, step 34750/55000, batch loss = 0.02
# epoch 2, step 35000/55000, batch loss = 0.03
# Train accuracy = 98.47
# epoch 2, step 35250/55000, batch loss = 0.07
# epoch 2, step 35500/55000, batch loss = 0.03
# epoch 2, step 35750/55000, batch loss = 0.00
# epoch 2, step 36000/55000, batch loss = 0.01
# epoch 2, step 36250/55000, batch loss = 0.04
# epoch 2, step 36500/55000, batch loss = 0.07
# epoch 2, step 36750/55000, batch loss = 0.01
# epoch 2, step 37000/55000, batch loss = 0.05
# epoch 2, step 37250/55000, batch loss = 0.04
# epoch 2, step 37500/55000, batch loss = 0.06
# Train accuracy = 98.47
# epoch 2, step 37750/55000, batch loss = 0.01
# epoch 2, step 38000/55000, batch loss = 0.02
# epoch 2, step 38250/55000, batch loss = 0.05
# epoch 2, step 38500/55000, batch loss = 0.02
# epoch 2, step 38750/55000, batch loss = 0.03
# epoch 2, step 39000/55000, batch loss = 0.01
# epoch 2, step 39250/55000, batch loss = 0.00
# epoch 2, step 39500/55000, batch loss = 0.12
# epoch 2, step 39750/55000, batch loss = 0.09
# epoch 2, step 40000/55000, batch loss = 0.03
# Train accuracy = 98.48
# epoch 2, step 40250/55000, batch loss = 0.04
# epoch 2, step 40500/55000, batch loss = 0.01
# epoch 2, step 40750/55000, batch loss = 0.03
# epoch 2, step 41000/55000, batch loss = 0.08
# epoch 2, step 41250/55000, batch loss = 0.04
# epoch 2, step 41500/55000, batch loss = 0.14
# epoch 2, step 41750/55000, batch loss = 0.04
# epoch 2, step 42000/55000, batch loss = 0.01
# epoch 2, step 42250/55000, batch loss = 0.04
# epoch 2, step 42500/55000, batch loss = 0.05
# Train accuracy = 98.49
# epoch 2, step 42750/55000, batch loss = 0.06
# epoch 2, step 43000/55000, batch loss = 0.00
# epoch 2, step 43250/55000, batch loss = 0.05
# epoch 2, step 43500/55000, batch loss = 0.03
# epoch 2, step 43750/55000, batch loss = 0.01
# epoch 2, step 44000/55000, batch loss = 0.09
# epoch 2, step 44250/55000, batch loss = 0.04
# epoch 2, step 44500/55000, batch loss = 0.02
# epoch 2, step 44750/55000, batch loss = 0.02
# epoch 2, step 45000/55000, batch loss = 0.00
# Train accuracy = 98.50
# epoch 2, step 45250/55000, batch loss = 0.01
# epoch 2, step 45500/55000, batch loss = 0.05
# epoch 2, step 45750/55000, batch loss = 0.02
# epoch 2, step 46000/55000, batch loss = 0.10
# epoch 2, step 46250/55000, batch loss = 0.14
# epoch 2, step 46500/55000, batch loss = 0.05
# epoch 2, step 46750/55000, batch loss = 0.25
# epoch 2, step 47000/55000, batch loss = 0.05
# epoch 2, step 47250/55000, batch loss = 0.04
# epoch 2, step 47500/55000, batch loss = 0.01
# Train accuracy = 98.52
# epoch 2, step 47750/55000, batch loss = 0.02
# epoch 2, step 48000/55000, batch loss = 0.15
# epoch 2, step 48250/55000, batch loss = 0.08
# epoch 2, step 48500/55000, batch loss = 0.04
# epoch 2, step 48750/55000, batch loss = 0.02
# epoch 2, step 49000/55000, batch loss = 0.00
# epoch 2, step 49250/55000, batch loss = 0.04
# epoch 2, step 49500/55000, batch loss = 0.01
# epoch 2, step 49750/55000, batch loss = 0.03
# epoch 2, step 50000/55000, batch loss = 0.02
# Train accuracy = 98.52
# epoch 2, step 50250/55000, batch loss = 0.11
# epoch 2, step 50500/55000, batch loss = 0.07
# epoch 2, step 50750/55000, batch loss = 0.04
# epoch 2, step 51000/55000, batch loss = 0.03
# epoch 2, step 51250/55000, batch loss = 0.02
# epoch 2, step 51500/55000, batch loss = 0.01
# epoch 2, step 51750/55000, batch loss = 0.00
# epoch 2, step 52000/55000, batch loss = 0.15
# epoch 2, step 52250/55000, batch loss = 0.05
# epoch 2, step 52500/55000, batch loss = 0.01
# Train accuracy = 98.51
# epoch 2, step 52750/55000, batch loss = 0.00
# epoch 2, step 53000/55000, batch loss = 0.14
# epoch 2, step 53250/55000, batch loss = 0.04
# epoch 2, step 53500/55000, batch loss = 0.03
# epoch 2, step 53750/55000, batch loss = 0.01
# epoch 2, step 54000/55000, batch loss = 0.04
# epoch 2, step 54250/55000, batch loss = 0.02
# epoch 2, step 54500/55000, batch loss = 0.05
# epoch 2, step 54750/55000, batch loss = 0.01
# Train accuracy = 98.52
#
# Running evaluation:  Validation
# Validation accuracy = 98.74
# Validation avg loss = 0.05
#
# epoch 3, step 0/55000, batch loss = 0.01
# epoch 3, step 250/55000, batch loss = 0.03
# epoch 3, step 500/55000, batch loss = 0.01
# epoch 3, step 750/55000, batch loss = 0.00
# epoch 3, step 1000/55000, batch loss = 0.01
# epoch 3, step 1250/55000, batch loss = 0.04
# epoch 3, step 1500/55000, batch loss = 0.00
# epoch 3, step 1750/55000, batch loss = 0.03
# epoch 3, step 2000/55000, batch loss = 0.03
# epoch 3, step 2250/55000, batch loss = 0.04
# epoch 3, step 2500/55000, batch loss = 0.00
# Train accuracy = 98.94
# epoch 3, step 2750/55000, batch loss = 0.01
# epoch 3, step 3000/55000, batch loss = 0.01
# epoch 3, step 3250/55000, batch loss = 0.01
# epoch 3, step 3500/55000, batch loss = 0.00
# epoch 3, step 3750/55000, batch loss = 0.03
# epoch 3, step 4000/55000, batch loss = 0.00
# epoch 3, step 4250/55000, batch loss = 0.01
# epoch 3, step 4500/55000, batch loss = 0.01
# epoch 3, step 4750/55000, batch loss = 0.01
# epoch 3, step 5000/55000, batch loss = 0.04
# Train accuracy = 99.09
# epoch 3, step 5250/55000, batch loss = 0.00
# epoch 3, step 5500/55000, batch loss = 0.17
# epoch 3, step 5750/55000, batch loss = 0.01
# epoch 3, step 6000/55000, batch loss = 0.00
# epoch 3, step 6250/55000, batch loss = 0.01
# epoch 3, step 6500/55000, batch loss = 0.00
# epoch 3, step 6750/55000, batch loss = 0.02
# epoch 3, step 7000/55000, batch loss = 0.02
# epoch 3, step 7250/55000, batch loss = 0.01
# epoch 3, step 7500/55000, batch loss = 0.00
# Train accuracy = 99.17
# epoch 3, step 7750/55000, batch loss = 0.03
# epoch 3, step 8000/55000, batch loss = 0.03
# epoch 3, step 8250/55000, batch loss = 0.05
# epoch 3, step 8500/55000, batch loss = 0.00
# epoch 3, step 8750/55000, batch loss = 0.05
# epoch 3, step 9000/55000, batch loss = 0.03
# epoch 3, step 9250/55000, batch loss = 0.05
# epoch 3, step 9500/55000, batch loss = 0.03
# epoch 3, step 9750/55000, batch loss = 0.07
# epoch 3, step 10000/55000, batch loss = 0.00
# Train accuracy = 99.17
# epoch 3, step 10250/55000, batch loss = 0.00
# epoch 3, step 10500/55000, batch loss = 0.01
# epoch 3, step 10750/55000, batch loss = 0.00
# epoch 3, step 11000/55000, batch loss = 0.05
# epoch 3, step 11250/55000, batch loss = 0.01
# epoch 3, step 11500/55000, batch loss = 0.00
# epoch 3, step 11750/55000, batch loss = 0.02
# epoch 3, step 12000/55000, batch loss = 0.01
# epoch 3, step 12250/55000, batch loss = 0.00
# epoch 3, step 12500/55000, batch loss = 0.01
# Train accuracy = 99.25
# epoch 3, step 12750/55000, batch loss = 0.02
# epoch 3, step 13000/55000, batch loss = 0.04
# epoch 3, step 13250/55000, batch loss = 0.01
# epoch 3, step 13500/55000, batch loss = 0.00
# epoch 3, step 13750/55000, batch loss = 0.12
# epoch 3, step 14000/55000, batch loss = 0.03
# epoch 3, step 14250/55000, batch loss = 0.02
# epoch 3, step 14500/55000, batch loss = 0.00
# epoch 3, step 14750/55000, batch loss = 0.02
# epoch 3, step 15000/55000, batch loss = 0.09
# Train accuracy = 99.24
# epoch 3, step 15250/55000, batch loss = 0.01
# epoch 3, step 15500/55000, batch loss = 0.03
# epoch 3, step 15750/55000, batch loss = 0.02
# epoch 3, step 16000/55000, batch loss = 0.11
# epoch 3, step 16250/55000, batch loss = 0.03
# epoch 3, step 16500/55000, batch loss = 0.00
# epoch 3, step 16750/55000, batch loss = 0.10
# epoch 3, step 17000/55000, batch loss = 0.01
# epoch 3, step 17250/55000, batch loss = 0.06
# epoch 3, step 17500/55000, batch loss = 0.01
# Train accuracy = 99.23
# epoch 3, step 17750/55000, batch loss = 0.05
# epoch 3, step 18000/55000, batch loss = 0.07
# epoch 3, step 18250/55000, batch loss = 0.00
# epoch 3, step 18500/55000, batch loss = 0.01
# epoch 3, step 18750/55000, batch loss = 0.00
# epoch 3, step 19000/55000, batch loss = 0.01
# epoch 3, step 19250/55000, batch loss = 0.08
# epoch 3, step 19500/55000, batch loss = 0.14
# epoch 3, step 19750/55000, batch loss = 0.00
# epoch 3, step 20000/55000, batch loss = 0.06
# Train accuracy = 99.24
# epoch 3, step 20250/55000, batch loss = 0.00
# epoch 3, step 20500/55000, batch loss = 0.00
# epoch 3, step 20750/55000, batch loss = 0.01
# epoch 3, step 21000/55000, batch loss = 0.00
# epoch 3, step 21250/55000, batch loss = 0.04
# epoch 3, step 21500/55000, batch loss = 0.02
# epoch 3, step 21750/55000, batch loss = 0.02
# epoch 3, step 22000/55000, batch loss = 0.01
# epoch 3, step 22250/55000, batch loss = 0.00
# epoch 3, step 22500/55000, batch loss = 0.01
# Train accuracy = 99.26
# epoch 3, step 22750/55000, batch loss = 0.03
# epoch 3, step 23000/55000, batch loss = 0.01
# epoch 3, step 23250/55000, batch loss = 0.01
# epoch 3, step 23500/55000, batch loss = 0.05
# epoch 3, step 23750/55000, batch loss = 0.01
# epoch 3, step 24000/55000, batch loss = 0.01
# epoch 3, step 24250/55000, batch loss = 0.01
# epoch 3, step 24500/55000, batch loss = 0.01
# epoch 3, step 24750/55000, batch loss = 0.06
# epoch 3, step 25000/55000, batch loss = 0.04
# Train accuracy = 99.29
# epoch 3, step 25250/55000, batch loss = 0.00
# epoch 3, step 25500/55000, batch loss = 0.00
# epoch 3, step 25750/55000, batch loss = 0.05
# epoch 3, step 26000/55000, batch loss = 0.00
# epoch 3, step 26250/55000, batch loss = 0.01
# epoch 3, step 26500/55000, batch loss = 0.08
# epoch 3, step 26750/55000, batch loss = 0.01
# epoch 3, step 27000/55000, batch loss = 0.01
# epoch 3, step 27250/55000, batch loss = 0.01
# epoch 3, step 27500/55000, batch loss = 0.01
# Train accuracy = 99.30
# epoch 3, step 27750/55000, batch loss = 0.01
# epoch 3, step 28000/55000, batch loss = 0.01
# epoch 3, step 28250/55000, batch loss = 0.03
# epoch 3, step 28500/55000, batch loss = 0.00
# epoch 3, step 28750/55000, batch loss = 0.00
# epoch 3, step 29000/55000, batch loss = 0.05
# epoch 3, step 29250/55000, batch loss = 0.03
# epoch 3, step 29500/55000, batch loss = 0.00
# epoch 3, step 29750/55000, batch loss = 0.01
# epoch 3, step 30000/55000, batch loss = 0.04
# Train accuracy = 99.30
# epoch 3, step 30250/55000, batch loss = 0.06
# epoch 3, step 30500/55000, batch loss = 0.01
# epoch 3, step 30750/55000, batch loss = 0.00
# epoch 3, step 31000/55000, batch loss = 0.00
# epoch 3, step 31250/55000, batch loss = 0.00
# epoch 3, step 31500/55000, batch loss = 0.05
# epoch 3, step 31750/55000, batch loss = 0.01
# epoch 3, step 32000/55000, batch loss = 0.00
# epoch 3, step 32250/55000, batch loss = 0.00
# epoch 3, step 32500/55000, batch loss = 0.03
# Train accuracy = 99.27
# epoch 3, step 32750/55000, batch loss = 0.00
# epoch 3, step 33000/55000, batch loss = 0.01
# epoch 3, step 33250/55000, batch loss = 0.09
# epoch 3, step 33500/55000, batch loss = 0.09
# epoch 3, step 33750/55000, batch loss = 0.01
# epoch 3, step 34000/55000, batch loss = 0.01
# epoch 3, step 34250/55000, batch loss = 0.02
# epoch 3, step 34500/55000, batch loss = 0.01
# epoch 3, step 34750/55000, batch loss = 0.04
# epoch 3, step 35000/55000, batch loss = 0.01
# Train accuracy = 99.26
# epoch 3, step 35250/55000, batch loss = 0.00
# epoch 3, step 35500/55000, batch loss = 0.01
# epoch 3, step 35750/55000, batch loss = 0.01
# epoch 3, step 36000/55000, batch loss = 0.02
# epoch 3, step 36250/55000, batch loss = 0.01
# epoch 3, step 36500/55000, batch loss = 0.01
# epoch 3, step 36750/55000, batch loss = 0.00
# epoch 3, step 37000/55000, batch loss = 0.00
# epoch 3, step 37250/55000, batch loss = 0.01
# epoch 3, step 37500/55000, batch loss = 0.05
# Train accuracy = 99.27
# epoch 3, step 37750/55000, batch loss = 0.02
# epoch 3, step 38000/55000, batch loss = 0.06
# epoch 3, step 38250/55000, batch loss = 0.05
# epoch 3, step 38500/55000, batch loss = 0.01
# epoch 3, step 38750/55000, batch loss = 0.02
# epoch 3, step 39000/55000, batch loss = 0.00
# epoch 3, step 39250/55000, batch loss = 0.06
# epoch 3, step 39500/55000, batch loss = 0.04
# epoch 3, step 39750/55000, batch loss = 0.02
# epoch 3, step 40000/55000, batch loss = 0.04
# Train accuracy = 99.27
# epoch 3, step 40250/55000, batch loss = 0.04
# epoch 3, step 40500/55000, batch loss = 0.08
# epoch 3, step 40750/55000, batch loss = 0.01
# epoch 3, step 41000/55000, batch loss = 0.05
# epoch 3, step 41250/55000, batch loss = 0.01
# epoch 3, step 41500/55000, batch loss = 0.00
# epoch 3, step 41750/55000, batch loss = 0.01
# epoch 3, step 42000/55000, batch loss = 0.01
# epoch 3, step 42250/55000, batch loss = 0.01
# epoch 3, step 42500/55000, batch loss = 0.06
# Train accuracy = 99.29
# epoch 3, step 42750/55000, batch loss = 0.00
# epoch 3, step 43000/55000, batch loss = 0.07
# epoch 3, step 43250/55000, batch loss = 0.00
# epoch 3, step 43500/55000, batch loss = 0.01
# epoch 3, step 43750/55000, batch loss = 0.02
# epoch 3, step 44000/55000, batch loss = 0.00
# epoch 3, step 44250/55000, batch loss = 0.00
# epoch 3, step 44500/55000, batch loss = 0.00
# epoch 3, step 44750/55000, batch loss = 0.05
# epoch 3, step 45000/55000, batch loss = 0.00
# Train accuracy = 99.30
# epoch 3, step 45250/55000, batch loss = 0.05
# epoch 3, step 45500/55000, batch loss = 0.02
# epoch 3, step 45750/55000, batch loss = 0.03
# epoch 3, step 46000/55000, batch loss = 0.00
# epoch 3, step 46250/55000, batch loss = 0.06
# epoch 3, step 46500/55000, batch loss = 0.00
# epoch 3, step 46750/55000, batch loss = 0.01
# epoch 3, step 47000/55000, batch loss = 0.01
# epoch 3, step 47250/55000, batch loss = 0.00
# epoch 3, step 47500/55000, batch loss = 0.00
# Train accuracy = 99.31
# epoch 3, step 47750/55000, batch loss = 0.03
# epoch 3, step 48000/55000, batch loss = 0.12
# epoch 3, step 48250/55000, batch loss = 0.00
# epoch 3, step 48500/55000, batch loss = 0.01
# epoch 3, step 48750/55000, batch loss = 0.01
# epoch 3, step 49000/55000, batch loss = 0.00
# epoch 3, step 49250/55000, batch loss = 0.03
# epoch 3, step 49500/55000, batch loss = 0.02
# epoch 3, step 49750/55000, batch loss = 0.01
# epoch 3, step 50000/55000, batch loss = 0.07
# Train accuracy = 99.31
# epoch 3, step 50250/55000, batch loss = 0.02
# epoch 3, step 50500/55000, batch loss = 0.00
# epoch 3, step 50750/55000, batch loss = 0.00
# epoch 3, step 51000/55000, batch loss = 0.01
# epoch 3, step 51250/55000, batch loss = 0.01
# epoch 3, step 51500/55000, batch loss = 0.01
# epoch 3, step 51750/55000, batch loss = 0.02
# epoch 3, step 52000/55000, batch loss = 0.03
# epoch 3, step 52250/55000, batch loss = 0.03
# epoch 3, step 52500/55000, batch loss = 0.00
# Train accuracy = 99.32
# epoch 3, step 52750/55000, batch loss = 0.00
# epoch 3, step 53000/55000, batch loss = 0.00
# epoch 3, step 53250/55000, batch loss = 0.01
# epoch 3, step 53500/55000, batch loss = 0.00
# epoch 3, step 53750/55000, batch loss = 0.05
# epoch 3, step 54000/55000, batch loss = 0.01
# epoch 3, step 54250/55000, batch loss = 0.00
# epoch 3, step 54500/55000, batch loss = 0.03
# epoch 3, step 54750/55000, batch loss = 0.00
# Train accuracy = 99.32
#
# Running evaluation:  Validation
# Validation accuracy = 99.08
# Validation avg loss = 0.03
#
# epoch 4, step 0/55000, batch loss = 0.04
# epoch 4, step 250/55000, batch loss = 0.03
# epoch 4, step 500/55000, batch loss = 0.02
# epoch 4, step 750/55000, batch loss = 0.01
# epoch 4, step 1000/55000, batch loss = 0.02
# epoch 4, step 1250/55000, batch loss = 0.02
# epoch 4, step 1500/55000, batch loss = 0.00
# epoch 4, step 1750/55000, batch loss = 0.00
# epoch 4, step 2000/55000, batch loss = 0.00
# epoch 4, step 2250/55000, batch loss = 0.00
# epoch 4, step 2500/55000, batch loss = 0.00
# Train accuracy = 99.29
# epoch 4, step 2750/55000, batch loss = 0.03
# epoch 4, step 3000/55000, batch loss = 0.00
# epoch 4, step 3250/55000, batch loss = 0.01
# epoch 4, step 3500/55000, batch loss = 0.01
# epoch 4, step 3750/55000, batch loss = 0.00
# epoch 4, step 4000/55000, batch loss = 0.00
# epoch 4, step 4250/55000, batch loss = 0.01
# epoch 4, step 4500/55000, batch loss = 0.04
# epoch 4, step 4750/55000, batch loss = 0.03
# epoch 4, step 5000/55000, batch loss = 0.02
# Train accuracy = 99.43
# epoch 4, step 5250/55000, batch loss = 0.03
# epoch 4, step 5500/55000, batch loss = 0.03
# epoch 4, step 5750/55000, batch loss = 0.00
# epoch 4, step 6000/55000, batch loss = 0.07
# epoch 4, step 6250/55000, batch loss = 0.02
# epoch 4, step 6500/55000, batch loss = 0.00
# epoch 4, step 6750/55000, batch loss = 0.00
# epoch 4, step 7000/55000, batch loss = 0.01
# epoch 4, step 7250/55000, batch loss = 0.01
# epoch 4, step 7500/55000, batch loss = 0.00
# Train accuracy = 99.44
# epoch 4, step 7750/55000, batch loss = 0.01
# epoch 4, step 8000/55000, batch loss = 0.00
# epoch 4, step 8250/55000, batch loss = 0.06
# epoch 4, step 8500/55000, batch loss = 0.00
# epoch 4, step 8750/55000, batch loss = 0.09
# epoch 4, step 9000/55000, batch loss = 0.15
# epoch 4, step 9250/55000, batch loss = 0.07
# epoch 4, step 9500/55000, batch loss = 0.02
# epoch 4, step 9750/55000, batch loss = 0.00
# epoch 4, step 10000/55000, batch loss = 0.01
# Train accuracy = 99.41
# epoch 4, step 10250/55000, batch loss = 0.00
# epoch 4, step 10500/55000, batch loss = 0.03
# epoch 4, step 10750/55000, batch loss = 0.01
# epoch 4, step 11000/55000, batch loss = 0.01
# epoch 4, step 11250/55000, batch loss = 0.00
# epoch 4, step 11500/55000, batch loss = 0.02
# epoch 4, step 11750/55000, batch loss = 0.00
# epoch 4, step 12000/55000, batch loss = 0.00
# epoch 4, step 12250/55000, batch loss = 0.00
# epoch 4, step 12500/55000, batch loss = 0.00
# Train accuracy = 99.42
# epoch 4, step 12750/55000, batch loss = 0.03
# epoch 4, step 13000/55000, batch loss = 0.01
# epoch 4, step 13250/55000, batch loss = 0.02
# epoch 4, step 13500/55000, batch loss = 0.01
# epoch 4, step 13750/55000, batch loss = 0.01
# epoch 4, step 14000/55000, batch loss = 0.08
# epoch 4, step 14250/55000, batch loss = 0.05
# epoch 4, step 14500/55000, batch loss = 0.00
# epoch 4, step 14750/55000, batch loss = 0.04
# epoch 4, step 15000/55000, batch loss = 0.04
# Train accuracy = 99.42
# epoch 4, step 15250/55000, batch loss = 0.01
# epoch 4, step 15500/55000, batch loss = 0.02
# epoch 4, step 15750/55000, batch loss = 0.03
# epoch 4, step 16000/55000, batch loss = 0.00
# epoch 4, step 16250/55000, batch loss = 0.02
# epoch 4, step 16500/55000, batch loss = 0.01
# epoch 4, step 16750/55000, batch loss = 0.00
# epoch 4, step 17000/55000, batch loss = 0.00
# epoch 4, step 17250/55000, batch loss = 0.00
# epoch 4, step 17500/55000, batch loss = 0.01
# Train accuracy = 99.42
# epoch 4, step 17750/55000, batch loss = 0.01
# epoch 4, step 18000/55000, batch loss = 0.00
# epoch 4, step 18250/55000, batch loss = 0.01
# epoch 4, step 18500/55000, batch loss = 0.10
# epoch 4, step 18750/55000, batch loss = 0.04
# epoch 4, step 19000/55000, batch loss = 0.09
# epoch 4, step 19250/55000, batch loss = 0.01
# epoch 4, step 19500/55000, batch loss = 0.00
# epoch 4, step 19750/55000, batch loss = 0.14
# epoch 4, step 20000/55000, batch loss = 0.01
# Train accuracy = 99.39
# epoch 4, step 20250/55000, batch loss = 0.07
# epoch 4, step 20500/55000, batch loss = 0.00
# epoch 4, step 20750/55000, batch loss = 0.00
# epoch 4, step 21000/55000, batch loss = 0.08
# epoch 4, step 21250/55000, batch loss = 0.04
# epoch 4, step 21500/55000, batch loss = 0.02
# epoch 4, step 21750/55000, batch loss = 0.13
# epoch 4, step 22000/55000, batch loss = 0.02
# epoch 4, step 22250/55000, batch loss = 0.01
# epoch 4, step 22500/55000, batch loss = 0.01
# Train accuracy = 99.40
# epoch 4, step 22750/55000, batch loss = 0.14
# epoch 4, step 23000/55000, batch loss = 0.00
# epoch 4, step 23250/55000, batch loss = 0.00
# epoch 4, step 23500/55000, batch loss = 0.07
# epoch 4, step 23750/55000, batch loss = 0.01
# epoch 4, step 24000/55000, batch loss = 0.01
# epoch 4, step 24250/55000, batch loss = 0.01
# epoch 4, step 24500/55000, batch loss = 0.03
# epoch 4, step 24750/55000, batch loss = 0.01
# epoch 4, step 25000/55000, batch loss = 0.03
# Train accuracy = 99.42
# epoch 4, step 25250/55000, batch loss = 0.01
# epoch 4, step 25500/55000, batch loss = 0.01
# epoch 4, step 25750/55000, batch loss = 0.01
# epoch 4, step 26000/55000, batch loss = 0.01
# epoch 4, step 26250/55000, batch loss = 0.01
# epoch 4, step 26500/55000, batch loss = 0.11
# epoch 4, step 26750/55000, batch loss = 0.00
# epoch 4, step 27000/55000, batch loss = 0.01
# epoch 4, step 27250/55000, batch loss = 0.00
# epoch 4, step 27500/55000, batch loss = 0.04
# Train accuracy = 99.43
# epoch 4, step 27750/55000, batch loss = 0.02
# epoch 4, step 28000/55000, batch loss = 0.02
# epoch 4, step 28250/55000, batch loss = 0.02
# epoch 4, step 28500/55000, batch loss = 0.06
# epoch 4, step 28750/55000, batch loss = 0.01
# epoch 4, step 29000/55000, batch loss = 0.01
# epoch 4, step 29250/55000, batch loss = 0.11
# epoch 4, step 29500/55000, batch loss = 0.00
# epoch 4, step 29750/55000, batch loss = 0.00
# epoch 4, step 30000/55000, batch loss = 0.00
# Train accuracy = 99.42
# epoch 4, step 30250/55000, batch loss = 0.01
# epoch 4, step 30500/55000, batch loss = 0.03
# epoch 4, step 30750/55000, batch loss = 0.01
# epoch 4, step 31000/55000, batch loss = 0.02
# epoch 4, step 31250/55000, batch loss = 0.01
# epoch 4, step 31500/55000, batch loss = 0.00
# epoch 4, step 31750/55000, batch loss = 0.00
# epoch 4, step 32000/55000, batch loss = 0.00
# epoch 4, step 32250/55000, batch loss = 0.04
# epoch 4, step 32500/55000, batch loss = 0.01
# Train accuracy = 99.43
# epoch 4, step 32750/55000, batch loss = 0.11
# epoch 4, step 33000/55000, batch loss = 0.00
# epoch 4, step 33250/55000, batch loss = 0.02
# epoch 4, step 33500/55000, batch loss = 0.07
# epoch 4, step 33750/55000, batch loss = 0.01
# epoch 4, step 34000/55000, batch loss = 0.00
# epoch 4, step 34250/55000, batch loss = 0.03
# epoch 4, step 34500/55000, batch loss = 0.01
# epoch 4, step 34750/55000, batch loss = 0.02
# epoch 4, step 35000/55000, batch loss = 0.14
# Train accuracy = 99.43
# epoch 4, step 35250/55000, batch loss = 0.15
# epoch 4, step 35500/55000, batch loss = 0.13
# epoch 4, step 35750/55000, batch loss = 0.02
# epoch 4, step 36000/55000, batch loss = 0.01
# epoch 4, step 36250/55000, batch loss = 0.00
# epoch 4, step 36500/55000, batch loss = 0.00
# epoch 4, step 36750/55000, batch loss = 0.01
# epoch 4, step 37000/55000, batch loss = 0.01
# epoch 4, step 37250/55000, batch loss = 0.01
# epoch 4, step 37500/55000, batch loss = 0.01
# Train accuracy = 99.42
# epoch 4, step 37750/55000, batch loss = 0.00
# epoch 4, step 38000/55000, batch loss = 0.02
# epoch 4, step 38250/55000, batch loss = 0.03
# epoch 4, step 38500/55000, batch loss = 0.00
# epoch 4, step 38750/55000, batch loss = 0.01
# epoch 4, step 39000/55000, batch loss = 0.01
# epoch 4, step 39250/55000, batch loss = 0.00
# epoch 4, step 39500/55000, batch loss = 0.03
# epoch 4, step 39750/55000, batch loss = 0.00
# epoch 4, step 40000/55000, batch loss = 0.00
# Train accuracy = 99.43
# epoch 4, step 40250/55000, batch loss = 0.02
# epoch 4, step 40500/55000, batch loss = 0.04
# epoch 4, step 40750/55000, batch loss = 0.05
# epoch 4, step 41000/55000, batch loss = 0.00
# epoch 4, step 41250/55000, batch loss = 0.01
# epoch 4, step 41500/55000, batch loss = 0.00
# epoch 4, step 41750/55000, batch loss = 0.00
# epoch 4, step 42000/55000, batch loss = 0.00
# epoch 4, step 42250/55000, batch loss = 0.01
# epoch 4, step 42500/55000, batch loss = 0.01
# Train accuracy = 99.42
# epoch 4, step 42750/55000, batch loss = 0.01
# epoch 4, step 43000/55000, batch loss = 0.00
# epoch 4, step 43250/55000, batch loss = 0.01
# epoch 4, step 43500/55000, batch loss = 0.01
# epoch 4, step 43750/55000, batch loss = 0.01
# epoch 4, step 44000/55000, batch loss = 0.02
# epoch 4, step 44250/55000, batch loss = 0.00
# epoch 4, step 44500/55000, batch loss = 0.02
# epoch 4, step 44750/55000, batch loss = 0.00
# epoch 4, step 45000/55000, batch loss = 0.01
# Train accuracy = 99.41
# epoch 4, step 45250/55000, batch loss = 0.00
# epoch 4, step 45500/55000, batch loss = 0.00
# epoch 4, step 45750/55000, batch loss = 0.04
# epoch 4, step 46000/55000, batch loss = 0.03
# epoch 4, step 46250/55000, batch loss = 0.02
# epoch 4, step 46500/55000, batch loss = 0.01
# epoch 4, step 46750/55000, batch loss = 0.01
# epoch 4, step 47000/55000, batch loss = 0.09
# epoch 4, step 47250/55000, batch loss = 0.10
# epoch 4, step 47500/55000, batch loss = 0.01
# Train accuracy = 99.41
# epoch 4, step 47750/55000, batch loss = 0.05
# epoch 4, step 48000/55000, batch loss = 0.05
# epoch 4, step 48250/55000, batch loss = 0.02
# epoch 4, step 48500/55000, batch loss = 0.00
# epoch 4, step 48750/55000, batch loss = 0.01
# epoch 4, step 49000/55000, batch loss = 0.01
# epoch 4, step 49250/55000, batch loss = 0.01
# epoch 4, step 49500/55000, batch loss = 0.01
# epoch 4, step 49750/55000, batch loss = 0.01
# epoch 4, step 50000/55000, batch loss = 0.00
# Train accuracy = 99.41
# epoch 4, step 50250/55000, batch loss = 0.01
# epoch 4, step 50500/55000, batch loss = 0.01
# epoch 4, step 50750/55000, batch loss = 0.06
# epoch 4, step 51000/55000, batch loss = 0.00
# epoch 4, step 51250/55000, batch loss = 0.00
# epoch 4, step 51500/55000, batch loss = 0.01
# epoch 4, step 51750/55000, batch loss = 0.00
# epoch 4, step 52000/55000, batch loss = 0.00
# epoch 4, step 52250/55000, batch loss = 0.01
# epoch 4, step 52500/55000, batch loss = 0.01
# Train accuracy = 99.42
# epoch 4, step 52750/55000, batch loss = 0.01
# epoch 4, step 53000/55000, batch loss = 0.04
# epoch 4, step 53250/55000, batch loss = 0.01
# epoch 4, step 53500/55000, batch loss = 0.00
# epoch 4, step 53750/55000, batch loss = 0.00
# epoch 4, step 54000/55000, batch loss = 0.09
# epoch 4, step 54250/55000, batch loss = 0.01
# epoch 4, step 54500/55000, batch loss = 0.02
# epoch 4, step 54750/55000, batch loss = 0.00
# Train accuracy = 99.42
#
# Running evaluation:  Validation
# Validation accuracy = 99.08
# Validation avg loss = 0.03
#
# epoch 5, step 0/55000, batch loss = 0.02
# epoch 5, step 250/55000, batch loss = 0.01
# epoch 5, step 500/55000, batch loss = 0.01
# epoch 5, step 750/55000, batch loss = 0.00
# epoch 5, step 1000/55000, batch loss = 0.00
# epoch 5, step 1250/55000, batch loss = 0.01
# epoch 5, step 1500/55000, batch loss = 0.00
# epoch 5, step 1750/55000, batch loss = 0.00
# epoch 5, step 2000/55000, batch loss = 0.00
# epoch 5, step 2250/55000, batch loss = 0.01
# epoch 5, step 2500/55000, batch loss = 0.01
# Train accuracy = 99.53
# epoch 5, step 2750/55000, batch loss = 0.01
# epoch 5, step 3000/55000, batch loss = 0.01
# epoch 5, step 3250/55000, batch loss = 0.01
# epoch 5, step 3500/55000, batch loss = 0.03
# epoch 5, step 3750/55000, batch loss = 0.01
# epoch 5, step 4000/55000, batch loss = 0.03
# epoch 5, step 4250/55000, batch loss = 0.00
# epoch 5, step 4500/55000, batch loss = 0.00
# epoch 5, step 4750/55000, batch loss = 0.03
# epoch 5, step 5000/55000, batch loss = 0.02
# Train accuracy = 99.45
# epoch 5, step 5250/55000, batch loss = 0.01
# epoch 5, step 5500/55000, batch loss = 0.01
# epoch 5, step 5750/55000, batch loss = 0.03
# epoch 5, step 6000/55000, batch loss = 0.03
# epoch 5, step 6250/55000, batch loss = 0.01
# epoch 5, step 6500/55000, batch loss = 0.00
# epoch 5, step 6750/55000, batch loss = 0.02
# epoch 5, step 7000/55000, batch loss = 0.02
# epoch 5, step 7250/55000, batch loss = 0.01
# epoch 5, step 7500/55000, batch loss = 0.00
# Train accuracy = 99.47
# epoch 5, step 7750/55000, batch loss = 0.00
# epoch 5, step 8000/55000, batch loss = 0.01
# epoch 5, step 8250/55000, batch loss = 0.01
# epoch 5, step 8500/55000, batch loss = 0.04
# epoch 5, step 8750/55000, batch loss = 0.01
# epoch 5, step 9000/55000, batch loss = 0.01
# epoch 5, step 9250/55000, batch loss = 0.00
# epoch 5, step 9500/55000, batch loss = 0.01
# epoch 5, step 9750/55000, batch loss = 0.03
# epoch 5, step 10000/55000, batch loss = 0.06
# Train accuracy = 99.47
# epoch 5, step 10250/55000, batch loss = 0.03
# epoch 5, step 10500/55000, batch loss = 0.00
# epoch 5, step 10750/55000, batch loss = 0.00
# epoch 5, step 11000/55000, batch loss = 0.00
# epoch 5, step 11250/55000, batch loss = 0.00
# epoch 5, step 11500/55000, batch loss = 0.02
# epoch 5, step 11750/55000, batch loss = 0.04
# epoch 5, step 12000/55000, batch loss = 0.01
# epoch 5, step 12250/55000, batch loss = 0.00
# epoch 5, step 12500/55000, batch loss = 0.05
# Train accuracy = 99.51
# epoch 5, step 12750/55000, batch loss = 0.00
# epoch 5, step 13000/55000, batch loss = 0.02
# epoch 5, step 13250/55000, batch loss = 0.00
# epoch 5, step 13500/55000, batch loss = 0.00
# epoch 5, step 13750/55000, batch loss = 0.01
# epoch 5, step 14000/55000, batch loss = 0.00
# epoch 5, step 14250/55000, batch loss = 0.00
# epoch 5, step 14500/55000, batch loss = 0.00
# epoch 5, step 14750/55000, batch loss = 0.02
# epoch 5, step 15000/55000, batch loss = 0.15
# Train accuracy = 99.48
# epoch 5, step 15250/55000, batch loss = 0.02
# epoch 5, step 15500/55000, batch loss = 0.00
# epoch 5, step 15750/55000, batch loss = 0.02
# epoch 5, step 16000/55000, batch loss = 0.01
# epoch 5, step 16250/55000, batch loss = 0.01
# epoch 5, step 16500/55000, batch loss = 0.01
# epoch 5, step 16750/55000, batch loss = 0.00
# epoch 5, step 17000/55000, batch loss = 0.00
# epoch 5, step 17250/55000, batch loss = 0.03
# epoch 5, step 17500/55000, batch loss = 0.00
# Train accuracy = 99.51
# epoch 5, step 17750/55000, batch loss = 0.04
# epoch 5, step 18000/55000, batch loss = 0.01
# epoch 5, step 18250/55000, batch loss = 0.02
# epoch 5, step 18500/55000, batch loss = 0.02
# epoch 5, step 18750/55000, batch loss = 0.02
# epoch 5, step 19000/55000, batch loss = 0.00
# epoch 5, step 19250/55000, batch loss = 0.00
# epoch 5, step 19500/55000, batch loss = 0.00
# epoch 5, step 19750/55000, batch loss = 0.00
# epoch 5, step 20000/55000, batch loss = 0.02
# Train accuracy = 99.53
# epoch 5, step 20250/55000, batch loss = 0.00
# epoch 5, step 20500/55000, batch loss = 0.02
# epoch 5, step 20750/55000, batch loss = 0.01
# epoch 5, step 21000/55000, batch loss = 0.01
# epoch 5, step 21250/55000, batch loss = 0.00
# epoch 5, step 21500/55000, batch loss = 0.02
# epoch 5, step 21750/55000, batch loss = 0.15
# epoch 5, step 22000/55000, batch loss = 0.02
# epoch 5, step 22250/55000, batch loss = 0.01
# epoch 5, step 22500/55000, batch loss = 0.01
# Train accuracy = 99.53
# epoch 5, step 22750/55000, batch loss = 0.00
# epoch 5, step 23000/55000, batch loss = 0.01
# epoch 5, step 23250/55000, batch loss = 0.01
# epoch 5, step 23500/55000, batch loss = 0.06
# epoch 5, step 23750/55000, batch loss = 0.00
# epoch 5, step 24000/55000, batch loss = 0.02
# epoch 5, step 24250/55000, batch loss = 0.13
# epoch 5, step 24500/55000, batch loss = 0.03
# epoch 5, step 24750/55000, batch loss = 0.04
# epoch 5, step 25000/55000, batch loss = 0.03
# Train accuracy = 99.52
# epoch 5, step 25250/55000, batch loss = 0.02
# epoch 5, step 25500/55000, batch loss = 0.01
# epoch 5, step 25750/55000, batch loss = 0.05
# epoch 5, step 26000/55000, batch loss = 0.01
# epoch 5, step 26250/55000, batch loss = 0.01
# epoch 5, step 26500/55000, batch loss = 0.01
# epoch 5, step 26750/55000, batch loss = 0.17
# epoch 5, step 27000/55000, batch loss = 0.02
# epoch 5, step 27250/55000, batch loss = 0.00
# epoch 5, step 27500/55000, batch loss = 0.00
# Train accuracy = 99.47
# epoch 5, step 27750/55000, batch loss = 0.00
# epoch 5, step 28000/55000, batch loss = 0.00
# epoch 5, step 28250/55000, batch loss = 0.02
# epoch 5, step 28500/55000, batch loss = 0.01
# epoch 5, step 28750/55000, batch loss = 0.01
# epoch 5, step 29000/55000, batch loss = 0.00
# epoch 5, step 29250/55000, batch loss = 0.00
# epoch 5, step 29500/55000, batch loss = 0.01
# epoch 5, step 29750/55000, batch loss = 0.00
# epoch 5, step 30000/55000, batch loss = 0.00
# Train accuracy = 99.50
# epoch 5, step 30250/55000, batch loss = 0.09
# epoch 5, step 30500/55000, batch loss = 0.01
# epoch 5, step 30750/55000, batch loss = 0.04
# epoch 5, step 31000/55000, batch loss = 0.00
# epoch 5, step 31250/55000, batch loss = 0.00
# epoch 5, step 31500/55000, batch loss = 0.00
# epoch 5, step 31750/55000, batch loss = 0.00
# epoch 5, step 32000/55000, batch loss = 0.04
# epoch 5, step 32250/55000, batch loss = 0.01
# epoch 5, step 32500/55000, batch loss = 0.01
# Train accuracy = 99.48
# epoch 5, step 32750/55000, batch loss = 0.08
# ...
# epoch 7, step 26750/55000, batch loss = 0.05
# epoch 7, step 27000/55000, batch loss = 0.01
# epoch 7, step 27250/55000, batch loss = 0.00
# epoch 7, step 27500/55000, batch loss = 0.00
# Train accuracy = 99.52
# epoch 7, step 27750/55000, batch loss = 0.04
# epoch 7, step 28000/55000, batch loss = 0.00
# epoch 7, step 28250/55000, batch loss = 0.01
# epoch 7, step 28500/55000, batch loss = 0.01
# epoch 7, step 28750/55000, batch loss = 0.03
# epoch 7, step 29000/55000, batch loss = 0.00
# epoch 7, step 29250/55000, batch loss = 0.01
# epoch 7, step 29500/55000, batch loss = 0.00
# epoch 7, step 29750/55000, batch loss = 0.00
# epoch 7, step 30000/55000, batch loss = 0.04
# Train accuracy = 99.52
# epoch 7, step 30250/55000, batch loss = 0.01
# epoch 7, step 30500/55000, batch loss = 0.02
# epoch 7, step 30750/55000, batch loss = 0.01
# epoch 7, step 31000/55000, batch loss = 0.00
# epoch 7, step 31250/55000, batch loss = 0.01
# epoch 7, step 31500/55000, batch loss = 0.02
# epoch 7, step 31750/55000, batch loss = 0.01
# epoch 7, step 32000/55000, batch loss = 0.02
# epoch 7, step 32250/55000, batch loss = 0.00
# epoch 7, step 32500/55000, batch loss = 0.02
# Train accuracy = 99.53
# epoch 7, step 32750/55000, batch loss = 0.02
# epoch 7, step 33000/55000, batch loss = 0.05
# epoch 7, step 33250/55000, batch loss = 0.02
# epoch 7, step 33500/55000, batch loss = 0.01
# epoch 7, step 33750/55000, batch loss = 0.01
# epoch 7, step 34000/55000, batch loss = 0.00
# epoch 7, step 34250/55000, batch loss = 0.02
# epoch 7, step 34500/55000, batch loss = 0.00
# epoch 7, step 34750/55000, batch loss = 0.14
# epoch 7, step 35000/55000, batch loss = 0.03
# Train accuracy = 99.53
# epoch 7, step 35250/55000, batch loss = 0.00
# epoch 7, step 35500/55000, batch loss = 0.04
# epoch 7, step 35750/55000, batch loss = 0.01
# epoch 7, step 36000/55000, batch loss = 0.01
# epoch 7, step 36250/55000, batch loss = 0.00
# epoch 7, step 36500/55000, batch loss = 0.07
# epoch 7, step 36750/55000, batch loss = 0.00
# epoch 7, step 37000/55000, batch loss = 0.01
# epoch 7, step 37250/55000, batch loss = 0.00
# epoch 7, step 37500/55000, batch loss = 0.01
# Train accuracy = 99.53
# epoch 7, step 37750/55000, batch loss = 0.00
# epoch 7, step 38000/55000, batch loss = 0.00
# epoch 7, step 38250/55000, batch loss = 0.00
# epoch 7, step 38500/55000, batch loss = 0.01
# epoch 7, step 38750/55000, batch loss = 0.02
# epoch 7, step 39000/55000, batch loss = 0.03
# epoch 7, step 39250/55000, batch loss = 0.03
# epoch 7, step 39500/55000, batch loss = 0.00
# epoch 7, step 39750/55000, batch loss = 0.00
# epoch 7, step 40000/55000, batch loss = 0.00
# Train accuracy = 99.53
# epoch 7, step 40250/55000, batch loss = 0.02
# epoch 7, step 40500/55000, batch loss = 0.00
# epoch 7, step 40750/55000, batch loss = 0.00
# epoch 7, step 41000/55000, batch loss = 0.02
# epoch 7, step 41250/55000, batch loss = 0.00
# epoch 7, step 41500/55000, batch loss = 0.00
# epoch 7, step 41750/55000, batch loss = 0.00
# epoch 7, step 42000/55000, batch loss = 0.00
# epoch 7, step 42250/55000, batch loss = 0.02
# epoch 7, step 42500/55000, batch loss = 0.00
# Train accuracy = 99.52
# epoch 7, step 42750/55000, batch loss = 0.02
# epoch 7, step 43000/55000, batch loss = 0.00
# epoch 7, step 43250/55000, batch loss = 0.01
# epoch 7, step 43500/55000, batch loss = 0.02
# epoch 7, step 43750/55000, batch loss = 0.02
# epoch 7, step 44000/55000, batch loss = 0.01
# epoch 7, step 44250/55000, batch loss = 0.02
# epoch 7, step 44500/55000, batch loss = 0.00
# epoch 7, step 44750/55000, batch loss = 0.02
# epoch 7, step 45000/55000, batch loss = 0.00
# Train accuracy = 99.53
# epoch 7, step 45250/55000, batch loss = 0.01
# epoch 7, step 45500/55000, batch loss = 0.12
# epoch 7, step 45750/55000, batch loss = 0.01
# epoch 7, step 46000/55000, batch loss = 0.00
# epoch 7, step 46250/55000, batch loss = 0.01
# epoch 7, step 46500/55000, batch loss = 0.01
# epoch 7, step 46750/55000, batch loss = 0.09
# epoch 7, step 47000/55000, batch loss = 0.01
# epoch 7, step 47250/55000, batch loss = 0.01
# epoch 7, step 47500/55000, batch loss = 0.00
# Train accuracy = 99.52
# epoch 7, step 47750/55000, batch loss = 0.00
# epoch 7, step 48000/55000, batch loss = 0.03
# epoch 7, step 48250/55000, batch loss = 0.00
# epoch 7, step 48500/55000, batch loss = 0.01
# epoch 7, step 48750/55000, batch loss = 0.00
# epoch 7, step 49000/55000, batch loss = 0.01
# epoch 7, step 49250/55000, batch loss = 0.00
# epoch 7, step 49500/55000, batch loss = 0.11
# epoch 7, step 49750/55000, batch loss = 0.01
# epoch 7, step 50000/55000, batch loss = 0.00
# Train accuracy = 99.53
# epoch 7, step 50250/55000, batch loss = 0.01
# epoch 7, step 50500/55000, batch loss = 0.00
# epoch 7, step 50750/55000, batch loss = 0.00
# epoch 7, step 51000/55000, batch loss = 0.01
# epoch 7, step 51250/55000, batch loss = 0.11
# epoch 7, step 51500/55000, batch loss = 0.01
# epoch 7, step 51750/55000, batch loss = 0.00
# epoch 7, step 52000/55000, batch loss = 0.00
# epoch 7, step 52250/55000, batch loss = 0.01
# epoch 7, step 52500/55000, batch loss = 0.04
# Train accuracy = 99.53
# epoch 7, step 52750/55000, batch loss = 0.00
# epoch 7, step 53000/55000, batch loss = 0.00
# epoch 7, step 53250/55000, batch loss = 0.01
# epoch 7, step 53500/55000, batch loss = 0.00
# epoch 7, step 53750/55000, batch loss = 0.00
# epoch 7, step 54000/55000, batch loss = 0.02
# epoch 7, step 54250/55000, batch loss = 0.09
# epoch 7, step 54500/55000, batch loss = 0.01
# epoch 7, step 54750/55000, batch loss = 0.01
# Train accuracy = 99.53
#
# Running evaluation:  Validation
# Validation accuracy = 99.16
# Validation avg loss = 0.03
#
# epoch 8, step 0/55000, batch loss = 0.01
# epoch 8, step 250/55000, batch loss = 0.02
# epoch 8, step 500/55000, batch loss = 0.00
# epoch 8, step 750/55000, batch loss = 0.00
# epoch 8, step 1000/55000, batch loss = 0.01
# epoch 8, step 1250/55000, batch loss = 0.01
# epoch 8, step 1500/55000, batch loss = 0.01
# epoch 8, step 1750/55000, batch loss = 0.01
# epoch 8, step 2000/55000, batch loss = 0.01
# epoch 8, step 2250/55000, batch loss = 0.04
# epoch 8, step 2500/55000, batch loss = 0.03
# Train accuracy = 99.41
# epoch 8, step 2750/55000, batch loss = 0.01
# epoch 8, step 3000/55000, batch loss = 0.01
# epoch 8, step 3250/55000, batch loss = 0.06
# epoch 8, step 3500/55000, batch loss = 0.01
# epoch 8, step 3750/55000, batch loss = 0.00
# epoch 8, step 4000/55000, batch loss = 0.00
# epoch 8, step 4250/55000, batch loss = 0.00
# epoch 8, step 4500/55000, batch loss = 0.03
# epoch 8, step 4750/55000, batch loss = 0.01
# epoch 8, step 5000/55000, batch loss = 0.01
# Train accuracy = 99.54
# epoch 8, step 5250/55000, batch loss = 0.00
# epoch 8, step 5500/55000, batch loss = 0.00
# epoch 8, step 5750/55000, batch loss = 0.02
# epoch 8, step 6000/55000, batch loss = 0.00
# epoch 8, step 6250/55000, batch loss = 0.00
# epoch 8, step 6500/55000, batch loss = 0.00
# epoch 8, step 6750/55000, batch loss = 0.00
# epoch 8, step 7000/55000, batch loss = 0.01
# epoch 8, step 7250/55000, batch loss = 0.01
# epoch 8, step 7500/55000, batch loss = 0.02
# Train accuracy = 99.54
# epoch 8, step 7750/55000, batch loss = 0.01
# epoch 8, step 8000/55000, batch loss = 0.01
# epoch 8, step 8250/55000, batch loss = 0.02
# epoch 8, step 8500/55000, batch loss = 0.03
# epoch 8, step 8750/55000, batch loss = 0.00
# epoch 8, step 9000/55000, batch loss = 0.01
# epoch 8, step 9250/55000, batch loss = 0.01
# epoch 8, step 9500/55000, batch loss = 0.01
# epoch 8, step 9750/55000, batch loss = 0.06
# epoch 8, step 10000/55000, batch loss = 0.01
# Train accuracy = 99.52
# epoch 8, step 10250/55000, batch loss = 0.03
# epoch 8, step 10500/55000, batch loss = 0.01
# epoch 8, step 10750/55000, batch loss = 0.01
# epoch 8, step 11000/55000, batch loss = 0.05
# epoch 8, step 11250/55000, batch loss = 0.02
# epoch 8, step 11500/55000, batch loss = 0.00
# epoch 8, step 11750/55000, batch loss = 0.01
# epoch 8, step 12000/55000, batch loss = 0.02
# epoch 8, step 12250/55000, batch loss = 0.01
# epoch 8, step 12500/55000, batch loss = 0.00
# Train accuracy = 99.49
# epoch 8, step 12750/55000, batch loss = 0.00
# epoch 8, step 13000/55000, batch loss = 0.01
# epoch 8, step 13250/55000, batch loss = 0.03
# epoch 8, step 13500/55000, batch loss = 0.06
# epoch 8, step 13750/55000, batch loss = 0.02
# epoch 8, step 14000/55000, batch loss = 0.01
# epoch 8, step 14250/55000, batch loss = 0.01
# epoch 8, step 14500/55000, batch loss = 0.10
# epoch 8, step 14750/55000, batch loss = 0.01
# epoch 8, step 15000/55000, batch loss = 0.00
# Train accuracy = 99.51
# epoch 8, step 15250/55000, batch loss = 0.01
# epoch 8, step 15500/55000, batch loss = 0.03
# epoch 8, step 15750/55000, batch loss = 0.01
# epoch 8, step 16000/55000, batch loss = 0.00
# epoch 8, step 16250/55000, batch loss = 0.00
# epoch 8, step 16500/55000, batch loss = 0.00
# epoch 8, step 16750/55000, batch loss = 0.04
# epoch 8, step 17000/55000, batch loss = 0.00
# epoch 8, step 17250/55000, batch loss = 0.00
# epoch 8, step 17500/55000, batch loss = 0.00
# Train accuracy = 99.51
# epoch 8, step 17750/55000, batch loss = 0.00
# epoch 8, step 18000/55000, batch loss = 0.02
# epoch 8, step 18250/55000, batch loss = 0.02
# epoch 8, step 18500/55000, batch loss = 0.02
# epoch 8, step 18750/55000, batch loss = 0.06
# epoch 8, step 19000/55000, batch loss = 0.00
# epoch 8, step 19250/55000, batch loss = 0.00
# epoch 8, step 19500/55000, batch loss = 0.00
# epoch 8, step 19750/55000, batch loss = 0.01
# epoch 8, step 20000/55000, batch loss = 0.03
# Train accuracy = 99.52
# epoch 8, step 20250/55000, batch loss = 0.00
# epoch 8, step 20500/55000, batch loss = 0.01
# epoch 8, step 20750/55000, batch loss = 0.00
# epoch 8, step 21000/55000, batch loss = 0.03
# epoch 8, step 21250/55000, batch loss = 0.00
# epoch 8, step 21500/55000, batch loss = 0.10
# epoch 8, step 21750/55000, batch loss = 0.00
# epoch 8, step 22000/55000, batch loss = 0.01
# epoch 8, step 22250/55000, batch loss = 0.01
# epoch 8, step 22500/55000, batch loss = 0.00
# Train accuracy = 99.52
# epoch 8, step 22750/55000, batch loss = 0.00
# epoch 8, step 23000/55000, batch loss = 0.09
# epoch 8, step 23250/55000, batch loss = 0.02
# epoch 8, step 23500/55000, batch loss = 0.00
# epoch 8, step 23750/55000, batch loss = 0.00
# epoch 8, step 24000/55000, batch loss = 0.00
# epoch 8, step 24250/55000, batch loss = 0.04
# epoch 8, step 24500/55000, batch loss = 0.03
# epoch 8, step 24750/55000, batch loss = 0.00
# epoch 8, step 25000/55000, batch loss = 0.01
# Train accuracy = 99.54
# epoch 8, step 25250/55000, batch loss = 0.00
# epoch 8, step 25500/55000, batch loss = 0.00
# epoch 8, step 25750/55000, batch loss = 0.00
# epoch 8, step 26000/55000, batch loss = 0.01
# epoch 8, step 26250/55000, batch loss = 0.00
# epoch 8, step 26500/55000, batch loss = 0.02
# epoch 8, step 26750/55000, batch loss = 0.12
# epoch 8, step 27000/55000, batch loss = 0.02
# epoch 8, step 27250/55000, batch loss = 0.19
# epoch 8, step 27500/55000, batch loss = 0.00
# Train accuracy = 99.52
# epoch 8, step 27750/55000, batch loss = 0.00
# epoch 8, step 28000/55000, batch loss = 0.02
# epoch 8, step 28250/55000, batch loss = 0.01
# epoch 8, step 28500/55000, batch loss = 0.00
# epoch 8, step 28750/55000, batch loss = 0.00
# epoch 8, step 29000/55000, batch loss = 0.08
# epoch 8, step 29250/55000, batch loss = 0.01
# epoch 8, step 29500/55000, batch loss = 0.00
# epoch 8, step 29750/55000, batch loss = 0.02
# epoch 8, step 30000/55000, batch loss = 0.00
# Train accuracy = 99.53
# epoch 8, step 30250/55000, batch loss = 0.00
# epoch 8, step 30500/55000, batch loss = 0.03
# epoch 8, step 30750/55000, batch loss = 0.02
# epoch 8, step 31000/55000, batch loss = 0.02
# epoch 8, step 31250/55000, batch loss = 0.01
# epoch 8, step 31500/55000, batch loss = 0.00
# epoch 8, step 31750/55000, batch loss = 0.00
# epoch 8, step 32000/55000, batch loss = 0.02
# epoch 8, step 32250/55000, batch loss = 0.01
# epoch 8, step 32500/55000, batch loss = 0.01
# Train accuracy = 99.54
# epoch 8, step 32750/55000, batch loss = 0.00
# epoch 8, step 33000/55000, batch loss = 0.01
# epoch 8, step 33250/55000, batch loss = 0.03
# epoch 8, step 33500/55000, batch loss = 0.03
# epoch 8, step 33750/55000, batch loss = 0.01
# epoch 8, step 34000/55000, batch loss = 0.03
# epoch 8, step 34250/55000, batch loss = 0.01
# epoch 8, step 34500/55000, batch loss = 0.06
# epoch 8, step 34750/55000, batch loss = 0.05
# epoch 8, step 35000/55000, batch loss = 0.00
# Train accuracy = 99.53
# epoch 8, step 35250/55000, batch loss = 0.02
# epoch 8, step 35500/55000, batch loss = 0.00
# epoch 8, step 35750/55000, batch loss = 0.01
# epoch 8, step 36000/55000, batch loss = 0.01
# epoch 8, step 36250/55000, batch loss = 0.00
# epoch 8, step 36500/55000, batch loss = 0.01
# epoch 8, step 36750/55000, batch loss = 0.03
# epoch 8, step 37000/55000, batch loss = 0.02
# epoch 8, step 37250/55000, batch loss = 0.02
# epoch 8, step 37500/55000, batch loss = 0.00
# Train accuracy = 99.53
# epoch 8, step 37750/55000, batch loss = 0.00
# epoch 8, step 38000/55000, batch loss = 0.01
# epoch 8, step 38250/55000, batch loss = 0.02
# epoch 8, step 38500/55000, batch loss = 0.03
# epoch 8, step 38750/55000, batch loss = 0.00
# epoch 8, step 39000/55000, batch loss = 0.00
# epoch 8, step 39250/55000, batch loss = 0.00
# epoch 8, step 39500/55000, batch loss = 0.00
# epoch 8, step 39750/55000, batch loss = 0.01
# epoch 8, step 40000/55000, batch loss = 0.02
# Train accuracy = 99.52
# epoch 8, step 40250/55000, batch loss = 0.11
# epoch 8, step 40500/55000, batch loss = 0.00
# epoch 8, step 40750/55000, batch loss = 0.01
# epoch 8, step 41000/55000, batch loss = 0.04
# epoch 8, step 41250/55000, batch loss = 0.04
# epoch 8, step 41500/55000, batch loss = 0.02
# epoch 8, step 41750/55000, batch loss = 0.03
# epoch 8, step 42000/55000, batch loss = 0.00
# epoch 8, step 42250/55000, batch loss = 0.01
# epoch 8, step 42500/55000, batch loss = 0.03
# Train accuracy = 99.52
# epoch 8, step 42750/55000, batch loss = 0.01
# epoch 8, step 43000/55000, batch loss = 0.02
# epoch 8, step 43250/55000, batch loss = 0.01
# epoch 8, step 43500/55000, batch loss = 0.01
# epoch 8, step 43750/55000, batch loss = 0.01
# epoch 8, step 44000/55000, batch loss = 0.00
# epoch 8, step 44250/55000, batch loss = 0.16
# epoch 8, step 44500/55000, batch loss = 0.00
# epoch 8, step 44750/55000, batch loss = 0.00
# epoch 8, step 45000/55000, batch loss = 0.00
# Train accuracy = 99.52
# epoch 8, step 45250/55000, batch loss = 0.01
# epoch 8, step 45500/55000, batch loss = 0.00
# epoch 8, step 45750/55000, batch loss = 0.01
# epoch 8, step 46000/55000, batch loss = 0.07
# epoch 8, step 46250/55000, batch loss = 0.00
# epoch 8, step 46500/55000, batch loss = 0.00
# epoch 8, step 46750/55000, batch loss = 0.01
# epoch 8, step 47000/55000, batch loss = 0.00
# epoch 8, step 47250/55000, batch loss = 0.02
# epoch 8, step 47500/55000, batch loss = 0.05
# Train accuracy = 99.52
# epoch 8, step 47750/55000, batch loss = 0.01
# epoch 8, step 48000/55000, batch loss = 0.01
# epoch 8, step 48250/55000, batch loss = 0.00
# epoch 8, step 48500/55000, batch loss = 0.04
# epoch 8, step 48750/55000, batch loss = 0.03
# epoch 8, step 49000/55000, batch loss = 0.01
# epoch 8, step 49250/55000, batch loss = 0.01
# epoch 8, step 49500/55000, batch loss = 0.02
# epoch 8, step 49750/55000, batch loss = 0.00
# epoch 8, step 50000/55000, batch loss = 0.00
# Train accuracy = 99.53
# epoch 8, step 50250/55000, batch loss = 0.00
# epoch 8, step 50500/55000, batch loss = 0.00
# epoch 8, step 50750/55000, batch loss = 0.03
# epoch 8, step 51000/55000, batch loss = 0.01
# epoch 8, step 51250/55000, batch loss = 0.00
# epoch 8, step 51500/55000, batch loss = 0.00
# epoch 8, step 51750/55000, batch loss = 0.01
# epoch 8, step 52000/55000, batch loss = 0.01
# epoch 8, step 52250/55000, batch loss = 0.04
# epoch 8, step 52500/55000, batch loss = 0.00
# Train accuracy = 99.54
# epoch 8, step 52750/55000, batch loss = 0.02
# epoch 8, step 53000/55000, batch loss = 0.00
# epoch 8, step 53250/55000, batch loss = 0.00
# epoch 8, step 53500/55000, batch loss = 0.01
# epoch 8, step 53750/55000, batch loss = 0.00
# epoch 8, step 54000/55000, batch loss = 0.00
# epoch 8, step 54250/55000, batch loss = 0.00
# epoch 8, step 54500/55000, batch loss = 0.08
# epoch 8, step 54750/55000, batch loss = 0.02
# Train accuracy = 99.54
#
# Running evaluation:  Validation
# Validation accuracy = 99.14
# Validation avg loss = 0.03
#
#
# Running evaluation:  Test
# Test accuracy = 99.04
# Test avg loss = 0.02

# %% [markdown]
# **2. zadatak (25%)**

# %%
# %run train_l2reg
# Out:
# epoch 1, step 0/55000, batch loss = 2.82
# epoch 1, step 250/55000, batch loss = 2.47
# epoch 1, step 500/55000, batch loss = 1.88
# epoch 1, step 750/55000, batch loss = 2.05
# epoch 1, step 1000/55000, batch loss = 1.28
# epoch 1, step 1250/55000, batch loss = 1.35
# epoch 1, step 1500/55000, batch loss = 0.95
# epoch 1, step 1750/55000, batch loss = 1.03
# epoch 1, step 2000/55000, batch loss = 1.09
# epoch 1, step 2250/55000, batch loss = 0.80
# epoch 1, step 2500/55000, batch loss = 0.98
# Train accuracy = 67.96
# epoch 1, step 2750/55000, batch loss = 0.79
# epoch 1, step 3000/55000, batch loss = 0.66
# epoch 1, step 3250/55000, batch loss = 0.74
# epoch 1, step 3500/55000, batch loss = 0.68
# epoch 1, step 3750/55000, batch loss = 0.87
# epoch 1, step 4000/55000, batch loss = 0.70
# epoch 1, step 4250/55000, batch loss = 0.65
# epoch 1, step 4500/55000, batch loss = 0.73
# epoch 1, step 4750/55000, batch loss = 0.72
# epoch 1, step 5000/55000, batch loss = 0.80
# Train accuracy = 79.15
# epoch 1, step 5250/55000, batch loss = 0.65
# epoch 1, step 5500/55000, batch loss = 0.68
# epoch 1, step 5750/55000, batch loss = 0.59
# epoch 1, step 6000/55000, batch loss = 0.65
# epoch 1, step 6250/55000, batch loss = 0.54
# epoch 1, step 6500/55000, batch loss = 0.76
# epoch 1, step 6750/55000, batch loss = 0.57
# epoch 1, step 7000/55000, batch loss = 0.76
# epoch 1, step 7250/55000, batch loss = 0.61
# epoch 1, step 7500/55000, batch loss = 0.54
# Train accuracy = 83.74
# epoch 1, step 7750/55000, batch loss = 0.93
# epoch 1, step 8000/55000, batch loss = 0.54
# epoch 1, step 8250/55000, batch loss = 0.58
# epoch 1, step 8500/55000, batch loss = 0.62
# epoch 1, step 8750/55000, batch loss = 0.64
# epoch 1, step 9000/55000, batch loss = 0.66
# epoch 1, step 9250/55000, batch loss = 0.71
# epoch 1, step 9500/55000, batch loss = 0.69
# epoch 1, step 9750/55000, batch loss = 0.54
# epoch 1, step 10000/55000, batch loss = 0.52
# Train accuracy = 86.27
# epoch 1, step 10250/55000, batch loss = 0.74
# epoch 1, step 10500/55000, batch loss = 0.56
# epoch 1, step 10750/55000, batch loss = 0.56
# epoch 1, step 11000/55000, batch loss = 0.51
# epoch 1, step 11250/55000, batch loss = 0.47
# epoch 1, step 11500/55000, batch loss = 0.56
# epoch 1, step 11750/55000, batch loss = 0.61
# epoch 1, step 12000/55000, batch loss = 0.55
# epoch 1, step 12250/55000, batch loss = 0.61
# epoch 1, step 12500/55000, batch loss = 0.54
# Train accuracy = 88.18
# epoch 1, step 12750/55000, batch loss = 0.56
# epoch 1, step 13000/55000, batch loss = 0.44
# epoch 1, step 13250/55000, batch loss = 0.49
# epoch 1, step 13500/55000, batch loss = 0.49
# epoch 1, step 13750/55000, batch loss = 0.53
# epoch 1, step 14000/55000, batch loss = 0.55
# epoch 1, step 14250/55000, batch loss = 0.61
# epoch 1, step 14500/55000, batch loss = 0.44
# epoch 1, step 14750/55000, batch loss = 0.84
# epoch 1, step 15000/55000, batch loss = 0.53
# Train accuracy = 89.48
# epoch 1, step 15250/55000, batch loss = 0.61
# epoch 1, step 15500/55000, batch loss = 0.56
# epoch 1, step 15750/55000, batch loss = 0.53
# epoch 1, step 16000/55000, batch loss = 0.76
# epoch 1, step 16250/55000, batch loss = 0.58
# epoch 1, step 16500/55000, batch loss = 0.47
# epoch 1, step 16750/55000, batch loss = 0.49
# epoch 1, step 17000/55000, batch loss = 0.56
# epoch 1, step 17250/55000, batch loss = 0.50
# epoch 1, step 17500/55000, batch loss = 0.45
# Train accuracy = 90.40
# epoch 1, step 17750/55000, batch loss = 0.46
# epoch 1, step 18000/55000, batch loss = 0.51
# epoch 1, step 18250/55000, batch loss = 0.46
# epoch 1, step 18500/55000, batch loss = 0.49
# epoch 1, step 18750/55000, batch loss = 0.52
# epoch 1, step 19000/55000, batch loss = 0.46
# epoch 1, step 19250/55000, batch loss = 0.43
# epoch 1, step 19500/55000, batch loss = 0.55
# epoch 1, step 19750/55000, batch loss = 0.47
# epoch 1, step 20000/55000, batch loss = 0.55
# Train accuracy = 91.16
# epoch 1, step 20250/55000, batch loss = 0.49
# epoch 1, step 20500/55000, batch loss = 0.53
# epoch 1, step 20750/55000, batch loss = 0.48
# epoch 1, step 21000/55000, batch loss = 0.47
# epoch 1, step 21250/55000, batch loss = 0.54
# epoch 1, step 21500/55000, batch loss = 0.50
# epoch 1, step 21750/55000, batch loss = 0.46
# epoch 1, step 22000/55000, batch loss = 0.47
# epoch 1, step 22250/55000, batch loss = 0.61
# epoch 1, step 22500/55000, batch loss = 0.48
# Train accuracy = 91.76
# epoch 1, step 22750/55000, batch loss = 0.43
# epoch 1, step 23000/55000, batch loss = 0.45
# epoch 1, step 23250/55000, batch loss = 0.50
# epoch 1, step 23500/55000, batch loss = 0.47
# epoch 1, step 23750/55000, batch loss = 0.45
# epoch 1, step 24000/55000, batch loss = 0.53
# epoch 1, step 24250/55000, batch loss = 0.62
# epoch 1, step 24500/55000, batch loss = 0.44
# epoch 1, step 24750/55000, batch loss = 0.48
# epoch 1, step 25000/55000, batch loss = 0.49
# Train accuracy = 92.26
# epoch 1, step 25250/55000, batch loss = 0.45
# epoch 1, step 25500/55000, batch loss = 0.59
# epoch 1, step 25750/55000, batch loss = 0.44
# epoch 1, step 26000/55000, batch loss = 0.57
# epoch 1, step 26250/55000, batch loss = 0.61
# epoch 1, step 26500/55000, batch loss = 0.47
# epoch 1, step 26750/55000, batch loss = 0.53
# epoch 1, step 27000/55000, batch loss = 0.44
# epoch 1, step 27250/55000, batch loss = 0.60
# epoch 1, step 27500/55000, batch loss = 0.59
# Train accuracy = 92.69
# epoch 1, step 27750/55000, batch loss = 0.47
# epoch 1, step 28000/55000, batch loss = 0.49
# epoch 1, step 28250/55000, batch loss = 0.44
# epoch 1, step 28500/55000, batch loss = 0.44
# epoch 1, step 28750/55000, batch loss = 0.48
# epoch 1, step 29000/55000, batch loss = 0.47
# epoch 1, step 29250/55000, batch loss = 0.42
# epoch 1, step 29500/55000, batch loss = 0.52
# epoch 1, step 29750/55000, batch loss = 0.48
# epoch 1, step 30000/55000, batch loss = 0.49
# Train accuracy = 93.10
# epoch 1, step 30250/55000, batch loss = 0.47
# epoch 1, step 30500/55000, batch loss = 0.47
# epoch 1, step 30750/55000, batch loss = 0.53
# epoch 1, step 31000/55000, batch loss = 0.43
# epoch 1, step 31250/55000, batch loss = 0.46
# epoch 1, step 31500/55000, batch loss = 0.45
# epoch 1, step 31750/55000, batch loss = 0.43
# epoch 1, step 32000/55000, batch loss = 0.44
# epoch 1, step 32250/55000, batch loss = 0.44
# epoch 1, step 32500/55000, batch loss = 0.50
# Train accuracy = 93.43
# epoch 1, step 32750/55000, batch loss = 0.41
# epoch 1, step 33000/55000, batch loss = 0.54
# epoch 1, step 33250/55000, batch loss = 0.50
# epoch 1, step 33500/55000, batch loss = 0.41
# epoch 1, step 33750/55000, batch loss = 0.46
# epoch 1, step 34000/55000, batch loss = 0.44
# epoch 1, step 34250/55000, batch loss = 0.48
# epoch 1, step 34500/55000, batch loss = 0.58
# epoch 1, step 34750/55000, batch loss = 0.40
# epoch 1, step 35000/55000, batch loss = 0.44
# Train accuracy = 93.73
# epoch 1, step 35250/55000, batch loss = 0.47
# epoch 1, step 35500/55000, batch loss = 0.56
# epoch 1, step 35750/55000, batch loss = 0.44
# epoch 1, step 36000/55000, batch loss = 0.45
# epoch 1, step 36250/55000, batch loss = 0.44
# epoch 1, step 36500/55000, batch loss = 0.43
# epoch 1, step 36750/55000, batch loss = 0.40
# epoch 1, step 37000/55000, batch loss = 0.45
# epoch 1, step 37250/55000, batch loss = 0.49
# epoch 1, step 37500/55000, batch loss = 0.48
# Train accuracy = 93.98
# epoch 1, step 37750/55000, batch loss = 0.47
# epoch 1, step 38000/55000, batch loss = 0.46
# epoch 1, step 38250/55000, batch loss = 0.42
# epoch 1, step 38500/55000, batch loss = 0.46
# epoch 1, step 38750/55000, batch loss = 0.45
# epoch 1, step 39000/55000, batch loss = 0.57
# epoch 1, step 39250/55000, batch loss = 0.64
# epoch 1, step 39500/55000, batch loss = 0.44
# epoch 1, step 39750/55000, batch loss = 0.54
# epoch 1, step 40000/55000, batch loss = 0.51
# Train accuracy = 94.19
# epoch 1, step 40250/55000, batch loss = 0.45
# epoch 1, step 40500/55000, batch loss = 0.45
# epoch 1, step 40750/55000, batch loss = 0.40
# epoch 1, step 41000/55000, batch loss = 0.42
# epoch 1, step 41250/55000, batch loss = 0.51
# epoch 1, step 41500/55000, batch loss = 0.41
# epoch 1, step 41750/55000, batch loss = 0.51
# epoch 1, step 42000/55000, batch loss = 0.40
# epoch 1, step 42250/55000, batch loss = 0.41
# epoch 1, step 42500/55000, batch loss = 0.48
# Train accuracy = 94.41
# epoch 1, step 42750/55000, batch loss = 0.45
# epoch 1, step 43000/55000, batch loss = 0.41
# epoch 1, step 43250/55000, batch loss = 0.51
# epoch 1, step 43500/55000, batch loss = 0.50
# epoch 1, step 43750/55000, batch loss = 0.39
# epoch 1, step 44000/55000, batch loss = 0.39
# epoch 1, step 44250/55000, batch loss = 0.44
# epoch 1, step 44500/55000, batch loss = 0.41
# epoch 1, step 44750/55000, batch loss = 0.50
# epoch 1, step 45000/55000, batch loss = 0.45
# Train accuracy = 94.60
# epoch 1, step 45250/55000, batch loss = 0.50
# epoch 1, step 45500/55000, batch loss = 0.51
# epoch 1, step 45750/55000, batch loss = 0.40
# epoch 1, step 46000/55000, batch loss = 0.40
# epoch 1, step 46250/55000, batch loss = 0.55
# epoch 1, step 46500/55000, batch loss = 0.44
# epoch 1, step 46750/55000, batch loss = 0.46
# epoch 1, step 47000/55000, batch loss = 0.44
# epoch 1, step 47250/55000, batch loss = 0.42
# epoch 1, step 47500/55000, batch loss = 0.42
# Train accuracy = 94.74
# epoch 1, step 47750/55000, batch loss = 0.44
# epoch 1, step 48000/55000, batch loss = 0.41
# epoch 1, step 48250/55000, batch loss = 0.43
# epoch 1, step 48500/55000, batch loss = 0.43
# epoch 1, step 48750/55000, batch loss = 0.40
# epoch 1, step 49000/55000, batch loss = 0.52
# epoch 1, step 49250/55000, batch loss = 0.43
# epoch 1, step 49500/55000, batch loss = 0.40
# epoch 1, step 49750/55000, batch loss = 0.45
# epoch 1, step 50000/55000, batch loss = 0.44
# Train accuracy = 94.92
# epoch 1, step 50250/55000, batch loss = 0.40
# epoch 1, step 50500/55000, batch loss = 0.41
# epoch 1, step 50750/55000, batch loss = 0.50
# epoch 1, step 51000/55000, batch loss = 0.38
# epoch 1, step 51250/55000, batch loss = 0.38
# epoch 1, step 51500/55000, batch loss = 0.46
# epoch 1, step 51750/55000, batch loss = 0.44
# epoch 1, step 52000/55000, batch loss = 0.40
# epoch 1, step 52250/55000, batch loss = 0.45
# epoch 1, step 52500/55000, batch loss = 0.39
# Train accuracy = 95.06
# epoch 1, step 52750/55000, batch loss = 0.46
# epoch 1, step 53000/55000, batch loss = 0.39
# epoch 1, step 53250/55000, batch loss = 0.49
# epoch 1, step 53500/55000, batch loss = 0.40
# epoch 1, step 53750/55000, batch loss = 0.44
# epoch 1, step 54000/55000, batch loss = 0.61
# epoch 1, step 54250/55000, batch loss = 0.40
# epoch 1, step 54500/55000, batch loss = 0.47
# epoch 1, step 54750/55000, batch loss = 0.42
# Train accuracy = 95.16
#
# Running evaluation:  Validation
# Validation accuracy = 98.10
# Validation avg loss = 0.43
#
# epoch 2, step 0/55000, batch loss = 0.37
# epoch 2, step 250/55000, batch loss = 0.45
# epoch 2, step 500/55000, batch loss = 0.47
# epoch 2, step 750/55000, batch loss = 0.45
# epoch 2, step 1000/55000, batch loss = 0.39
# epoch 2, step 1250/55000, batch loss = 0.41
# epoch 2, step 1500/55000, batch loss = 0.41
# epoch 2, step 1750/55000, batch loss = 0.38
# epoch 2, step 2000/55000, batch loss = 0.45
# epoch 2, step 2250/55000, batch loss = 0.43
# epoch 2, step 2500/55000, batch loss = 0.37
# Train accuracy = 97.96
# epoch 2, step 2750/55000, batch loss = 0.37
# epoch 2, step 3000/55000, batch loss = 0.42
# epoch 2, step 3250/55000, batch loss = 0.38
# epoch 2, step 3500/55000, batch loss = 0.40
# epoch 2, step 3750/55000, batch loss = 0.39
# epoch 2, step 4000/55000, batch loss = 0.37
# epoch 2, step 4250/55000, batch loss = 0.44
# epoch 2, step 4500/55000, batch loss = 0.38
# epoch 2, step 4750/55000, batch loss = 0.37
# epoch 2, step 5000/55000, batch loss = 0.42
# Train accuracy = 98.28
# epoch 2, step 5250/55000, batch loss = 0.38
# epoch 2, step 5500/55000, batch loss = 0.36
# epoch 2, step 5750/55000, batch loss = 0.45
# epoch 2, step 6000/55000, batch loss = 0.60
# epoch 2, step 6250/55000, batch loss = 0.39
# epoch 2, step 6500/55000, batch loss = 0.37
# epoch 2, step 6750/55000, batch loss = 0.38
# epoch 2, step 7000/55000, batch loss = 0.44
# epoch 2, step 7250/55000, batch loss = 0.42
# epoch 2, step 7500/55000, batch loss = 0.36
# Train accuracy = 98.41
# epoch 2, step 7750/55000, batch loss = 0.38
# epoch 2, step 8000/55000, batch loss = 0.48
# epoch 2, step 8250/55000, batch loss = 0.40
# epoch 2, step 8500/55000, batch loss = 0.40
# epoch 2, step 8750/55000, batch loss = 0.37
# epoch 2, step 9000/55000, batch loss = 0.37
# epoch 2, step 9250/55000, batch loss = 0.39
# epoch 2, step 9500/55000, batch loss = 0.38
# epoch 2, step 9750/55000, batch loss = 0.43
# epoch 2, step 10000/55000, batch loss = 0.36
# Train accuracy = 98.40
# epoch 2, step 10250/55000, batch loss = 0.36
# epoch 2, step 10500/55000, batch loss = 0.38
# epoch 2, step 10750/55000, batch loss = 0.37
# epoch 2, step 11000/55000, batch loss = 0.36
# epoch 2, step 11250/55000, batch loss = 0.57
# epoch 2, step 11500/55000, batch loss = 0.36
# epoch 2, step 11750/55000, batch loss = 0.36
# epoch 2, step 12000/55000, batch loss = 0.41
# epoch 2, step 12250/55000, batch loss = 0.38
# epoch 2, step 12500/55000, batch loss = 0.44
# Train accuracy = 98.40
# epoch 2, step 12750/55000, batch loss = 0.37
# epoch 2, step 13000/55000, batch loss = 0.35
# epoch 2, step 13250/55000, batch loss = 0.38
# epoch 2, step 13500/55000, batch loss = 0.37
# epoch 2, step 13750/55000, batch loss = 0.35
# epoch 2, step 14000/55000, batch loss = 0.40
# epoch 2, step 14250/55000, batch loss = 0.46
# epoch 2, step 14500/55000, batch loss = 0.38
# epoch 2, step 14750/55000, batch loss = 0.36
# epoch 2, step 15000/55000, batch loss = 0.38
# Train accuracy = 98.44
# epoch 2, step 15250/55000, batch loss = 0.46
# epoch 2, step 15500/55000, batch loss = 0.44
# epoch 2, step 15750/55000, batch loss = 0.38
# epoch 2, step 16000/55000, batch loss = 0.46
# epoch 2, step 16250/55000, batch loss = 0.36
# epoch 2, step 16500/55000, batch loss = 0.36
# epoch 2, step 16750/55000, batch loss = 0.50
# epoch 2, step 17000/55000, batch loss = 0.35
# epoch 2, step 17250/55000, batch loss = 0.39
# epoch 2, step 17500/55000, batch loss = 0.43
# Train accuracy = 98.47
# epoch 2, step 17750/55000, batch loss = 0.35
# epoch 2, step 18000/55000, batch loss = 0.36
# epoch 2, step 18250/55000, batch loss = 0.37
# epoch 2, step 18500/55000, batch loss = 0.48
# epoch 2, step 18750/55000, batch loss = 0.45
# epoch 2, step 19000/55000, batch loss = 0.36
# epoch 2, step 19250/55000, batch loss = 0.39
# epoch 2, step 19500/55000, batch loss = 0.36
# epoch 2, step 19750/55000, batch loss = 0.37
# epoch 2, step 20000/55000, batch loss = 0.43
# Train accuracy = 98.44
# epoch 2, step 20250/55000, batch loss = 0.41
# epoch 2, step 20500/55000, batch loss = 0.37
# epoch 2, step 20750/55000, batch loss = 0.44
# epoch 2, step 21000/55000, batch loss = 0.41
# epoch 2, step 21250/55000, batch loss = 0.41
# epoch 2, step 21500/55000, batch loss = 0.35
# epoch 2, step 21750/55000, batch loss = 0.50
# epoch 2, step 22000/55000, batch loss = 0.37
# epoch 2, step 22250/55000, batch loss = 0.38
# epoch 2, step 22500/55000, batch loss = 0.40
# Train accuracy = 98.43
# epoch 2, step 22750/55000, batch loss = 0.39
# epoch 2, step 23000/55000, batch loss = 0.38
# epoch 2, step 23250/55000, batch loss = 0.35
# epoch 2, step 23500/55000, batch loss = 0.34
# epoch 2, step 23750/55000, batch loss = 0.34
# epoch 2, step 24000/55000, batch loss = 0.35
# epoch 2, step 24250/55000, batch loss = 0.78
# epoch 2, step 24500/55000, batch loss = 0.44
# epoch 2, step 24750/55000, batch loss = 0.42
# epoch 2, step 25000/55000, batch loss = 0.38
# Train accuracy = 98.40
# epoch 2, step 25250/55000, batch loss = 0.37
# epoch 2, step 25500/55000, batch loss = 0.34
# epoch 2, step 25750/55000, batch loss = 0.38
# epoch 2, step 26000/55000, batch loss = 0.36
# epoch 2, step 26250/55000, batch loss = 0.35
# epoch 2, step 26500/55000, batch loss = 0.36
# epoch 2, step 26750/55000, batch loss = 0.38
# epoch 2, step 27000/55000, batch loss = 0.37
# epoch 2, step 27250/55000, batch loss = 0.35
# epoch 2, step 27500/55000, batch loss = 0.39
# Train accuracy = 98.43
# epoch 2, step 27750/55000, batch loss = 0.36
# epoch 2, step 28000/55000, batch loss = 0.48
# epoch 2, step 28250/55000, batch loss = 0.35
# epoch 2, step 28500/55000, batch loss = 0.34
# epoch 2, step 28750/55000, batch loss = 0.34
# epoch 2, step 29000/55000, batch loss = 0.41
# epoch 2, step 29250/55000, batch loss = 0.35
# epoch 2, step 29500/55000, batch loss = 0.34
# epoch 2, step 29750/55000, batch loss = 0.33
# epoch 2, step 30000/55000, batch loss = 0.34
# Train accuracy = 98.42
# epoch 2, step 30250/55000, batch loss = 0.37
# epoch 2, step 30500/55000, batch loss = 0.34
# epoch 2, step 30750/55000, batch loss = 0.36
# epoch 2, step 31000/55000, batch loss = 0.34
# epoch 2, step 31250/55000, batch loss = 0.33
# epoch 2, step 31500/55000, batch loss = 0.37
# epoch 2, step 31750/55000, batch loss = 0.44
# epoch 2, step 32000/55000, batch loss = 0.36
# epoch 2, step 32250/55000, batch loss = 0.34
# epoch 2, step 32500/55000, batch loss = 0.42
# Train accuracy = 98.40
# epoch 2, step 32750/55000, batch loss = 0.36
# epoch 2, step 33000/55000, batch loss = 0.33
# epoch 2, step 33250/55000, batch loss = 0.47
# epoch 2, step 33500/55000, batch loss = 0.35
# epoch 2, step 33750/55000, batch loss = 0.34
# epoch 2, step 34000/55000, batch loss = 0.38
# epoch 2, step 34250/55000, batch loss = 0.33
# epoch 2, step 34500/55000, batch loss = 0.35
# epoch 2, step 34750/55000, batch loss = 0.38
# epoch 2, step 35000/55000, batch loss = 0.33
# Train accuracy = 98.44
# epoch 2, step 35250/55000, batch loss = 0.33
# epoch 2, step 35500/55000, batch loss = 0.33
# epoch 2, step 35750/55000, batch loss = 0.35
# epoch 2, step 36000/55000, batch loss = 0.33
# epoch 2, step 36250/55000, batch loss = 0.34
# epoch 2, step 36500/55000, batch loss = 0.48
# epoch 2, step 36750/55000, batch loss = 0.35
# epoch 2, step 37000/55000, batch loss = 0.40
# epoch 2, step 37250/55000, batch loss = 0.36
# epoch 2, step 37500/55000, batch loss = 0.32
# Train accuracy = 98.43
# epoch 2, step 37750/55000, batch loss = 0.37
# epoch 2, step 38000/55000, batch loss = 0.33
# epoch 2, step 38250/55000, batch loss = 0.34
# epoch 2, step 38500/55000, batch loss = 0.39
# epoch 2, step 38750/55000, batch loss = 0.34
# epoch 2, step 39000/55000, batch loss = 0.32
# epoch 2, step 39250/55000, batch loss = 0.34
# epoch 2, step 39500/55000, batch loss = 0.41
# epoch 2, step 39750/55000, batch loss = 0.41
# epoch 2, step 40000/55000, batch loss = 0.32
# Train accuracy = 98.45
# epoch 2, step 40250/55000, batch loss = 0.40
# epoch 2, step 40500/55000, batch loss = 0.35
# epoch 2, step 40750/55000, batch loss = 0.40
# epoch 2, step 41000/55000, batch loss = 0.35
# epoch 2, step 41250/55000, batch loss = 0.37
# epoch 2, step 41500/55000, batch loss = 0.33
# epoch 2, step 41750/55000, batch loss = 0.33
# epoch 2, step 42000/55000, batch loss = 0.38
# epoch 2, step 42250/55000, batch loss = 0.37
# epoch 2, step 42500/55000, batch loss = 0.33
# Train accuracy = 98.44
# epoch 2, step 42750/55000, batch loss = 0.35
# epoch 2, step 43000/55000, batch loss = 0.34
# epoch 2, step 43250/55000, batch loss = 0.46
# epoch 2, step 43500/55000, batch loss = 0.35
# epoch 2, step 43750/55000, batch loss = 0.35
# epoch 2, step 44000/55000, batch loss = 0.33
# epoch 2, step 44250/55000, batch loss = 0.34
# epoch 2, step 44500/55000, batch loss = 0.38
# epoch 2, step 44750/55000, batch loss = 0.32
# epoch 2, step 45000/55000, batch loss = 0.32
# Train accuracy = 98.47
# epoch 2, step 45250/55000, batch loss = 0.50
# epoch 2, step 45500/55000, batch loss = 0.36
# epoch 2, step 45750/55000, batch loss = 0.33
# epoch 2, step 46000/55000, batch loss = 0.54
# epoch 2, step 46250/55000, batch loss = 0.41
# epoch 2, step 46500/55000, batch loss = 0.50
# epoch 2, step 46750/55000, batch loss = 0.40
# epoch 2, step 47000/55000, batch loss = 0.37
# epoch 2, step 47250/55000, batch loss = 0.36
# epoch 2, step 47500/55000, batch loss = 0.41
# Train accuracy = 98.42
# epoch 2, step 47750/55000, batch loss = 0.33
# epoch 2, step 48000/55000, batch loss = 0.33
# epoch 2, step 48250/55000, batch loss = 0.48
# epoch 2, step 48500/55000, batch loss = 0.35
# epoch 2, step 48750/55000, batch loss = 0.37
# epoch 2, step 49000/55000, batch loss = 0.40
# epoch 2, step 49250/55000, batch loss = 0.33
# epoch 2, step 49500/55000, batch loss = 0.40
# epoch 2, step 49750/55000, batch loss = 0.37
# epoch 2, step 50000/55000, batch loss = 0.33
# Train accuracy = 98.43
# epoch 2, step 50250/55000, batch loss = 0.39
# epoch 2, step 50500/55000, batch loss = 0.34
# epoch 2, step 50750/55000, batch loss = 0.34
# epoch 2, step 51000/55000, batch loss = 0.36
# epoch 2, step 51250/55000, batch loss = 0.31
# epoch 2, step 51500/55000, batch loss = 0.31
# epoch 2, step 51750/55000, batch loss = 0.33
# epoch 2, step 52000/55000, batch loss = 0.33
# epoch 2, step 52250/55000, batch loss = 0.34
# epoch 2, step 52500/55000, batch loss = 0.38
# Train accuracy = 98.45
# epoch 2, step 52750/55000, batch loss = 0.33
# epoch 2, step 53000/55000, batch loss = 0.35
# epoch 2, step 53250/55000, batch loss = 0.41
# epoch 2, step 53500/55000, batch loss = 0.36
# epoch 2, step 53750/55000, batch loss = 0.35
# epoch 2, step 54000/55000, batch loss = 0.34
# epoch 2, step 54250/55000, batch loss = 0.32
# epoch 2, step 54500/55000, batch loss = 0.32
# epoch 2, step 54750/55000, batch loss = 0.35
# Train accuracy = 98.45
#
# Running evaluation:  Validation
# Validation accuracy = 98.40
# Validation avg loss = 0.35
#
# epoch 3, step 0/55000, batch loss = 0.34
# epoch 3, step 250/55000, batch loss = 0.36
# epoch 3, step 500/55000, batch loss = 0.31
# epoch 3, step 750/55000, batch loss = 0.32
# epoch 3, step 1000/55000, batch loss = 0.31
# epoch 3, step 1250/55000, batch loss = 0.36
# epoch 3, step 1500/55000, batch loss = 0.31
# epoch 3, step 1750/55000, batch loss = 0.42
# epoch 3, step 2000/55000, batch loss = 0.30
# epoch 3, step 2250/55000, batch loss = 0.32
# epoch 3, step 2500/55000, batch loss = 0.30
# Train accuracy = 99.22
# epoch 3, step 2750/55000, batch loss = 0.31
# epoch 3, step 3000/55000, batch loss = 0.30
# epoch 3, step 3250/55000, batch loss = 0.30
# epoch 3, step 3500/55000, batch loss = 0.43
# epoch 3, step 3750/55000, batch loss = 0.33
# epoch 3, step 4000/55000, batch loss = 0.35
# epoch 3, step 4250/55000, batch loss = 0.35
# epoch 3, step 4500/55000, batch loss = 0.31
# epoch 3, step 4750/55000, batch loss = 0.46
# epoch 3, step 5000/55000, batch loss = 0.30
# Train accuracy = 99.13
# epoch 3, step 5250/55000, batch loss = 0.30
# epoch 3, step 5500/55000, batch loss = 0.32
# epoch 3, step 5750/55000, batch loss = 0.45
# epoch 3, step 6000/55000, batch loss = 0.31
# epoch 3, step 6250/55000, batch loss = 0.35
# epoch 3, step 6500/55000, batch loss = 0.33
# epoch 3, step 6750/55000, batch loss = 0.31
# epoch 3, step 7000/55000, batch loss = 0.31
# epoch 3, step 7250/55000, batch loss = 0.31
# epoch 3, step 7500/55000, batch loss = 0.31
# Train accuracy = 99.13
# epoch 3, step 7750/55000, batch loss = 0.32
# epoch 3, step 8000/55000, batch loss = 0.31
# epoch 3, step 8250/55000, batch loss = 0.32
# epoch 3, step 8500/55000, batch loss = 0.30
# epoch 3, step 8750/55000, batch loss = 0.31
# epoch 3, step 9000/55000, batch loss = 0.30
# epoch 3, step 9250/55000, batch loss = 0.31
# epoch 3, step 9500/55000, batch loss = 0.35
# epoch 3, step 9750/55000, batch loss = 0.33
# epoch 3, step 10000/55000, batch loss = 0.33
# Train accuracy = 99.09
# epoch 3, step 10250/55000, batch loss = 0.30
# epoch 3, step 10500/55000, batch loss = 0.31
# epoch 3, step 10750/55000, batch loss = 0.31
# epoch 3, step 11000/55000, batch loss = 0.31
# epoch 3, step 11250/55000, batch loss = 0.32
# epoch 3, step 11500/55000, batch loss = 0.33
# epoch 3, step 11750/55000, batch loss = 0.30
# epoch 3, step 12000/55000, batch loss = 0.42
# epoch 3, step 12250/55000, batch loss = 0.32
# epoch 3, step 12500/55000, batch loss = 0.31
# Train accuracy = 99.14
# epoch 3, step 12750/55000, batch loss = 0.34
# epoch 3, step 13000/55000, batch loss = 0.31
# epoch 3, step 13250/55000, batch loss = 0.31
# epoch 3, step 13500/55000, batch loss = 0.38
# epoch 3, step 13750/55000, batch loss = 0.32
# epoch 3, step 14000/55000, batch loss = 0.31
# epoch 3, step 14250/55000, batch loss = 0.30
# epoch 3, step 14500/55000, batch loss = 0.31
# epoch 3, step 14750/55000, batch loss = 0.32
# epoch 3, step 15000/55000, batch loss = 0.30
# Train accuracy = 99.19
# epoch 3, step 15250/55000, batch loss = 0.30
# epoch 3, step 15500/55000, batch loss = 0.34
# epoch 3, step 15750/55000, batch loss = 0.31
# epoch 3, step 16000/55000, batch loss = 0.30
# epoch 3, step 16250/55000, batch loss = 0.31
# epoch 3, step 16500/55000, batch loss = 0.32
# epoch 3, step 16750/55000, batch loss = 0.46
# epoch 3, step 17000/55000, batch loss = 0.31
# epoch 3, step 17250/55000, batch loss = 0.33
# epoch 3, step 17500/55000, batch loss = 0.31
# Train accuracy = 99.20
# epoch 3, step 17750/55000, batch loss = 0.37
# epoch 3, step 18000/55000, batch loss = 0.42
# epoch 3, step 18250/55000, batch loss = 0.37
# epoch 3, step 18500/55000, batch loss = 0.32
# epoch 3, step 18750/55000, batch loss = 0.34
# epoch 3, step 19000/55000, batch loss = 0.32
# epoch 3, step 19250/55000, batch loss = 0.31
# epoch 3, step 19500/55000, batch loss = 0.32
# epoch 3, step 19750/55000, batch loss = 0.32
# epoch 3, step 20000/55000, batch loss = 0.40
# Train accuracy = 99.19
# epoch 3, step 20250/55000, batch loss = 0.34
# epoch 3, step 20500/55000, batch loss = 0.34
# epoch 3, step 20750/55000, batch loss = 0.31
# epoch 3, step 21000/55000, batch loss = 0.34
# epoch 3, step 21250/55000, batch loss = 0.31
# epoch 3, step 21500/55000, batch loss = 0.32
# epoch 3, step 21750/55000, batch loss = 0.31
# epoch 3, step 22000/55000, batch loss = 0.30
# epoch 3, step 22250/55000, batch loss = 0.31
# epoch 3, step 22500/55000, batch loss = 0.30
# Train accuracy = 99.14
# epoch 3, step 22750/55000, batch loss = 0.31
# epoch 3, step 23000/55000, batch loss = 0.32
# epoch 3, step 23250/55000, batch loss = 0.30
# epoch 3, step 23500/55000, batch loss = 0.31
# epoch 3, step 23750/55000, batch loss = 0.52
# epoch 3, step 24000/55000, batch loss = 0.35
# epoch 3, step 24250/55000, batch loss = 0.31
# epoch 3, step 24500/55000, batch loss = 0.31
# epoch 3, step 24750/55000, batch loss = 0.34
# epoch 3, step 25000/55000, batch loss = 0.31
# Train accuracy = 99.15
# epoch 3, step 25250/55000, batch loss = 0.34
# epoch 3, step 25500/55000, batch loss = 0.30
# epoch 3, step 25750/55000, batch loss = 0.31
# epoch 3, step 26000/55000, batch loss = 0.30
# epoch 3, step 26250/55000, batch loss = 0.31
# epoch 3, step 26500/55000, batch loss = 0.31
# epoch 3, step 26750/55000, batch loss = 0.35
# epoch 3, step 27000/55000, batch loss = 0.31
# epoch 3, step 27250/55000, batch loss = 0.34
# epoch 3, step 27500/55000, batch loss = 0.30
# Train accuracy = 99.17
# epoch 3, step 27750/55000, batch loss = 0.38
# epoch 3, step 28000/55000, batch loss = 0.33
# epoch 3, step 28250/55000, batch loss = 0.31
# epoch 3, step 28500/55000, batch loss = 0.37
# epoch 3, step 28750/55000, batch loss = 0.32
# epoch 3, step 29000/55000, batch loss = 0.32
# epoch 3, step 29250/55000, batch loss = 0.32
# epoch 3, step 29500/55000, batch loss = 0.36
# epoch 3, step 29750/55000, batch loss = 0.34
# epoch 3, step 30000/55000, batch loss = 0.32
# Train accuracy = 99.15
# epoch 3, step 30250/55000, batch loss = 0.30
# epoch 3, step 30500/55000, batch loss = 0.31
# epoch 3, step 30750/55000, batch loss = 0.38
# epoch 3, step 31000/55000, batch loss = 0.32
# epoch 3, step 31250/55000, batch loss = 0.35
# epoch 3, step 31500/55000, batch loss = 0.31
# epoch 3, step 31750/55000, batch loss = 0.30
# epoch 3, step 32000/55000, batch loss = 0.31
# epoch 3, step 32250/55000, batch loss = 0.31
# epoch 3, step 32500/55000, batch loss = 0.34
# Train accuracy = 99.17
# epoch 3, step 32750/55000, batch loss = 0.30
# epoch 3, step 33000/55000, batch loss = 0.32
# epoch 3, step 33250/55000, batch loss = 0.31
# epoch 3, step 33500/55000, batch loss = 0.31
# epoch 3, step 33750/55000, batch loss = 0.31
# epoch 3, step 34000/55000, batch loss = 0.30
# epoch 3, step 34250/55000, batch loss = 0.32
# epoch 3, step 34500/55000, batch loss = 0.31
# epoch 3, step 34750/55000, batch loss = 0.32
# epoch 3, step 35000/55000, batch loss = 0.33
# Train accuracy = 99.20
# epoch 3, step 35250/55000, batch loss = 0.30
# epoch 3, step 35500/55000, batch loss = 0.36
# epoch 3, step 35750/55000, batch loss = 0.30
# epoch 3, step 36000/55000, batch loss = 0.31
# epoch 3, step 36250/55000, batch loss = 0.30
# epoch 3, step 36500/55000, batch loss = 0.30
# epoch 3, step 36750/55000, batch loss = 0.33
# epoch 3, step 37000/55000, batch loss = 0.33
# epoch 3, step 37250/55000, batch loss = 0.30
# epoch 3, step 37500/55000, batch loss = 0.32
# Train accuracy = 99.22
# epoch 3, step 37750/55000, batch loss = 0.31
# epoch 3, step 38000/55000, batch loss = 0.30
# epoch 3, step 38250/55000, batch loss = 0.30
# epoch 3, step 38500/55000, batch loss = 0.31
# epoch 3, step 38750/55000, batch loss = 0.30
# epoch 3, step 39000/55000, batch loss = 0.31
# epoch 3, step 39250/55000, batch loss = 0.30
# epoch 3, step 39500/55000, batch loss = 0.30
# epoch 3, step 39750/55000, batch loss = 0.30
# epoch 3, step 40000/55000, batch loss = 0.31
# Train accuracy = 99.23
# epoch 3, step 40250/55000, batch loss = 0.30
# epoch 3, step 40500/55000, batch loss = 0.34
# epoch 3, step 40750/55000, batch loss = 0.31
# epoch 3, step 41000/55000, batch loss = 0.41
# epoch 3, step 41250/55000, batch loss = 0.30
# epoch 3, step 41500/55000, batch loss = 0.33
# epoch 3, step 41750/55000, batch loss = 0.31
# epoch 3, step 42000/55000, batch loss = 0.30
# epoch 3, step 42250/55000, batch loss = 0.31
# epoch 3, step 42500/55000, batch loss = 0.30
# Train accuracy = 99.23
# epoch 3, step 42750/55000, batch loss = 0.34
# epoch 3, step 43000/55000, batch loss = 0.33
# epoch 3, step 43250/55000, batch loss = 0.30
# epoch 3, step 43500/55000, batch loss = 0.31
# epoch 3, step 43750/55000, batch loss = 0.35
# epoch 3, step 44000/55000, batch loss = 0.30
# epoch 3, step 44250/55000, batch loss = 0.30
# epoch 3, step 44500/55000, batch loss = 0.31
# epoch 3, step 44750/55000, batch loss = 0.30
# epoch 3, step 45000/55000, batch loss = 0.30
# Train accuracy = 99.24
# epoch 3, step 45250/55000, batch loss = 0.31
# epoch 3, step 45500/55000, batch loss = 0.30
# epoch 3, step 45750/55000, batch loss = 0.32
# epoch 3, step 46000/55000, batch loss = 0.32
# epoch 3, step 46250/55000, batch loss = 0.37
# epoch 3, step 46500/55000, batch loss = 0.31
# epoch 3, step 46750/55000, batch loss = 0.30
# epoch 3, step 47000/55000, batch loss = 0.32
# epoch 3, step 47250/55000, batch loss = 0.32
# epoch 3, step 47500/55000, batch loss = 0.31
# Train accuracy = 99.25
# epoch 3, step 47750/55000, batch loss = 0.31
# epoch 3, step 48000/55000, batch loss = 0.31
# epoch 3, step 48250/55000, batch loss = 0.30
# epoch 3, step 48500/55000, batch loss = 0.31
# epoch 3, step 48750/55000, batch loss = 0.30
# epoch 3, step 49000/55000, batch loss = 0.30
# epoch 3, step 49250/55000, batch loss = 0.36
# epoch 3, step 49500/55000, batch loss = 0.33
# epoch 3, step 49750/55000, batch loss = 0.36
# epoch 3, step 50000/55000, batch loss = 0.32
# Train accuracy = 99.25
# epoch 3, step 50250/55000, batch loss = 0.30
# epoch 3, step 50500/55000, batch loss = 0.31
# epoch 3, step 50750/55000, batch loss = 0.31
# epoch 3, step 51000/55000, batch loss = 0.32
# epoch 3, step 51250/55000, batch loss = 0.31
# epoch 3, step 51500/55000, batch loss = 0.31
# epoch 3, step 51750/55000, batch loss = 0.31
# epoch 3, step 52000/55000, batch loss = 0.30
# epoch 3, step 52250/55000, batch loss = 0.30
# epoch 3, step 52500/55000, batch loss = 0.31
# Train accuracy = 99.25
# epoch 3, step 52750/55000, batch loss = 0.32
# epoch 3, step 53000/55000, batch loss = 0.30
# epoch 3, step 53250/55000, batch loss = 0.30
# epoch 3, step 53500/55000, batch loss = 0.31
# epoch 3, step 53750/55000, batch loss = 0.30
# epoch 3, step 54000/55000, batch loss = 0.31
# epoch 3, step 54250/55000, batch loss = 0.30
# epoch 3, step 54500/55000, batch loss = 0.32
# epoch 3, step 54750/55000, batch loss = 0.44
# Train accuracy = 99.24
#
# Running evaluation:  Validation
# Validation accuracy = 99.00
# Validation avg loss = 0.33
#
# epoch 4, step 0/55000, batch loss = 0.30
# epoch 4, step 250/55000, batch loss = 0.30
# epoch 4, step 500/55000, batch loss = 0.33
# epoch 4, step 750/55000, batch loss = 0.30
# epoch 4, step 1000/55000, batch loss = 0.30
# epoch 4, step 1250/55000, batch loss = 0.30
# epoch 4, step 1500/55000, batch loss = 0.30
# epoch 4, step 1750/55000, batch loss = 0.30
# epoch 4, step 2000/55000, batch loss = 0.34
# epoch 4, step 2250/55000, batch loss = 0.30
# epoch 4, step 2500/55000, batch loss = 0.30
# Train accuracy = 99.33
# epoch 4, step 2750/55000, batch loss = 0.30
# epoch 4, step 3000/55000, batch loss = 0.34
# epoch 4, step 3250/55000, batch loss = 0.30
# epoch 4, step 3500/55000, batch loss = 0.30
# epoch 4, step 3750/55000, batch loss = 0.30
# epoch 4, step 4000/55000, batch loss = 0.30
# epoch 4, step 4250/55000, batch loss = 0.32
# epoch 4, step 4500/55000, batch loss = 0.31
# epoch 4, step 4750/55000, batch loss = 0.36
# epoch 4, step 5000/55000, batch loss = 0.30
# Train accuracy = 99.25
# epoch 4, step 5250/55000, batch loss = 0.30
# epoch 4, step 5500/55000, batch loss = 0.31
# epoch 4, step 5750/55000, batch loss = 0.37
# epoch 4, step 6000/55000, batch loss = 0.38
# epoch 4, step 6250/55000, batch loss = 0.33
# epoch 4, step 6500/55000, batch loss = 0.31
# epoch 4, step 6750/55000, batch loss = 0.30
# epoch 4, step 7000/55000, batch loss = 0.37
# epoch 4, step 7250/55000, batch loss = 0.30
# epoch 4, step 7500/55000, batch loss = 0.30
# Train accuracy = 99.23
# epoch 4, step 7750/55000, batch loss = 0.31
# epoch 4, step 8000/55000, batch loss = 0.30
# epoch 4, step 8250/55000, batch loss = 0.30
# epoch 4, step 8500/55000, batch loss = 0.32
# epoch 4, step 8750/55000, batch loss = 0.30
# epoch 4, step 9000/55000, batch loss = 0.32
# epoch 4, step 9250/55000, batch loss = 0.35
# epoch 4, step 9500/55000, batch loss = 0.34
# epoch 4, step 9750/55000, batch loss = 0.30
# epoch 4, step 10000/55000, batch loss = 0.32
# Train accuracy = 99.25
# epoch 4, step 10250/55000, batch loss = 0.34
# epoch 4, step 10500/55000, batch loss = 0.32
# epoch 4, step 10750/55000, batch loss = 0.35
# epoch 4, step 11000/55000, batch loss = 0.30
# epoch 4, step 11250/55000, batch loss = 0.32
# epoch 4, step 11500/55000, batch loss = 0.30
# epoch 4, step 11750/55000, batch loss = 0.30
# epoch 4, step 12000/55000, batch loss = 0.30
# epoch 4, step 12250/55000, batch loss = 0.36
# epoch 4, step 12500/55000, batch loss = 0.31
# Train accuracy = 99.26
# epoch 4, step 12750/55000, batch loss = 0.30
# epoch 4, step 13000/55000, batch loss = 0.30
# epoch 4, step 13250/55000, batch loss = 0.30
# epoch 4, step 13500/55000, batch loss = 0.32
# epoch 4, step 13750/55000, batch loss = 0.31
# epoch 4, step 14000/55000, batch loss = 0.30
# epoch 4, step 14250/55000, batch loss = 0.30
# epoch 4, step 14500/55000, batch loss = 0.30
# epoch 4, step 14750/55000, batch loss = 0.30
# epoch 4, step 15000/55000, batch loss = 0.39
# Train accuracy = 99.33
# epoch 4, step 15250/55000, batch loss = 0.30
# epoch 4, step 15500/55000, batch loss = 0.30
# epoch 4, step 15750/55000, batch loss = 0.30
# epoch 4, step 16000/55000, batch loss = 0.30
# epoch 4, step 16250/55000, batch loss = 0.38
# epoch 4, step 16500/55000, batch loss = 0.33
# epoch 4, step 16750/55000, batch loss = 0.31
# epoch 4, step 17000/55000, batch loss = 0.39
# epoch 4, step 17250/55000, batch loss = 0.32
# epoch 4, step 17500/55000, batch loss = 0.32
# Train accuracy = 99.33
# epoch 4, step 17750/55000, batch loss = 0.30
# epoch 4, step 18000/55000, batch loss = 0.30
# epoch 4, step 18250/55000, batch loss = 0.32
# epoch 4, step 18500/55000, batch loss = 0.30
# epoch 4, step 18750/55000, batch loss = 0.31
# epoch 4, step 19000/55000, batch loss = 0.29
# epoch 4, step 19250/55000, batch loss = 0.32
# epoch 4, step 19500/55000, batch loss = 0.30
# epoch 4, step 19750/55000, batch loss = 0.29
# epoch 4, step 20000/55000, batch loss = 0.33
# Train accuracy = 99.33
# epoch 4, step 20250/55000, batch loss = 0.35
# epoch 4, step 20500/55000, batch loss = 0.31
# epoch 4, step 20750/55000, batch loss = 0.31
# epoch 4, step 21000/55000, batch loss = 0.30
# epoch 4, step 21250/55000, batch loss = 0.31
# epoch 4, step 21500/55000, batch loss = 0.30
# epoch 4, step 21750/55000, batch loss = 0.33
# epoch 4, step 22000/55000, batch loss = 0.31
# epoch 4, step 22250/55000, batch loss = 0.30
# epoch 4, step 22500/55000, batch loss = 0.29
# Train accuracy = 99.30
# epoch 4, step 22750/55000, batch loss = 0.34
# epoch 4, step 23000/55000, batch loss = 0.29
# epoch 4, step 23250/55000, batch loss = 0.30
# epoch 4, step 23500/55000, batch loss = 0.30
# epoch 4, step 23750/55000, batch loss = 0.36
# epoch 4, step 24000/55000, batch loss = 0.30
# epoch 4, step 24250/55000, batch loss = 0.35
# epoch 4, step 24500/55000, batch loss = 0.30
# epoch 4, step 24750/55000, batch loss = 0.35
# epoch 4, step 25000/55000, batch loss = 0.30
# Train accuracy = 99.32
# epoch 4, step 25250/55000, batch loss = 0.29
# epoch 4, step 25500/55000, batch loss = 0.32
# epoch 4, step 25750/55000, batch loss = 0.30
# epoch 4, step 26000/55000, batch loss = 0.29
# epoch 4, step 26250/55000, batch loss = 0.31
# epoch 4, step 26500/55000, batch loss = 0.37
# epoch 4, step 26750/55000, batch loss = 0.30
# epoch 4, step 27000/55000, batch loss = 0.31
# epoch 4, step 27250/55000, batch loss = 0.29
# epoch 4, step 27500/55000, batch loss = 0.30
# Train accuracy = 99.32
# epoch 4, step 27750/55000, batch loss = 0.30
# epoch 4, step 28000/55000, batch loss = 0.29
# epoch 4, step 28250/55000, batch loss = 0.30
# epoch 4, step 28500/55000, batch loss = 0.31
# epoch 4, step 28750/55000, batch loss = 0.31
# epoch 4, step 29000/55000, batch loss = 0.31
# epoch 4, step 29250/55000, batch loss = 0.31
# epoch 4, step 29500/55000, batch loss = 0.30
# epoch 4, step 29750/55000, batch loss = 0.30
# epoch 4, step 30000/55000, batch loss = 0.29
# Train accuracy = 99.34
# epoch 4, step 30250/55000, batch loss = 0.29
# epoch 4, step 30500/55000, batch loss = 0.33
# epoch 4, step 30750/55000, batch loss = 0.32
# epoch 4, step 31000/55000, batch loss = 0.39
# epoch 4, step 31250/55000, batch loss = 0.31
# epoch 4, step 31500/55000, batch loss = 0.29
# epoch 4, step 31750/55000, batch loss = 0.29
# epoch 4, step 32000/55000, batch loss = 0.38
# epoch 4, step 32250/55000, batch loss = 0.29
# epoch 4, step 32500/55000, batch loss = 0.30
# Train accuracy = 99.32
# epoch 4, step 32750/55000, batch loss = 0.29
# epoch 4, step 33000/55000, batch loss = 0.30
# epoch 4, step 33250/55000, batch loss = 0.32
# epoch 4, step 33500/55000, batch loss = 0.33
# epoch 4, step 33750/55000, batch loss = 0.32
# epoch 4, step 34000/55000, batch loss = 0.38
# epoch 4, step 34250/55000, batch loss = 0.31
# epoch 4, step 34500/55000, batch loss = 0.30
# epoch 4, step 34750/55000, batch loss = 0.30
# epoch 4, step 35000/55000, batch loss = 0.34
# Train accuracy = 99.32
# epoch 4, step 35250/55000, batch loss = 0.43
# epoch 4, step 35500/55000, batch loss = 0.32
# epoch 4, step 35750/55000, batch loss = 0.32
# epoch 4, step 36000/55000, batch loss = 0.30
# epoch 4, step 36250/55000, batch loss = 0.29
# epoch 4, step 36500/55000, batch loss = 0.30
# epoch 4, step 36750/55000, batch loss = 0.31
# epoch 4, step 37000/55000, batch loss = 0.31
# epoch 4, step 37250/55000, batch loss = 0.30
# epoch 4, step 37500/55000, batch loss = 0.30
# Train accuracy = 99.31
# epoch 4, step 37750/55000, batch loss = 0.31
# epoch 4, step 38000/55000, batch loss = 0.29
# epoch 4, step 38250/55000, batch loss = 0.33
# epoch 4, step 38500/55000, batch loss = 0.31
# epoch 4, step 38750/55000, batch loss = 0.30
# epoch 4, step 39000/55000, batch loss = 0.32
# epoch 4, step 39250/55000, batch loss = 0.29
# epoch 4, step 39500/55000, batch loss = 0.33
# epoch 4, step 39750/55000, batch loss = 0.30
# epoch 4, step 40000/55000, batch loss = 0.30
# Train accuracy = 99.33
# epoch 4, step 40250/55000, batch loss = 0.30
# epoch 4, step 40500/55000, batch loss = 0.31
# epoch 4, step 40750/55000, batch loss = 0.31
# epoch 4, step 41000/55000, batch loss = 0.37
# epoch 4, step 41250/55000, batch loss = 0.33
# epoch 4, step 41500/55000, batch loss = 0.29
# epoch 4, step 41750/55000, batch loss = 0.29
# epoch 4, step 42000/55000, batch loss = 0.36
# epoch 4, step 42250/55000, batch loss = 0.30
# epoch 4, step 42500/55000, batch loss = 0.31
# Train accuracy = 99.33
# epoch 4, step 42750/55000, batch loss = 0.29
# epoch 4, step 43000/55000, batch loss = 0.31
# epoch 4, step 43250/55000, batch loss = 0.29
# epoch 4, step 43500/55000, batch loss = 0.31
# epoch 4, step 43750/55000, batch loss = 0.30
# epoch 4, step 44000/55000, batch loss = 0.32
# epoch 4, step 44250/55000, batch loss = 0.38
# epoch 4, step 44500/55000, batch loss = 0.30
# epoch 4, step 44750/55000, batch loss = 0.29
# epoch 4, step 45000/55000, batch loss = 0.30
# Train accuracy = 99.32
# epoch 4, step 45250/55000, batch loss = 0.30
# epoch 4, step 45500/55000, batch loss = 0.31
# epoch 4, step 45750/55000, batch loss = 0.30
# epoch 4, step 46000/55000, batch loss = 0.30
# epoch 4, step 46250/55000, batch loss = 0.33
# epoch 4, step 46500/55000, batch loss = 0.31
# epoch 4, step 46750/55000, batch loss = 0.31
# epoch 4, step 47000/55000, batch loss = 0.32
# epoch 4, step 47250/55000, batch loss = 0.29
# epoch 4, step 47500/55000, batch loss = 0.29
# Train accuracy = 99.32
# epoch 4, step 47750/55000, batch loss = 0.29
# epoch 4, step 48000/55000, batch loss = 0.37
# epoch 4, step 48250/55000, batch loss = 0.34
# epoch 4, step 48500/55000, batch loss = 0.29
# epoch 4, step 48750/55000, batch loss = 0.30
# epoch 4, step 49000/55000, batch loss = 0.29
# epoch 4, step 49250/55000, batch loss = 0.30
# epoch 4, step 49500/55000, batch loss = 0.29
# epoch 4, step 49750/55000, batch loss = 0.33
# epoch 4, step 50000/55000, batch loss = 0.33
# Train accuracy = 99.31
# epoch 4, step 50250/55000, batch loss = 0.31
# epoch 4, step 50500/55000, batch loss = 0.29
# epoch 4, step 50750/55000, batch loss = 0.30
# epoch 4, step 51000/55000, batch loss = 0.29
# epoch 4, step 51250/55000, batch loss = 0.34
# epoch 4, step 51500/55000, batch loss = 0.29
# epoch 4, step 51750/55000, batch loss = 0.29
# epoch 4, step 52000/55000, batch loss = 0.29
# epoch 4, step 52250/55000, batch loss = 0.29
# epoch 4, step 52500/55000, batch loss = 0.41
# Train accuracy = 99.31
# epoch 4, step 52750/55000, batch loss = 0.29
# epoch 4, step 53000/55000, batch loss = 0.29
# epoch 4, step 53250/55000, batch loss = 0.29
# epoch 4, step 53500/55000, batch loss = 0.31
# epoch 4, step 53750/55000, batch loss = 0.34
# epoch 4, step 54000/55000, batch loss = 0.32
# epoch 4, step 54250/55000, batch loss = 0.29
# epoch 4, step 54500/55000, batch loss = 0.33
# epoch 4, step 54750/55000, batch loss = 0.29
# Train accuracy = 99.33
#
# Running evaluation:  Validation
# Validation accuracy = 99.04
# Validation avg loss = 0.32
#
# epoch 5, step 0/55000, batch loss = 0.41
# epoch 5, step 250/55000, batch loss = 0.32
# epoch 5, step 500/55000, batch loss = 0.30
# epoch 5, step 750/55000, batch loss = 0.46
# epoch 5, step 1000/55000, batch loss = 0.29
# epoch 5, step 1250/55000, batch loss = 0.36
# epoch 5, step 1500/55000, batch loss = 0.35
# epoch 5, step 1750/55000, batch loss = 0.31
# epoch 5, step 2000/55000, batch loss = 0.31
# epoch 5, step 2250/55000, batch loss = 0.33
# epoch 5, step 2500/55000, batch loss = 0.32
# Train accuracy = 99.18
# epoch 5, step 2750/55000, batch loss = 0.29
# epoch 5, step 3000/55000, batch loss = 0.34
# epoch 5, step 3250/55000, batch loss = 0.30
# epoch 5, step 3500/55000, batch loss = 0.32
# epoch 5, step 3750/55000, batch loss = 0.30
# epoch 5, step 4000/55000, batch loss = 0.29
# epoch 5, step 4250/55000, batch loss = 0.32
# epoch 5, step 4500/55000, batch loss = 0.29
# epoch 5, step 4750/55000, batch loss = 0.29
# epoch 5, step 5000/55000, batch loss = 0.29
# Train accuracy = 99.11
# epoch 5, step 5250/55000, batch loss = 0.43
# epoch 5, step 5500/55000, batch loss = 0.30
# epoch 5, step 5750/55000, batch loss = 0.30
# epoch 5, step 6000/55000, batch loss = 0.29
# epoch 5, step 6250/55000, batch loss = 0.29
# epoch 5, step 6500/55000, batch loss = 0.29
# epoch 5, step 6750/55000, batch loss = 0.31
# epoch 5, step 7000/55000, batch loss = 0.30
# epoch 5, step 7250/55000, batch loss = 0.30
# epoch 5, step 7500/55000, batch loss = 0.32
# Train accuracy = 99.26
# epoch 5, step 7750/55000, batch loss = 0.30
# epoch 5, step 8000/55000, batch loss = 0.29
# epoch 5, step 8250/55000, batch loss = 0.29
# epoch 5, step 8500/55000, batch loss = 0.30
# epoch 5, step 8750/55000, batch loss = 0.31
# epoch 5, step 9000/55000, batch loss = 0.31
# epoch 5, step 9250/55000, batch loss = 0.30
# epoch 5, step 9500/55000, batch loss = 0.29
# epoch 5, step 9750/55000, batch loss = 0.29
# epoch 5, step 10000/55000, batch loss = 0.29
# Train accuracy = 99.35
# epoch 5, step 10250/55000, batch loss = 0.30
# epoch 5, step 10500/55000, batch loss = 0.29
# epoch 5, step 10750/55000, batch loss = 0.29
# epoch 5, step 11000/55000, batch loss = 0.29
# epoch 5, step 11250/55000, batch loss = 0.29
# epoch 5, step 11500/55000, batch loss = 0.30
# epoch 5, step 11750/55000, batch loss = 0.30
# epoch 5, step 12000/55000, batch loss = 0.29
# epoch 5, step 12250/55000, batch loss = 0.29
# epoch 5, step 12500/55000, batch loss = 0.31
# Train accuracy = 99.39
# epoch 5, step 12750/55000, batch loss = 0.29
# epoch 5, step 13000/55000, batch loss = 0.36
# epoch 5, step 13250/55000, batch loss = 0.31
# epoch 5, step 13500/55000, batch loss = 0.34
# epoch 5, step 13750/55000, batch loss = 0.29
# epoch 5, step 14000/55000, batch loss = 0.31
# epoch 5, step 14250/55000, batch loss = 0.30
# epoch 5, step 14500/55000, batch loss = 0.32
# epoch 5, step 14750/55000, batch loss = 0.29
# epoch 5, step 15000/55000, batch loss = 0.34
# Train accuracy = 99.37
# epoch 5, step 15250/55000, batch loss = 0.29
# epoch 5, step 15500/55000, batch loss = 0.31
# epoch 5, step 15750/55000, batch loss = 0.30
# epoch 5, step 16000/55000, batch loss = 0.31
# epoch 5, step 16250/55000, batch loss = 0.31
# epoch 5, step 16500/55000, batch loss = 0.30
# epoch 5, step 16750/55000, batch loss = 0.29
# epoch 5, step 17000/55000, batch loss = 0.29
# epoch 5, step 17250/55000, batch loss = 0.31
# epoch 5, step 17500/55000, batch loss = 0.30
# Train accuracy = 99.39
# epoch 5, step 17750/55000, batch loss = 0.35
# epoch 5, step 18000/55000, batch loss = 0.29
# epoch 5, step 18250/55000, batch loss = 0.30
# epoch 5, step 18500/55000, batch loss = 0.29
# epoch 5, step 18750/55000, batch loss = 0.31
# epoch 5, step 19000/55000, batch loss = 0.31
# epoch 5, step 19250/55000, batch loss = 0.29
# epoch 5, step 19500/55000, batch loss = 0.30
# epoch 5, step 19750/55000, batch loss = 0.33
# epoch 5, step 20000/55000, batch loss = 0.40
# Train accuracy = 99.37
# epoch 5, step 20250/55000, batch loss = 0.29
# epoch 5, step 20500/55000, batch loss = 0.30
# epoch 5, step 20750/55000, batch loss = 0.29
# epoch 5, step 21000/55000, batch loss = 0.29
# epoch 5, step 21250/55000, batch loss = 0.33
# epoch 5, step 21500/55000, batch loss = 0.36
# epoch 5, step 21750/55000, batch loss = 0.31
# epoch 5, step 22000/55000, batch loss = 0.29
# epoch 5, step 22250/55000, batch loss = 0.29
# epoch 5, step 22500/55000, batch loss = 0.31
# Train accuracy = 99.39
# epoch 5, step 22750/55000, batch loss = 0.30
# epoch 5, step 23000/55000, batch loss = 0.29
# epoch 5, step 23250/55000, batch loss = 0.30
# epoch 5, step 23500/55000, batch loss = 0.29
# epoch 5, step 23750/55000, batch loss = 0.29
# epoch 5, step 24000/55000, batch loss = 0.38
# epoch 5, step 24250/55000, batch loss = 0.30
# epoch 5, step 24500/55000, batch loss = 0.33
# epoch 5, step 24750/55000, batch loss = 0.29
# epoch 5, step 25000/55000, batch loss = 0.30
# Train accuracy = 99.38
# epoch 5, step 25250/55000, batch loss = 0.33
# epoch 5, step 25500/55000, batch loss = 0.33
# epoch 5, step 25750/55000, batch loss = 0.29
# epoch 5, step 26000/55000, batch loss = 0.29
# epoch 5, step 26250/55000, batch loss = 0.34
# epoch 5, step 26500/55000, batch loss = 0.30
# epoch 5, step 26750/55000, batch loss = 0.30
# epoch 5, step 27000/55000, batch loss = 0.33
# epoch 5, step 27250/55000, batch loss = 0.29
# epoch 5, step 27500/55000, batch loss = 0.30
# Train accuracy = 99.39
# epoch 5, step 27750/55000, batch loss = 0.38
# epoch 5, step 28000/55000, batch loss = 0.29
# epoch 5, step 28250/55000, batch loss = 0.31
# epoch 5, step 28500/55000, batch loss = 0.29
# epoch 5, step 28750/55000, batch loss = 0.31
# epoch 5, step 29000/55000, batch loss = 0.29
# epoch 5, step 29250/55000, batch loss = 0.29
# epoch 5, step 29500/55000, batch loss = 0.29
# epoch 5, step 29750/55000, batch loss = 0.30
# epoch 5, step 30000/55000, batch loss = 0.34
# Train accuracy = 99.40
# epoch 5, step 30250/55000, batch loss = 0.29
# epoch 5, step 30500/55000, batch loss = 0.31
# epoch 5, step 30750/55000, batch loss = 0.29
# epoch 5, step 31000/55000, batch loss = 0.30
# epoch 5, step 31250/55000, batch loss = 0.31
# epoch 5, step 31500/55000, batch loss = 0.30
# epoch 5, step 31750/55000, batch loss = 0.30
# epoch 5, step 32000/55000, batch loss = 0.30
# epoch 5, step 32250/55000, batch loss = 0.29
# epoch 5, step 32500/55000, batch loss = 0.30
# Train accuracy = 99.40
# epoch 5, step 32750/55000, batch loss = 0.30
# ...
# epoch 7, step 26750/55000, batch loss = 0.31
# epoch 7, step 27000/55000, batch loss = 0.30
# epoch 7, step 27250/55000, batch loss = 0.29
# epoch 7, step 27500/55000, batch loss = 0.34
# Train accuracy = 99.44
# epoch 7, step 27750/55000, batch loss = 0.32
# epoch 7, step 28000/55000, batch loss = 0.29
# epoch 7, step 28250/55000, batch loss = 0.30
# epoch 7, step 28500/55000, batch loss = 0.29
# epoch 7, step 28750/55000, batch loss = 0.37
# epoch 7, step 29000/55000, batch loss = 0.29
# epoch 7, step 29250/55000, batch loss = 0.33
# epoch 7, step 29500/55000, batch loss = 0.29
# epoch 7, step 29750/55000, batch loss = 0.30
# epoch 7, step 30000/55000, batch loss = 0.29
# Train accuracy = 99.44
# epoch 7, step 30250/55000, batch loss = 0.29
# epoch 7, step 30500/55000, batch loss = 0.29
# epoch 7, step 30750/55000, batch loss = 0.29
# epoch 7, step 31000/55000, batch loss = 0.30
# epoch 7, step 31250/55000, batch loss = 0.30
# epoch 7, step 31500/55000, batch loss = 0.29
# epoch 7, step 31750/55000, batch loss = 0.29
# epoch 7, step 32000/55000, batch loss = 0.30
# epoch 7, step 32250/55000, batch loss = 0.32
# epoch 7, step 32500/55000, batch loss = 0.30
# Train accuracy = 99.44
# epoch 7, step 32750/55000, batch loss = 0.30
# epoch 7, step 33000/55000, batch loss = 0.32
# epoch 7, step 33250/55000, batch loss = 0.35
# epoch 7, step 33500/55000, batch loss = 0.31
# epoch 7, step 33750/55000, batch loss = 0.29
# epoch 7, step 34000/55000, batch loss = 0.29
# epoch 7, step 34250/55000, batch loss = 0.33
# epoch 7, step 34500/55000, batch loss = 0.30
# epoch 7, step 34750/55000, batch loss = 0.29
# epoch 7, step 35000/55000, batch loss = 0.29
# Train accuracy = 99.44
# epoch 7, step 35250/55000, batch loss = 0.31
# epoch 7, step 35500/55000, batch loss = 0.29
# epoch 7, step 35750/55000, batch loss = 0.30
# epoch 7, step 36000/55000, batch loss = 0.30
# epoch 7, step 36250/55000, batch loss = 0.30
# epoch 7, step 36500/55000, batch loss = 0.33
# epoch 7, step 36750/55000, batch loss = 0.31
# epoch 7, step 37000/55000, batch loss = 0.29
# epoch 7, step 37250/55000, batch loss = 0.29
# epoch 7, step 37500/55000, batch loss = 0.29
# Train accuracy = 99.44
# epoch 7, step 37750/55000, batch loss = 0.29
# epoch 7, step 38000/55000, batch loss = 0.29
# epoch 7, step 38250/55000, batch loss = 0.30
# epoch 7, step 38500/55000, batch loss = 0.30
# epoch 7, step 38750/55000, batch loss = 0.30
# epoch 7, step 39000/55000, batch loss = 0.37
# epoch 7, step 39250/55000, batch loss = 0.30
# epoch 7, step 39500/55000, batch loss = 0.30
# epoch 7, step 39750/55000, batch loss = 0.29
# epoch 7, step 40000/55000, batch loss = 0.31
# Train accuracy = 99.43
# epoch 7, step 40250/55000, batch loss = 0.30
# epoch 7, step 40500/55000, batch loss = 0.35
# epoch 7, step 40750/55000, batch loss = 0.30
# epoch 7, step 41000/55000, batch loss = 0.31
# epoch 7, step 41250/55000, batch loss = 0.36
# epoch 7, step 41500/55000, batch loss = 0.29
# epoch 7, step 41750/55000, batch loss = 0.29
# epoch 7, step 42000/55000, batch loss = 0.29
# epoch 7, step 42250/55000, batch loss = 0.29
# epoch 7, step 42500/55000, batch loss = 0.33
# Train accuracy = 99.42
# epoch 7, step 42750/55000, batch loss = 0.33
# epoch 7, step 43000/55000, batch loss = 0.32
# epoch 7, step 43250/55000, batch loss = 0.29
# epoch 7, step 43500/55000, batch loss = 0.31
# epoch 7, step 43750/55000, batch loss = 0.29
# epoch 7, step 44000/55000, batch loss = 0.29
# epoch 7, step 44250/55000, batch loss = 0.31
# epoch 7, step 44500/55000, batch loss = 0.29
# epoch 7, step 44750/55000, batch loss = 0.29
# epoch 7, step 45000/55000, batch loss = 0.30
# Train accuracy = 99.42
# epoch 7, step 45250/55000, batch loss = 0.29
# epoch 7, step 45500/55000, batch loss = 0.36
# epoch 7, step 45750/55000, batch loss = 0.30
# epoch 7, step 46000/55000, batch loss = 0.32
# epoch 7, step 46250/55000, batch loss = 0.30
# epoch 7, step 46500/55000, batch loss = 0.32
# epoch 7, step 46750/55000, batch loss = 0.29
# epoch 7, step 47000/55000, batch loss = 0.29
# epoch 7, step 47250/55000, batch loss = 0.29
# epoch 7, step 47500/55000, batch loss = 0.36
# Train accuracy = 99.43
# epoch 7, step 47750/55000, batch loss = 0.29
# epoch 7, step 48000/55000, batch loss = 0.32
# epoch 7, step 48250/55000, batch loss = 0.30
# epoch 7, step 48500/55000, batch loss = 0.29
# epoch 7, step 48750/55000, batch loss = 0.29
# epoch 7, step 49000/55000, batch loss = 0.29
# epoch 7, step 49250/55000, batch loss = 0.32
# epoch 7, step 49500/55000, batch loss = 0.30
# epoch 7, step 49750/55000, batch loss = 0.29
# epoch 7, step 50000/55000, batch loss = 0.29
# Train accuracy = 99.43
# epoch 7, step 50250/55000, batch loss = 0.29
# epoch 7, step 50500/55000, batch loss = 0.29
# epoch 7, step 50750/55000, batch loss = 0.29
# epoch 7, step 51000/55000, batch loss = 0.30
# epoch 7, step 51250/55000, batch loss = 0.33
# epoch 7, step 51500/55000, batch loss = 0.29
# epoch 7, step 51750/55000, batch loss = 0.30
# epoch 7, step 52000/55000, batch loss = 0.29
# epoch 7, step 52250/55000, batch loss = 0.29
# epoch 7, step 52500/55000, batch loss = 0.29
# Train accuracy = 99.44
# epoch 7, step 52750/55000, batch loss = 0.30
# epoch 7, step 53000/55000, batch loss = 0.31
# epoch 7, step 53250/55000, batch loss = 0.33
# epoch 7, step 53500/55000, batch loss = 0.29
# epoch 7, step 53750/55000, batch loss = 0.32
# epoch 7, step 54000/55000, batch loss = 0.29
# epoch 7, step 54250/55000, batch loss = 0.31
# epoch 7, step 54500/55000, batch loss = 0.31
# epoch 7, step 54750/55000, batch loss = 0.29
# Train accuracy = 99.45
#
# Running evaluation:  Validation
# Validation accuracy = 99.00
# Validation avg loss = 0.32
#
# epoch 8, step 0/55000, batch loss = 0.29
# epoch 8, step 250/55000, batch loss = 0.29
# epoch 8, step 500/55000, batch loss = 0.31
# epoch 8, step 750/55000, batch loss = 0.31
# epoch 8, step 1000/55000, batch loss = 0.31
# epoch 8, step 1250/55000, batch loss = 0.35
# epoch 8, step 1500/55000, batch loss = 0.29
# epoch 8, step 1750/55000, batch loss = 0.29
# epoch 8, step 2000/55000, batch loss = 0.33
# epoch 8, step 2250/55000, batch loss = 0.29
# epoch 8, step 2500/55000, batch loss = 0.31
# Train accuracy = 99.37
# epoch 8, step 2750/55000, batch loss = 0.31
# epoch 8, step 3000/55000, batch loss = 0.29
# epoch 8, step 3250/55000, batch loss = 0.29
# epoch 8, step 3500/55000, batch loss = 0.29
# epoch 8, step 3750/55000, batch loss = 0.30
# epoch 8, step 4000/55000, batch loss = 0.39
# epoch 8, step 4250/55000, batch loss = 0.32
# epoch 8, step 4500/55000, batch loss = 0.29
# epoch 8, step 4750/55000, batch loss = 0.29
# epoch 8, step 5000/55000, batch loss = 0.29
# Train accuracy = 99.37
# epoch 8, step 5250/55000, batch loss = 0.35
# epoch 8, step 5500/55000, batch loss = 0.29
# epoch 8, step 5750/55000, batch loss = 0.29
# epoch 8, step 6000/55000, batch loss = 0.31
# epoch 8, step 6250/55000, batch loss = 0.30
# epoch 8, step 6500/55000, batch loss = 0.35
# epoch 8, step 6750/55000, batch loss = 0.35
# epoch 8, step 7000/55000, batch loss = 0.32
# epoch 8, step 7250/55000, batch loss = 0.38
# epoch 8, step 7500/55000, batch loss = 0.31
# Train accuracy = 99.38
# epoch 8, step 7750/55000, batch loss = 0.30
# epoch 8, step 8000/55000, batch loss = 0.29
# epoch 8, step 8250/55000, batch loss = 0.31
# epoch 8, step 8500/55000, batch loss = 0.29
# epoch 8, step 8750/55000, batch loss = 0.29
# epoch 8, step 9000/55000, batch loss = 0.29
# epoch 8, step 9250/55000, batch loss = 0.34
# epoch 8, step 9500/55000, batch loss = 0.30
# epoch 8, step 9750/55000, batch loss = 0.31
# epoch 8, step 10000/55000, batch loss = 0.29
# Train accuracy = 99.39
# epoch 8, step 10250/55000, batch loss = 0.29
# epoch 8, step 10500/55000, batch loss = 0.29
# epoch 8, step 10750/55000, batch loss = 0.29
# epoch 8, step 11000/55000, batch loss = 0.33
# epoch 8, step 11250/55000, batch loss = 0.29
# epoch 8, step 11500/55000, batch loss = 0.29
# epoch 8, step 11750/55000, batch loss = 0.29
# epoch 8, step 12000/55000, batch loss = 0.31
# epoch 8, step 12250/55000, batch loss = 0.34
# epoch 8, step 12500/55000, batch loss = 0.33
# Train accuracy = 99.45
# epoch 8, step 12750/55000, batch loss = 0.29
# epoch 8, step 13000/55000, batch loss = 0.34
# epoch 8, step 13250/55000, batch loss = 0.30
# epoch 8, step 13500/55000, batch loss = 0.29
# epoch 8, step 13750/55000, batch loss = 0.33
# epoch 8, step 14000/55000, batch loss = 0.33
# epoch 8, step 14250/55000, batch loss = 0.31
# epoch 8, step 14500/55000, batch loss = 0.29
# epoch 8, step 14750/55000, batch loss = 0.30
# epoch 8, step 15000/55000, batch loss = 0.30
# Train accuracy = 99.46
# epoch 8, step 15250/55000, batch loss = 0.38
# epoch 8, step 15500/55000, batch loss = 0.36
# epoch 8, step 15750/55000, batch loss = 0.30
# epoch 8, step 16000/55000, batch loss = 0.36
# epoch 8, step 16250/55000, batch loss = 0.29
# epoch 8, step 16500/55000, batch loss = 0.29
# epoch 8, step 16750/55000, batch loss = 0.29
# epoch 8, step 17000/55000, batch loss = 0.33
# epoch 8, step 17250/55000, batch loss = 0.37
# epoch 8, step 17500/55000, batch loss = 0.30
# Train accuracy = 99.40
# epoch 8, step 17750/55000, batch loss = 0.29
# epoch 8, step 18000/55000, batch loss = 0.30
# epoch 8, step 18250/55000, batch loss = 0.29
# epoch 8, step 18500/55000, batch loss = 0.29
# epoch 8, step 18750/55000, batch loss = 0.30
# epoch 8, step 19000/55000, batch loss = 0.29
# epoch 8, step 19250/55000, batch loss = 0.29
# epoch 8, step 19500/55000, batch loss = 0.30
# epoch 8, step 19750/55000, batch loss = 0.30
# epoch 8, step 20000/55000, batch loss = 0.29
# Train accuracy = 99.40
# epoch 8, step 20250/55000, batch loss = 0.30
# epoch 8, step 20500/55000, batch loss = 0.29
# epoch 8, step 20750/55000, batch loss = 0.29
# epoch 8, step 21000/55000, batch loss = 0.29
# epoch 8, step 21250/55000, batch loss = 0.32
# epoch 8, step 21500/55000, batch loss = 0.31
# epoch 8, step 21750/55000, batch loss = 0.29
# epoch 8, step 22000/55000, batch loss = 0.30
# epoch 8, step 22250/55000, batch loss = 0.30
# epoch 8, step 22500/55000, batch loss = 0.29
# Train accuracy = 99.44
# epoch 8, step 22750/55000, batch loss = 0.30
# epoch 8, step 23000/55000, batch loss = 0.29
# epoch 8, step 23250/55000, batch loss = 0.31
# epoch 8, step 23500/55000, batch loss = 0.29
# epoch 8, step 23750/55000, batch loss = 0.29
# epoch 8, step 24000/55000, batch loss = 0.32
# epoch 8, step 24250/55000, batch loss = 0.30
# epoch 8, step 24500/55000, batch loss = 0.32
# epoch 8, step 24750/55000, batch loss = 0.29
# epoch 8, step 25000/55000, batch loss = 0.30
# Train accuracy = 99.46
# epoch 8, step 25250/55000, batch loss = 0.29
# epoch 8, step 25500/55000, batch loss = 0.30
# epoch 8, step 25750/55000, batch loss = 0.29
# epoch 8, step 26000/55000, batch loss = 0.29
# epoch 8, step 26250/55000, batch loss = 0.30
# epoch 8, step 26500/55000, batch loss = 0.31
# epoch 8, step 26750/55000, batch loss = 0.29
# epoch 8, step 27000/55000, batch loss = 0.37
# epoch 8, step 27250/55000, batch loss = 0.32
# epoch 8, step 27500/55000, batch loss = 0.30
# Train accuracy = 99.44
# epoch 8, step 27750/55000, batch loss = 0.30
# epoch 8, step 28000/55000, batch loss = 0.29
# epoch 8, step 28250/55000, batch loss = 0.29
# epoch 8, step 28500/55000, batch loss = 0.29
# epoch 8, step 28750/55000, batch loss = 0.30
# epoch 8, step 29000/55000, batch loss = 0.31
# epoch 8, step 29250/55000, batch loss = 0.32
# epoch 8, step 29500/55000, batch loss = 0.31
# epoch 8, step 29750/55000, batch loss = 0.34
# epoch 8, step 30000/55000, batch loss = 0.29
# Train accuracy = 99.45
# epoch 8, step 30250/55000, batch loss = 0.30
# epoch 8, step 30500/55000, batch loss = 0.30
# epoch 8, step 30750/55000, batch loss = 0.44
# epoch 8, step 31000/55000, batch loss = 0.29
# epoch 8, step 31250/55000, batch loss = 0.31
# epoch 8, step 31500/55000, batch loss = 0.30
# epoch 8, step 31750/55000, batch loss = 0.30
# epoch 8, step 32000/55000, batch loss = 0.30
# epoch 8, step 32250/55000, batch loss = 0.30
# epoch 8, step 32500/55000, batch loss = 0.29
# Train accuracy = 99.47
# epoch 8, step 32750/55000, batch loss = 0.31
# epoch 8, step 33000/55000, batch loss = 0.29
# epoch 8, step 33250/55000, batch loss = 0.30
# epoch 8, step 33500/55000, batch loss = 0.30
# epoch 8, step 33750/55000, batch loss = 0.30
# epoch 8, step 34000/55000, batch loss = 0.29
# epoch 8, step 34250/55000, batch loss = 0.34
# epoch 8, step 34500/55000, batch loss = 0.29
# epoch 8, step 34750/55000, batch loss = 0.30
# epoch 8, step 35000/55000, batch loss = 0.29
# Train accuracy = 99.47
# epoch 8, step 35250/55000, batch loss = 0.32
# epoch 8, step 35500/55000, batch loss = 0.29
# epoch 8, step 35750/55000, batch loss = 0.30
# epoch 8, step 36000/55000, batch loss = 0.33
# epoch 8, step 36250/55000, batch loss = 0.29
# epoch 8, step 36500/55000, batch loss = 0.30
# epoch 8, step 36750/55000, batch loss = 0.31
# epoch 8, step 37000/55000, batch loss = 0.35
# epoch 8, step 37250/55000, batch loss = 0.29
# epoch 8, step 37500/55000, batch loss = 0.29
# Train accuracy = 99.46
# epoch 8, step 37750/55000, batch loss = 0.30
# epoch 8, step 38000/55000, batch loss = 0.30
# epoch 8, step 38250/55000, batch loss = 0.30
# epoch 8, step 38500/55000, batch loss = 0.30
# epoch 8, step 38750/55000, batch loss = 0.30
# epoch 8, step 39000/55000, batch loss = 0.31
# epoch 8, step 39250/55000, batch loss = 0.30
# epoch 8, step 39500/55000, batch loss = 0.30
# epoch 8, step 39750/55000, batch loss = 0.29
# epoch 8, step 40000/55000, batch loss = 0.30
# Train accuracy = 99.46
# epoch 8, step 40250/55000, batch loss = 0.37
# epoch 8, step 40500/55000, batch loss = 0.30
# epoch 8, step 40750/55000, batch loss = 0.29
# epoch 8, step 41000/55000, batch loss = 0.30
# epoch 8, step 41250/55000, batch loss = 0.30
# epoch 8, step 41500/55000, batch loss = 0.30
# epoch 8, step 41750/55000, batch loss = 0.29
# epoch 8, step 42000/55000, batch loss = 0.29
# epoch 8, step 42250/55000, batch loss = 0.29
# epoch 8, step 42500/55000, batch loss = 0.30
# Train accuracy = 99.46
# epoch 8, step 42750/55000, batch loss = 0.31
# epoch 8, step 43000/55000, batch loss = 0.29
# epoch 8, step 43250/55000, batch loss = 0.35
# epoch 8, step 43500/55000, batch loss = 0.30
# epoch 8, step 43750/55000, batch loss = 0.29
# epoch 8, step 44000/55000, batch loss = 0.31
# epoch 8, step 44250/55000, batch loss = 0.30
# epoch 8, step 44500/55000, batch loss = 0.29
# epoch 8, step 44750/55000, batch loss = 0.33
# epoch 8, step 45000/55000, batch loss = 0.31
# Train accuracy = 99.46
# epoch 8, step 45250/55000, batch loss = 0.30
# epoch 8, step 45500/55000, batch loss = 0.29
# epoch 8, step 45750/55000, batch loss = 0.35
# epoch 8, step 46000/55000, batch loss = 0.30
# epoch 8, step 46250/55000, batch loss = 0.30
# epoch 8, step 46500/55000, batch loss = 0.30
# epoch 8, step 46750/55000, batch loss = 0.29
# epoch 8, step 47000/55000, batch loss = 0.34
# epoch 8, step 47250/55000, batch loss = 0.30
# epoch 8, step 47500/55000, batch loss = 0.29
# Train accuracy = 99.46
# epoch 8, step 47750/55000, batch loss = 0.29
# epoch 8, step 48000/55000, batch loss = 0.34
# epoch 8, step 48250/55000, batch loss = 0.30
# epoch 8, step 48500/55000, batch loss = 0.31
# epoch 8, step 48750/55000, batch loss = 0.29
# epoch 8, step 49000/55000, batch loss = 0.29
# epoch 8, step 49250/55000, batch loss = 0.29
# epoch 8, step 49500/55000, batch loss = 0.33
# epoch 8, step 49750/55000, batch loss = 0.29
# epoch 8, step 50000/55000, batch loss = 0.29
# Train accuracy = 99.47
# epoch 8, step 50250/55000, batch loss = 0.29
# epoch 8, step 50500/55000, batch loss = 0.29
# epoch 8, step 50750/55000, batch loss = 0.35
# epoch 8, step 51000/55000, batch loss = 0.29
# epoch 8, step 51250/55000, batch loss = 0.29
# epoch 8, step 51500/55000, batch loss = 0.31
# epoch 8, step 51750/55000, batch loss = 0.29
# epoch 8, step 52000/55000, batch loss = 0.31
# epoch 8, step 52250/55000, batch loss = 0.29
# epoch 8, step 52500/55000, batch loss = 0.29
# Train accuracy = 99.46
# epoch 8, step 52750/55000, batch loss = 0.30
# epoch 8, step 53000/55000, batch loss = 0.29
# epoch 8, step 53250/55000, batch loss = 0.36
# epoch 8, step 53500/55000, batch loss = 0.29
# epoch 8, step 53750/55000, batch loss = 0.29
# epoch 8, step 54000/55000, batch loss = 0.30
# epoch 8, step 54250/55000, batch loss = 0.31
# epoch 8, step 54500/55000, batch loss = 0.33
# epoch 8, step 54750/55000, batch loss = 0.29
# Train accuracy = 99.45
#
# Running evaluation:  Validation
# Validation accuracy = 99.00
# Validation avg loss = 0.32
#
#
# Running evaluation:  Test
# Test accuracy = 99.18
# Test avg loss = 0.31

# %% [markdown]
# **3. zadatak - usporedba s PyTorchem (25%)**

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
train_loader_MNIST, val_loader_MNIST, test_loader_MNIST = task_3.load_preprocess_and_create_MNIST_dataloaders()

# %%
# initialize model
model = task_3.ConvolutionalModel(in_channels=1, out_channels=16, class_count=10).to(device)

# train specs
config = {}
config['max_epochs'] = 8
config['batch_size'] = 50
config['save_dir'] = 'out2'
config['weight_decay'] = 1e-3
config['lr_policy'] = {1:1e-1, 3:1e-2, 5:1e-3, 7:1e-4}
config['print_every_n'] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19
# Train acuraccy = 98.78521478521478
# Epoch: 8/8, Step: 50250/55000, Batch loss: 0.10728328675031662
# Epoch: 8/8, Step: 50500/55000, Batch loss: 0.15352101624011993
# Epoch: 8/8, Step: 50750/55000, Batch loss: 0.0420382060110569
# Epoch: 8/8, Step: 51000/55000, Batch loss: 0.051974259316921234
# Epoch: 8/8, Step: 51250/55000, Batch loss: 0.15661901235580444
# Epoch: 8/8, Step: 51500/55000, Batch loss: 0.0061158365570008755
# Epoch: 8/8, Step: 51750/55000, Batch loss: 0.02038106881082058
# Epoch: 8/8, Step: 52000/55000, Batch loss: 0.08783121407032013
# Epoch: 8/8, Step: 52250/55000, Batch loss: 0.043936796486377716
# Epoch: 8/8, Step: 52500/55000, Batch loss: 0.04470188915729523
# Train acuraccy = 98.75166508087536
# Epoch: 8/8, Step: 52750/55000, Batch loss: 0.022075321525335312
# Epoch: 8/8, Step: 53000/55000, Batch loss: 0.00524511281400919
# Epoch: 8/8, Step: 53250/55000, Batch loss: 0.05640995129942894
# Epoch: 8/8, Step: 53500/55000, Batch loss: 0.02018224634230137
# Epoch: 8/8, Step: 53750/55000, Batch loss: 0.0056209866888821125
# Epoch: 8/8, Step: 54000/55000, Batch loss: 0.09176155924797058
# Epoch: 8/8, Step: 54250/55000, Batch loss: 0.05607744678854942
# Epoch: 8/8, Step: 54500/55000, Batch loss: 0.03961062803864479
# Epoch: 8/8, Step: 54750/55000, Batch loss: 0.09782364219427109
# Epoch: 8/8, Loss: 0.04072282463312149
# Train acuraccy = 98.74000000000001
#
# Running evaluation: Validation
# Validation acuraccy = 0.9807999730110168
# Validation avg loss = 0.06779836863279343

# %%
task_3.plot_conv_filters('First convolutional layer kernel after training', model.conv1.weight)
# Out:
# First convolutional layer kernel after training

# %%
_, _ = task_3.evaluate("Test", model, test_loader_MNIST, config)
# Out:
# Running evaluation: Test
# Test acuraccy = 0.9842000007629395
# Test avg loss = 0.05039869621396065

# %%
directory = 'task_3_losses_accs'
filename = 'train_losses'
task_3.plot_data(task_3.read_file_return_as_list(directory=directory, filename=filename), label='train loss')
filename = 'valid_losses'
task_3.plot_data(task_3.read_file_return_as_list(directory=directory, filename=filename), label='valid loss')
plt.xlabel('epochs')
plt.ylabel('losses')
plt.legend()

# %%
directory = 'task_3_losses_accs'
filename = 'train_accs'
task_3.plot_data(task_3.read_file_return_as_list(directory=directory, filename=filename), 'train acc')
filename = 'valid_accs'
task_3.plot_data(task_3.read_file_return_as_list(directory=directory, filename=filename), 'valid acc')
plt.xlabel('epochs')
plt.ylabel('acuraccies')
plt.legend()

# %% [markdown]
# **4. zadatak - Klasifikacija na skupu CIFAR-10 (25%)**

# %%
#DATA_DIR = Path(__file__).parent / 'datasets' / 'MNIST'
#SAVE_DIR = Path(__file__).parent / 'out2'

DATA_DIR = 'datasets/CIFAR10'
cifar10_train_set = CIFAR10(root=DATA_DIR, train=True, download=True, transform=None)
cifar10_test_set = CIFAR10(root=DATA_DIR, train=False, download=True, transform=None)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(cifar10_train_set.data.shape, cifar10_test_set.data.shape)
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)

# %%
import os
import pickle
import numpy as np
import skimage as ski
import skimage.io
import math
import torch
import torchvision
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torchvision.datasets import CIFAR10
import matplotlib.pyplot as plt
import skimage as ski
import skimage.io
from torch.utils.data import TensorDataset, DataLoader

device = 'cuda' if torch.cuda.is_available() else 'cpu'

class ConvolutionalModelCIFAR10(nn.Module):
  # conv(16,5) -> relu() -> pool(3,2) ->
  # conv(32,5) -> relu() -> pool(3,2) ->
  # fc(256) -> relu() ->
  # fc(128) -> relu() ->
  # fc(10)
  def __init__(self, in_channels1=3, out_channels1=16, kernel_size1=5, class_count=10):
    super().__init__()
    # sloj 1
    # in: batch_size x 3 x 32 x 32 (N=batch_size, C=3, H=32, W=32)
    self.conv1 = nn.Conv2d(in_channels1, out_channels1, kernel_size=kernel_size1, stride=1, padding=2, bias=True)
    # out: batch_size x 16 x 32 x 32
    self.relu1 = nn.ReLU()
    # out: batch_size x 16 x 32 x 32
    self.max_pool1 = nn.MaxPool2d(kernel_size=3, stride=2, padding=0)
    # out: batch_size x 16 x 15 x 15

    # sloj 2
    out_channels2 = 32
    self.conv2 = nn.Conv2d(out_channels1, out_channels2, kernel_size=kernel_size1, stride=1, padding=2, bias=True)
    # out: batch_size x 32 x 15 x 15
    self.relu2 = nn.ReLU()
    # out: batch_size x 32 x 15 x 15
    self.max_pool2 = nn.MaxPool2d(kernel_size=3, stride=2, padding=0)
    # out: batch_size x 32 x 7 x 7

    # sloj 3
    linear_in3 = 32 * 7 * 7
    self.fc3 = nn.Linear(in_features=linear_in3, out_features=256, bias=True)
    self.relu3 = nn.ReLU()

    # sloj 4
    self.fc4 = nn.Linear(in_features=256, out_features=128, bias=True)
    self.relu4 = nn.ReLU()

    # sloj 5
    self.fc_logits = nn.Linear(in_features=128, out_features=class_count, bias=True)

    # parametri su već inicijalizirani pozivima Conv2d i Linear
    # ali možemo ih drugačije inicijalizirati


    self.reset_parameters() #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

  def reset_parameters(self):
    for m in self.modules():
      if isinstance(m, nn.Conv2d):
        nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
        #nn.init.xavier_normal_(m.weight)
        nn.init.constant_(m.bias, 0)
      elif isinstance(m, nn.Linear) and m is not self.fc_logits:
        nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
        #nn.init.xavier_normal_(m.weight)
        nn.init.constant_(m.bias, 0)
    self.fc_logits.reset_parameters()


  def forward(self, x):
    # sloj 1
    h = self.conv1(x)
    h = self.max_pool1(h)
    h = self.relu1(h)  # može i h.relu() ili nn.functional.relu(h)

    # sloj 2
    h = self.conv2(h)
    h = self.max_pool2(h)
    h = self.relu2(h)

    # sloj 3
    h = h.contiguous().view(h.shape[0], -1) # https://stackoverflow.com/questions/66750391/runtimeerror-view-size-is-not-compatible-with-input-tensors-size-and-stride-a
    h = self.fc3(h)
    h = self.relu3(h)

    # sloj 4
    h = self.fc4(h)
    h = self.relu4(h)

    # sloj 5
    logits = self.fc_logits(h)
    return logits


  def get_loss(self, logits, y, loss_fn_name):
    if loss_fn_name == 'lce':
      return F.cross_entropy(logits, y)
    else:
      return multiclass_hinge_loss(logits, y)


def shuffle_data(data_x, data_y):
  indices = np.arange(data_x.shape[0])
  np.random.shuffle(indices)
  shuffled_data_x = np.ascontiguousarray(data_x[indices])
  shuffled_data_y = np.ascontiguousarray(data_y[indices])
  return shuffled_data_x, shuffled_data_y


def unpickle(file):
  fo = open(file, 'rb')
  dict = pickle.load(fo, encoding='latin1')
  fo.close()
  return dict


def preprocess_data():
  DATA_DIR = 'datasets/CIFAR10/cifar-10-batches-py/'

  img_height = 32
  img_width = 32
  num_channels = 3
  num_classes = 10

  train_x = np.ndarray((0, img_height * img_width * num_channels), dtype=np.float32)
  train_y = []
  for i in range(1, 6):
    subset = unpickle(os.path.join(DATA_DIR, 'data_batch_%d' % i))
    train_x = np.vstack((train_x, subset['data']))
    train_y += subset['labels']
  train_x = train_x.reshape((-1, num_channels, img_height, img_width)).transpose(0, 2, 3, 1)
  train_y = np.array(train_y, dtype=np.int32)

  subset = unpickle(os.path.join(DATA_DIR, 'test_batch'))
  test_x = subset['data'].reshape((-1, num_channels, img_height, img_width)).transpose(0, 2, 3, 1).astype(np.float32)
  test_y = np.array(subset['labels'], dtype=np.int32)

  valid_size = 5000
  train_x, train_y = shuffle_data(train_x, train_y)
  valid_x = train_x[:valid_size, ...]
  valid_y = train_y[:valid_size, ...]
  train_x = train_x[valid_size:, ...]
  train_y = train_y[valid_size:, ...]
  data_mean = train_x.mean((0, 1, 2))
  data_std = train_x.std((0, 1, 2))

  train_x = (train_x - data_mean) / data_std
  valid_x = (valid_x - data_mean) / data_std
  test_x = (test_x - data_mean) / data_std

  train_x = train_x.transpose(0, 3, 1, 2)
  valid_x = valid_x.transpose(0, 3, 1, 2)
  test_x = test_x.transpose(0, 3, 1, 2)

  return train_x, train_y, valid_x, valid_y, test_x, test_y


def draw_conv_filters(epoch, step, weights, save_dir):
  w = weights.copy()
  num_filters = w.shape[0]
  num_channels = w.shape[1]
  k = w.shape[2]
  assert w.shape[3] == w.shape[2]
  w = w.transpose(2, 3, 1, 0)
  w -= w.min()
  w /= w.max()
  border = 1
  cols = 8
  rows = math.ceil(num_filters / cols)
  width = cols * k + (cols-1) * border
  height = rows * k + (rows-1) * border
  img = np.zeros([height, width, num_channels])
  for i in range(num_filters):
    r = int(i / cols) * (k + border)
    c = int(i % cols) * (k + border)
    img[r:r+k,c:c+k,:] = w[:,:,:,i]
  filename = 'epoch_%02d_step_%06d.png' % (epoch, step)
  img = (img * 255).astype(np.uint8)
  ski.io.imsave(os.path.join(save_dir, filename), img)


def plot_conv_filters(title, weights):
  w = weights.copy()
  num_filters = w.shape[0]
  num_channels = w.shape[1]
  k = w.shape[2]
  assert w.shape[3] == w.shape[2]
  w = w.transpose(2, 3, 1, 0)
  w -= w.min()
  w /= w.max()
  border = 1
  cols = 8
  rows = math.ceil(num_filters / cols)
  width = cols * k + (cols-1) * border
  height = rows * k + (rows-1) * border
  img = np.zeros([height, width, num_channels])
  for i in range(num_filters):
    r = int(i / cols) * (k + border)
    c = int(i % cols) * (k + border)
    img[r:r+k,c:c+k,:] = w[:,:,:,i]
  print(title)
  plt.imshow((img * 255.0).astype(np.uint8))
  plt.axis('off')


def plot_training_progress(save_dir, data, loss_fn_name):
  fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16,8))

  linewidth = 2
  legend_size = 10
  train_color = 'm'
  val_color = 'c'

  num_points = len(data['train_loss'])
  x_data = np.linspace(1, num_points, num_points)
  ax1.set_title('Cross-entropy loss' if loss_fn_name == 'lce' else 'Multiclass hinge loss')
  ax1.plot(x_data, data['train_loss'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='train')
  ax1.plot(x_data, data['valid_loss'], marker='o', color=val_color,
           linewidth=linewidth, linestyle='-', label='validation')
  ax1.legend(loc='upper right', fontsize=legend_size)
  ax2.set_title('Average class accuracy')
  ax2.plot(x_data, data['train_acc'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='train')
  ax2.plot(x_data, data['valid_acc'], marker='o', color=val_color,
           linewidth=linewidth, linestyle='-', label='validation')
  ax2.legend(loc='upper left', fontsize=legend_size)
  ax3.set_title('Learning rate')
  ax3.plot(x_data, data['lr'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='learning_rate')
  ax3.legend(loc='upper left', fontsize=legend_size)

  save_path = os.path.join(save_dir, 'training_plot.png')
  print('Plotting in: ', save_path)
  plt.savefig(save_path)


def class_to_onehot(y):
  Yoh = np.zeros((y.shape[0],max(y)+1))
  Yoh[np.arange(len(y)),y] = 1
  return Yoh


def eval_perf_multi(Y_, Y):
  pr = []
  n = max(Y_)+1
  M = np.bincount(n * Y_ + Y, minlength=n*n).reshape(n, n)
  for i in range(n):
    tp_i = M[i,i]
    fn_i = np.sum(M[i,:]) - tp_i
    fp_i = np.sum(M[:,i]) - tp_i
    tn_i = np.sum(M) - fp_i - fn_i - tp_i
    recall_i = tp_i / (tp_i + fn_i)
    precision_i = tp_i / (tp_i + fp_i)
    pr.append( (recall_i, precision_i) )

  accuracy = np.trace(M)/np.sum(M)
  return accuracy, pr, M


def evaluate(model, x, y, loss_fn_name='lce'):
  with torch.no_grad():
    # loss
    logits = model.forward(x)
    loss = model.get_loss(logits, y, loss_fn_name)
    # točnost, preciznost, matricu zabune
    y_pred = np.argmax(logits.detach().cpu().numpy(), axis=1)
    acuraccy, precision, M = eval_perf_multi(y.detach().cpu(), y_pred)

  return loss, acuraccy


def train(model, train_x, train_labels, valid_x, valid_labels, num_epochs, n_batch, bsz, optimizer, lr_scheduler, SAVE_DIR='task_4_plot_data', loss_fn_name='lce'):
  device = 'cuda' if torch.cuda.is_available() else 'cpu'
  plot_data = {}
  plot_data['train_loss'] = []
  plot_data['valid_loss'] = []
  plot_data['train_acc'] = []
  plot_data['valid_acc'] = []
  plot_data['lr'] = []

  train_x_torch = torch.tensor(train_x).to(device)
  train_y_torch = torch.tensor(train_labels, dtype=torch.long).to(device)
  valid_x_torch = torch.tensor(valid_x).to(device)
  valid_y_torch = torch.tensor(valid_labels, dtype=torch.long).to(device)


  train_ds = TensorDataset(train_x_torch, train_y_torch)
  dataloader = DataLoader(train_ds, batch_size=bsz, shuffle=True)

  for epoch in range(num_epochs):
    for batch, (batch_x, batch_y) in enumerate(dataloader):
      model.train()
      batch_x = batch_x.to(device)
      batch_y = batch_y.to(device)

      logits = model.forward(batch_x)
      loss = model.get_loss(logits, batch_y, loss_fn_name)
      loss.backward()
      optimizer.step()
      optimizer.zero_grad()

      if batch%100 == 0:
        print("epoch: {}, step: {}/{}, batch_loss: {}".format(epoch, batch, n_batch, loss))

      if batch%200 == 0:
        draw_conv_filters(epoch, batch, model.conv1.weight.detach().cpu().numpy(), SAVE_DIR)

    train_loss, train_acc = evaluate(model, train_x_torch, train_y_torch, loss_fn_name)
    val_loss, val_acc = evaluate(model, valid_x_torch, valid_y_torch, loss_fn_name)
    print(f'Epoch: {epoch}/{num_epochs}')
    print(f'Train loss: {train_loss}')
    print(f'Train acc: {train_acc}')
    print(f'Val loss: {val_loss}')
    print(f'Val acc: {val_acc}')

    plot_data['train_loss'] += [train_loss.detach().cpu().numpy()]
    plot_data['valid_loss'] += [val_loss.detach().cpu().numpy()]
    plot_data['train_acc'] += [train_acc]
    plot_data['valid_acc'] += [val_acc]
    plot_data['lr'] += [lr_scheduler.get_last_lr()]
    lr_scheduler.step()

  plot_training_progress(SAVE_DIR, plot_data, loss_fn_name)

  return plot_data


def overfit_NN(model, train_x, train_labels, num_epochs, n_batch, bsz, optimizer, lr_scheduler, SAVE_DIR='task_4_plot_data', loss_fn_name='lce'):
  device = 'cuda' if torch.cuda.is_available() else 'cpu'

  train_x_torch = torch.tensor(train_x).to(device)
  train_y_torch = torch.tensor(train_labels, dtype=torch.long).to(device)

  train_ds = TensorDataset(train_x_torch, train_y_torch)
  dataloader = DataLoader(train_ds, batch_size=bsz, shuffle=True)

  for epoch in range(num_epochs):
    for batch, (batch_x, batch_y) in enumerate(dataloader):
      model.train()
      batch_x = batch_x.to(device)
      batch_y = batch_y.to(device)

      logits = model.forward(batch_x)
      loss = model.get_loss(logits, batch_y, loss_fn_name)
      loss.backward()
      optimizer.step()
      optimizer.zero_grad()

    train_loss, train_acc = evaluate(model, train_x_torch, train_y_torch, loss_fn_name)
    if epoch % 20 == 0:
      print(f'Epoch: {epoch}/{num_epochs}')
      print(f'Train loss: {train_loss}')
      print(f'Train acc: {train_acc}')


def draw_image(img, mean, std):
  img = img.transpose(1, 2, 0)
  img *= std
  img += mean
  #img = img.astype(np.uint8)
  ski.io.imshow(img)
  ski.io.show()


def show_k_missclassified_pictures_with_biggest_loss(model, x, y, mean, std, k=20):
  x = torch.tensor(x).to(device)
  y = torch.tensor(y, dtype=torch.long).to(device)
  with torch.no_grad():
    logits = model.forward(x)
    #mean = torch.mean(x, dim=(0, 2, 3))
    #std = torch.std(x, dim=(0, 2, 3))
  loss_per_example = F.cross_entropy(logits, y, reduction='none')
  top_20 = torch.topk(loss_per_example, k) # vraca k najvecih losseva i njihovih indeksa
  top_20_biggest_loss_x = x[top_20[1]]
  top_20_biggest_loss_correct_class = y[top_20[1]]
  top_20_biggest_loss_predicted_class_3, _ = torch.topk(F.softmax(logits[top_20[1]], dim=1), k=3, dim=1)

  for i in range(k):
    print(f'Correct class: {top_20_biggest_loss_correct_class[i]}')
    print(f'Top 3 largest predicted probabilities: {top_20_biggest_loss_predicted_class_3[i]}')
    draw_image(top_20_biggest_loss_x[i].detach().cpu().numpy(), mean.cpu().numpy(), std.cpu().numpy())



def compare_loss_functions_graphs(data1, data2, loss_fn_name1, loss_fn_name2):
  fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16,8))

  linewidth = 2
  legend_size = 10
  train_color1 = 'm'
  val_color1 = 'c'
  train_color2 = 'r'
  val_color2 = 'b'

  num_points = len(data1['train_loss'])
  x_data = np.linspace(1, num_points, num_points)
  ax1.set_title('Cross-entropy loss vs Multiclass hinge loss')
  ax1.plot(x_data, data1['train_loss'], marker='o', color=train_color1,
           linewidth=linewidth, linestyle='-', label='train lce')
  ax1.plot(x_data, data2['train_loss'], marker='o', color=train_color2,
           linewidth=linewidth, linestyle='-', label='train mchl')

  ax1.plot(x_data, data1['valid_loss'], marker='o', color=val_color1,
           linewidth=linewidth, linestyle='-', label='validation lce')
  ax1.plot(x_data, data2['valid_loss'], marker='o', color=val_color2,
           linewidth=linewidth, linestyle='-', label='validation mchl')

  ax1.legend(loc='upper right', fontsize=legend_size)
  ax2.set_title('Average class accuracy')
  ax2.plot(x_data, data1['train_acc'], marker='o', color=train_color1,
           linewidth=linewidth, linestyle='-', label='train lce')
  ax2.plot(x_data, data2['train_acc'], marker='o', color=train_color2,
           linewidth=linewidth, linestyle='-', label='train mchl')

  ax2.plot(x_data, data1['valid_acc'], marker='o', color=val_color1,
           linewidth=linewidth, linestyle='-', label='validation lce')
  ax2.plot(x_data, data2['valid_acc'], marker='o', color=val_color2,
           linewidth=linewidth, linestyle='-', label='validation mchl')

  ax2.legend(loc='upper left', fontsize=legend_size)
  ax3.set_title('Learning rate')
  ax3.plot(x_data, data1['lr'], marker='o', color=train_color1,
           linewidth=linewidth, linestyle='-', label='learning_rate lce')
  ax3.plot(x_data, data2['lr'], marker='o', color=train_color2,
           linewidth=linewidth, linestyle='-', label='learning_rate mchl')
  ax3.legend(loc='upper left', fontsize=legend_size)



def multiclass_hinge_loss(logits: torch.Tensor, target: torch.Tensor, delta=1.):
    '''
        Args:
            logits: torch.Tensor with shape (B, C), where B is batch size, and C is number of classes.
            target: torch.LongTensor with shape (B, ) representing ground truth labels.
            delta: Hyperparameter.
        Returns:
            Loss as scalar torch.Tensor.
    '''
    target_oh = F.one_hot(target, 10)
    mask = target_oh > 0
    logits_correct_class = torch.masked_select(logits, mask)[:, None]
    zeros = torch.zeros(logits.shape).to(device)
    return torch.mean(torch.sum(torch.max(zeros, logits - logits_correct_class + torch.tensor(delta).to(device)[None, None]), dim=1))

# %%
train_x, train_y, valid_x, valid_y, test_x, test_y = preprocess_data()

# %%
print("Train data shape:", train_x.shape, train_y.shape)
print("Valid data shape:", valid_x.shape, valid_y.shape)
print("Test data shape:", test_x.shape, test_y.shape)
# Out:
# Train data shape: (45000, 3, 32, 32) (45000,)
# Valid data shape: (5000, 3, 32, 32) (5000,)
# Test data shape: (10000, 3, 32, 32) (10000,)

# %%
CIFAR10_model = ConvolutionalModelCIFAR10().to(device) # https://stackoverflow.com/questions/59560043/what-is-the-difference-between-model-todevice-and-model-model-todevice

SAVE_KERNEL_WEIGHTS_DIR = 'task_4_kernel_weights'
draw_conv_filters(0, 0, CIFAR10_model.conv1.weight.detach().cpu().numpy(), SAVE_KERNEL_WEIGHTS_DIR)

# %%
plot_conv_filters('Kernel weights before training', CIFAR10_model.conv1.weight.detach().cpu().numpy())
# Out:
# Kernel weights before training

# %%
optimizer = torch.optim.Adam(CIFAR10_model.parameters(), lr=1e-3, weight_decay=1e-2)
scheduler  = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.8)
epochs = 10
batch_size = 50
num_batches = train_x.shape[0] // batch_size

# %%
plot_data = train(CIFAR10_model, train_x, train_y, valid_x, valid_y, epochs, num_batches, batch_size, optimizer, scheduler)
# Out:
# epoch: 0, step: 0/900, batch_loss: 3.1814568042755127
# epoch: 0, step: 100/900, batch_loss: 1.3958163261413574
# epoch: 0, step: 200/900, batch_loss: 1.6823680400848389
# epoch: 0, step: 300/900, batch_loss: 1.4877026081085205
# epoch: 0, step: 400/900, batch_loss: 1.4063422679901123
# epoch: 0, step: 500/900, batch_loss: 1.4532047510147095
# epoch: 0, step: 600/900, batch_loss: 1.2553436756134033
# epoch: 0, step: 700/900, batch_loss: 1.2413328886032104
# epoch: 0, step: 800/900, batch_loss: 1.2650755643844604
# Epoch: 0/10
# Train loss: 1.233609914779663
# Train acc: 0.5488666666666666
# Val loss: 1.260612964630127
# Val acc: 0.5442
# epoch: 1, step: 0/900, batch_loss: 1.3333897590637207
# epoch: 1, step: 100/900, batch_loss: 0.9796008467674255
# epoch: 1, step: 200/900, batch_loss: 1.1975200176239014
# epoch: 1, step: 300/900, batch_loss: 1.0490355491638184
# epoch: 1, step: 400/900, batch_loss: 1.0093650817871094
# epoch: 1, step: 500/900, batch_loss: 1.1130536794662476
# epoch: 1, step: 600/900, batch_loss: 1.2318272590637207
# epoch: 1, step: 700/900, batch_loss: 1.0977550745010376
# epoch: 1, step: 800/900, batch_loss: 1.2714346647262573
# Epoch: 1/10
# Train loss: 1.0696989297866821
# Train acc: 0.624
# Val loss: 1.1100475788116455
# Val acc: 0.6108
# epoch: 2, step: 0/900, batch_loss: 1.0365569591522217
# epoch: 2, step: 100/900, batch_loss: 0.8925334215164185
# epoch: 2, step: 200/900, batch_loss: 1.0649406909942627
# epoch: 2, step: 300/900, batch_loss: 1.0149273872375488
# epoch: 2, step: 400/900, batch_loss: 0.915256679058075
# epoch: 2, step: 500/900, batch_loss: 0.8584198951721191
# epoch: 2, step: 600/900, batch_loss: 0.9839964509010315
# epoch: 2, step: 700/900, batch_loss: 0.7285627126693726
# epoch: 2, step: 800/900, batch_loss: 0.8794705867767334
# Epoch: 2/10
# Train loss: 0.9162856936454773
# Train acc: 0.6850888888888889
# Val loss: 0.9612900614738464
# Val acc: 0.6726
# epoch: 3, step: 0/900, batch_loss: 0.8748655915260315
# epoch: 3, step: 100/900, batch_loss: 1.0233649015426636
# epoch: 3, step: 200/900, batch_loss: 0.7418626546859741
# epoch: 3, step: 300/900, batch_loss: 0.8191987872123718
# Epoch: 7/10
# Train loss: 0.7534096240997314
# Train acc: 0.7406444444444444
# Val loss: 0.8471043109893799
# Val acc: 0.7084
# epoch: 8, step: 0/900, batch_loss: 0.9391235113143921
# epoch: 8, step: 100/900, batch_loss: 0.6936945915222168
# epoch: 8, step: 200/900, batch_loss: 0.7639615535736084
# epoch: 8, step: 300/900, batch_loss: 0.6939456462860107
# epoch: 8, step: 400/900, batch_loss: 0.7367872595787048
# epoch: 8, step: 500/900, batch_loss: 0.6571927666664124
# epoch: 8, step: 600/900, batch_loss: 0.7440870404243469
# epoch: 8, step: 700/900, batch_loss: 0.7278392910957336
# epoch: 8, step: 800/900, batch_loss: 0.6880702376365662
# Epoch: 8/10
# Train loss: 0.7293528914451599
# Train acc: 0.7512
# Val loss: 0.8226185441017151
# Val acc: 0.7194
# epoch: 9, step: 0/900, batch_loss: 0.4176168739795685
# epoch: 9, step: 100/900, batch_loss: 0.5501906871795654
# epoch: 9, step: 200/900, batch_loss: 0.8770875334739685
# epoch: 9, step: 300/900, batch_loss: 0.5940337181091309
# epoch: 9, step: 400/900, batch_loss: 0.7805289626121521
# epoch: 9, step: 500/900, batch_loss: 0.5370664000511169
# epoch: 9, step: 600/900, batch_loss: 0.7163684368133545
# epoch: 9, step: 700/900, batch_loss: 0.7471332550048828
# epoch: 9, step: 800/900, batch_loss: 0.8532319664955139
# Epoch: 9/10
# Train loss: 0.7161761522293091
# Train acc: 0.7524
# Val loss: 0.8233253955841064
# Val acc: 0.7106
# Plotting in:  task_4_plot_data/training_plot.png

# %%
plot_conv_filters('Kernel weights after training', CIFAR10_model.conv1.weight.detach().cpu().numpy())
# Out:
# Kernel weights after training

# %%
mean = torch.mean(torch.tensor(train_x).to(device), dim=(0, 2, 3))
std = torch.std(torch.tensor(train_x).to(device), dim=(0, 2, 3))

# %%
show_k_missclassified_pictures_with_biggest_loss(CIFAR10_model, train_x, train_y, mean, std)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 0
# Top 3 largest predicted probabilities: tensor([0.9175, 0.0792, 0.0011], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 5
# Top 3 largest predicted probabilities: tensor([0.8106, 0.0854, 0.0809], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 1
# Top 3 largest predicted probabilities: tensor([0.9320, 0.0349, 0.0205], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 5
# Top 3 largest predicted probabilities: tensor([0.9954, 0.0015, 0.0012], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 4
# Top 3 largest predicted probabilities: tensor([0.9197, 0.0490, 0.0227], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 4
# Top 3 largest predicted probabilities: tensor([0.8949, 0.0940, 0.0059], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 9
# Top 3 largest predicted probabilities: tensor([0.6589, 0.1698, 0.0603], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 0
# Top 3 largest predicted probabilities: tensor([0.7553, 0.1949, 0.0414], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 3
# Top 3 largest predicted probabilities: tensor([0.8248, 0.1718, 0.0018], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 5
# Top 3 largest predicted probabilities: tensor([0.4526, 0.3276, 0.1220], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 2
# Top 3 largest predicted probabilities: tensor([0.8488, 0.0730, 0.0690], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 6
# Top 3 largest predicted probabilities: tensor([0.6248, 0.1992, 0.0776], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 7
# Top 3 largest predicted probabilities: tensor([0.9770, 0.0108, 0.0054], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 1
# Top 3 largest predicted probabilities: tensor([0.4811, 0.3165, 0.0637], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 1
# Top 3 largest predicted probabilities: tensor([0.4877, 0.4646, 0.0138], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 5
# Top 3 largest predicted probabilities: tensor([0.4838, 0.1978, 0.1937], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 6
# Top 3 largest predicted probabilities: tensor([0.9918, 0.0037, 0.0016], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 7
# Top 3 largest predicted probabilities: tensor([0.6417, 0.3494, 0.0063], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 0
# Top 3 largest predicted probabilities: tensor([0.3724, 0.2919, 0.2064], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 0
# Top 3 largest predicted probabilities: tensor([0.9756, 0.0130, 0.0037], device='cuda:0')

# %% [markdown]
# **Bonus zadatak - Multiclass hinge loss (max 20%)**

# %%
CIFAR10_model2 = ConvolutionalModelCIFAR10().to(device)
optimizer = torch.optim.Adam(CIFAR10_model2.parameters(), lr=1e-3, weight_decay=1e-2)
scheduler  = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.8)
epochs = 10
batch_size = 50
num_batches = train_x.shape[0] // batch_size

# %%
plot_conv_filters('Kernel weights before training', CIFAR10_model2.conv1.weight.detach().cpu().numpy())
# Out:
# Kernel weights before training

# %%
plot_data2 = train(CIFAR10_model2, train_x, train_y, valid_x, valid_y, epochs, num_batches, batch_size, optimizer, scheduler, 'bonus_task_plot_data', 'mchl')
# Out:
# epoch: 0, step: 0/900, batch_loss: 13.69968032836914
# epoch: 0, step: 100/900, batch_loss: 5.924997329711914
# epoch: 0, step: 200/900, batch_loss: 5.332002639770508
# epoch: 0, step: 300/900, batch_loss: 4.571177959442139
# epoch: 0, step: 400/900, batch_loss: 4.73920202255249
# epoch: 0, step: 500/900, batch_loss: 4.119267463684082
# epoch: 0, step: 600/900, batch_loss: 3.6685595512390137
# epoch: 0, step: 700/900, batch_loss: 3.448547840118408
# epoch: 0, step: 800/900, batch_loss: 3.362576484680176
# Epoch: 0/10
# Train loss: 3.0519638061523438
# Train acc: 0.6094
# Val loss: 3.2531073093414307
# Val acc: 0.5942
# epoch: 1, step: 0/900, batch_loss: 2.812884569168091
# epoch: 1, step: 100/900, batch_loss: 3.7201859951019287
# epoch: 1, step: 200/900, batch_loss: 2.612950325012207
# epoch: 1, step: 300/900, batch_loss: 2.9133856296539307
# epoch: 1, step: 400/900, batch_loss: 2.6842541694641113
# epoch: 1, step: 500/900, batch_loss: 2.841496229171753
# epoch: 1, step: 600/900, batch_loss: 3.547555446624756
# epoch: 1, step: 700/900, batch_loss: 2.7569146156311035
# epoch: 1, step: 800/900, batch_loss: 2.8264079093933105
# Epoch: 1/10
# Train loss: 2.7490909099578857
# Train acc: 0.6530222222222222
# Val loss: 3.0382533073425293
# Val acc: 0.6228
# epoch: 2, step: 0/900, batch_loss: 2.3288021087646484
# epoch: 2, step: 100/900, batch_loss: 2.426879644393921
# epoch: 2, step: 200/900, batch_loss: 3.356065511703491
# epoch: 2, step: 300/900, batch_loss: 3.270704984664917
# epoch: 2, step: 400/900, batch_loss: 2.3837671279907227
# epoch: 2, step: 500/900, batch_loss: 2.5341689586639404
# epoch: 2, step: 600/900, batch_loss: 3.0482144355773926
# epoch: 2, step: 700/900, batch_loss: 2.8946568965911865
# epoch: 2, step: 800/900, batch_loss: 2.9249672889709473
# Epoch: 2/10
# Train loss: 2.490450382232666
# Train acc: 0.6832222222222222
# Val loss: 2.797577142715454
# Val acc: 0.6528
# epoch: 3, step: 0/900, batch_loss: 1.8369356393814087
# epoch: 3, step: 100/900, batch_loss: 3.2119719982147217
# epoch: 3, step: 200/900, batch_loss: 2.7668488025665283
# epoch: 7, step: 800/900, batch_loss: 2.0140836238861084
# Epoch: 7/10
# Train loss: 1.8433923721313477
# Train acc: 0.7899777777777778
# Val loss: 2.3728890419006348
# Val acc: 0.7228
# epoch: 8, step: 0/900, batch_loss: 1.7433947324752808
# epoch: 8, step: 100/900, batch_loss: 1.7736419439315796
# epoch: 8, step: 200/900, batch_loss: 1.7544611692428589
# epoch: 8, step: 300/900, batch_loss: 1.7736175060272217
# epoch: 8, step: 400/900, batch_loss: 1.6272083520889282
# epoch: 8, step: 500/900, batch_loss: 2.0095627307891846
# epoch: 8, step: 600/900, batch_loss: 1.7400890588760376
# epoch: 8, step: 700/900, batch_loss: 2.053809404373169
# epoch: 8, step: 800/900, batch_loss: 1.6817737817764282
# Epoch: 8/10
# Train loss: 1.7689034938812256
# Train acc: 0.8052
# Val loss: 2.3419008255004883
# Val acc: 0.7268
# epoch: 9, step: 0/900, batch_loss: 1.5156633853912354
# epoch: 9, step: 100/900, batch_loss: 1.8939626216888428
# epoch: 9, step: 200/900, batch_loss: 1.6969683170318604
# epoch: 9, step: 300/900, batch_loss: 2.0854601860046387
# epoch: 9, step: 400/900, batch_loss: 2.116912603378296
# epoch: 9, step: 500/900, batch_loss: 1.8597631454467773
# epoch: 9, step: 600/900, batch_loss: 1.4609050750732422
# epoch: 9, step: 700/900, batch_loss: 1.7572190761566162
# epoch: 9, step: 800/900, batch_loss: 1.5537588596343994
# Epoch: 9/10
# Train loss: 1.7761727571487427
# Train acc: 0.8003555555555556
# Val loss: 2.371668577194214
# Val acc: 0.7278
# Plotting in:  bonus_task_plot_data/training_plot.png

# %%
plot_conv_filters('Kernel weights after training', CIFAR10_model2.conv1.weight.detach().cpu().numpy())
# Out:
# Kernel weights after training

# %%
show_k_missclassified_pictures_with_biggest_loss(CIFAR10_model2, train_x, train_y, mean, std)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 8
# Top 3 largest predicted probabilities: tensor([0.6141, 0.1132, 0.0818], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 5
# Top 3 largest predicted probabilities: tensor([0.9536, 0.0276, 0.0064], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 4
# Top 3 largest predicted probabilities: tensor([0.7825, 0.1219, 0.0414], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 3
# Top 3 largest predicted probabilities: tensor([0.9469, 0.0242, 0.0094], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 3
# Top 3 largest predicted probabilities: tensor([0.9466, 0.0347, 0.0103], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 5
# Top 3 largest predicted probabilities: tensor([0.4414, 0.1387, 0.1356], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 3
# Top 3 largest predicted probabilities: tensor([0.8116, 0.0722, 0.0570], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 0
# Top 3 largest predicted probabilities: tensor([0.3405, 0.3067, 0.2072], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 5
# Top 3 largest predicted probabilities: tensor([0.3141, 0.2973, 0.2395], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 5
# Top 3 largest predicted probabilities: tensor([0.9590, 0.0143, 0.0087], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 1
# Top 3 largest predicted probabilities: tensor([0.9489, 0.0186, 0.0143], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 3
# Top 3 largest predicted probabilities: tensor([0.5015, 0.4341, 0.0253], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 5
# Top 3 largest predicted probabilities: tensor([0.2893, 0.2333, 0.1996], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 3
# Top 3 largest predicted probabilities: tensor([0.8946, 0.0579, 0.0175], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 5
# Top 3 largest predicted probabilities: tensor([0.8559, 0.1045, 0.0159], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 1
# Top 3 largest predicted probabilities: tensor([0.9703, 0.0159, 0.0055], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 2
# Top 3 largest predicted probabilities: tensor([0.8834, 0.0533, 0.0347], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 9
# Top 3 largest predicted probabilities: tensor([0.4187, 0.3519, 0.0872], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 1
# Top 3 largest predicted probabilities: tensor([0.9487, 0.0169, 0.0129], device='cuda:0')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct class: 5
# Top 3 largest predicted probabilities: tensor([0.4995, 0.2898, 0.1522], device='cuda:0')

# %%
compare_loss_functions_graphs(plot_data, plot_data2, 'lce', 'mchl')
